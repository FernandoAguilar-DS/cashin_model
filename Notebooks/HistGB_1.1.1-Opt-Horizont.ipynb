# %%
# %%capture
pip install xgboost catboost optuna

# %%
import warnings, math
warnings.filterwarnings("ignore")
import calendar
import datetime as dt

import numpy as np
import pandas as pd
from pandas.api.types import is_datetime64_any_dtype, is_object_dtype, is_string_dtype
import matplotlib.pyplot as plt

from datetime import timedelta

# Métricas y visuales
from sklearn.metrics import (
    roc_auc_score, average_precision_score,
    precision_recall_curve, roc_curve,
    confusion_matrix, precision_score, recall_score,
    brier_score_loss
)
from sklearn.calibration import calibration_curve
from sklearn.model_selection import TimeSeriesSplit,train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler, FunctionTransformer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.calibration import CalibratedClassifierCV
from sklearn.isotonic import IsotonicRegression
from sklearn.metrics import confusion_matrix

# Opcionales (se activan si están instalados)
try:
    import xgboost as xgb
    HAS_XGB = True
except Exception:
    HAS_XGB = False

try:
    import lightgbm as lgb
    HAS_LGBM = True
except Exception:
    HAS_LGBM = False

try:
    from catboost import CatBoostClassifier, Pool
    HAS_CAT = True
except Exception:
    HAS_CAT = False
    

    
ID_COLS = {
    "user_id", "userid",
    "channelUserIdentifier",
    "premia_accountid", "accountid", "member_id",
    "spin_user_id", "id"
}

# %%
from google.cloud import bigquery
client = bigquery.Client(project="spin-aip-singularity-comp-sb")

query = """
SELECT * 
FROM `spin-aip-singularity-comp-sb.model_activation.dataste_model_activation_timewindow_reduction_V-1-4-1` 
"""
data = client.query(query).to_dataframe()

# %%
TZ_MX = "America/Mexico_City"

# -------------------------
# Helpers de fechas/tiempo
# -------------------------
def to_dt_local(s: pd.Series | None, tz: str = TZ_MX) -> pd.Series | None:
    """Convierte a datetime TZ-aware en MX. Soporta UTC/naive/None."""
    if s is None:
        return None
    x = pd.to_datetime(s, errors="coerce")
    # Si ya tiene tz, convierte; si no, localiza en MX
    if getattr(x.dt, "tz", None) is not None:
        return x.dt.tz_convert(tz)
    # Caso BigQuery Date/naive: localiza a medianoche MX
    return x.dt.tz_localize(tz, nonexistent="NaT", ambiguous="NaT")

def month_end(ts: pd.Timestamp) -> pd.Timestamp:
    last = calendar.monthrange(ts.year, ts.month)[1]
    return pd.Timestamp(year=ts.year, month=ts.month, day=last)

def near_payday_flag(dates: pd.Series, window_days: int = 3) -> pd.Series:
    """
    Flag=1 si la fecha cae cerca (±window_days) de quincena (15) o fin de mes.
    """
    d = pd.to_datetime(dates, errors="coerce")
    fifteenth = d.apply(lambda x: pd.Timestamp(year=x.year, month=x.month, day=15))
    monthend  = d.apply(month_end)
    dist15 = (d - fifteenth).abs().dt.days
    distEOM = (d - monthend ).abs().dt.days
    return ((dist15 <= window_days) | (distEOM <= window_days)).astype(int)

def make_daypart(h: int) -> str:
    if h < 12: return "morning"
    if h < 18: return "afternoon"
    return "night"

# -------------------------
# Labels (discretas + acum)
# -------------------------
def build_time_window_labels(
    df: pd.DataFrame,
    instant_hours: int = 1,
    signup_date_col: str = "signup_date",
    first_tx_ts_col: str | None = None,       # ej. "first_tx_ts" si existe
    activation_date_col: str = "activation_date_ever"
) -> pd.DataFrame:
    """
    Crea y_w0, y_w1, y_w7, y_w30 y y_cum30 con la definición:
      - W0:  [0, instant_hours] horas
      - W1:  (instant_hours, 24]
      - W7:  (24, 24*7]
      - W30: (24*7, 24*30]
    y_cum30 = 1 si activó en [0..30d]
    """
    out = df.copy(deep=True)

    # Base temporal de signup (date -> tz-aware a medianoche MX)
    if signup_date_col not in out.columns:
        raise ValueError(f"Falta columna {signup_date_col} para labels.")
    signup_dt = pd.to_datetime(out[signup_date_col], errors="coerce")
    signup_ts = signup_dt.dt.tz_localize(TZ_MX)

    # Origen de activación: preferimos TS exacto si existe, si no, date
    if first_tx_ts_col and first_tx_ts_col in out.columns:
        first_tx_ts = to_dt_local(out[first_tx_ts_col])
        delta_h = (first_tx_ts - signup_ts).dt.total_seconds() / 3600.0
    elif activation_date_col in out.columns:
        act_dt  = pd.to_datetime(out[activation_date_col], errors="coerce")
        act_ts  = act_dt.dt.tz_localize(TZ_MX)
        delta_h = (act_ts - signup_ts).dt.total_seconds() / 3600.0
    elif "days_to_first_activation" in out.columns:
        # Fallback directo si ya tienes el delta en días
        delta_h = pd.to_numeric(out["days_to_first_activation"], errors="coerce") * 24.0
    else:
        raise ValueError("No encuentro TS/DATE de activación (first_tx_ts / activation_date_ever / days_to_first_activation).")

    y_w0  = ((delta_h >= 0) & (delta_h <= instant_hours)).astype(int)
    y_w1  = ((delta_h > instant_hours) & (delta_h <= 24)).astype(int)
    y_w7  = ((delta_h > 24) & (delta_h <= 24*7)).astype(int)
    y_w30 = ((delta_h > 24*7) & (delta_h <= 24*30)).astype(int)

    out["y_w0"]   = y_w0.fillna(0)
    out["y_w1"]   = y_w1.fillna(0)
    out["y_w7"]   = y_w7.fillna(0)
    out["y_w30"]  = y_w30.fillna(0)
    out["y_cum30"]= (out["y_w0"] + out["y_w1"] + out["y_w7"] + out["y_w30"]).clip(0,1)

    return out

# ---------------------------------
# Features censurados hasta k días
# ---------------------------------
def build_features_at_k(
    df: pd.DataFrame,
    k_days: int,
    event_windows: list[tuple[str, str, str]] | None = None
) -> pd.DataFrame:
    """
    Genera features solo con info <= t_k = signup_ts + k días.
    - KYC momentum: tiempo/flags a confirmación teléfono/email
    - Card readiness: link de tarjeta
    - Premia hook
    - Calendario: DOW, week, month, hour, daypart, near_payday
    - Demografía: edad/age_bucket
    - Baseline por estado (lag-1 mes) con y_cum30
    - Cruces: canal×daypart, canal×estado, edad×canal
    - Limpia variables con riesgo de fuga post-activación
    """
    out = df.copy(deep=True)

    # signup_ts/t_k base (local, aware)
    if "signup_ts" in out:
        out["signup_ts"] = to_dt_local(out["signup_ts"])
    else:
        # Si sólo hay signup_date, localiza a medianoche MX
        sd = pd.to_datetime(out["signup_date"], errors="coerce")
        out["signup_ts"] = sd.dt.tz_localize(TZ_MX)

    out["t_k"] = out["signup_ts"] + pd.to_timedelta(k_days, unit="D")

    # Normalización de fechas adicionales
    out["signup_date"] = pd.to_datetime(out.get("signup_date"), errors="coerce").dt.date
    if "birth_date" in out:
        out["birth_date"] = pd.to_datetime(out["birth_date"], errors="coerce").dt.date

    # Phone/Email confirm (censurados a k)
    if "phone_conf_ts" in out:
        out["phone_conf_ts"] = to_dt_local(out["phone_conf_ts"])
    if "email_conf_ts" in out:
        out["email_conf_ts"] = to_dt_local(out["email_conf_ts"])

    # Card linked (si viene como fecha)
    if "Card_linked_date" in out:
        card_dt = pd.to_datetime(out["Card_linked_date"], errors="coerce")
        out["card_linked_ts"] = card_dt.dt.tz_localize(TZ_MX)

    # --- KYC momentum (censurado a k)
    def censored_lag(ts_col):
        ts = out[ts_col]
        dt_h = (ts - out["signup_ts"]).dt.total_seconds() / 3600.0
        return np.where(ts.notna() & (ts <= out["t_k"]), np.maximum(dt_h, 0), np.nan)

    out["time_to_phone_confirm_k"] = np.nan
    out["time_to_email_confirm_k"] = np.nan
    out["has_phone_confirm_by_k"]  = 0
    out["has_email_confirm_by_k"]  = 0

    if "phone_conf_ts" in out:
        out["time_to_phone_confirm_k"] = censored_lag("phone_conf_ts")
        out["has_phone_confirm_by_k"]  = ((out["phone_conf_ts"].notna()) & (out["phone_conf_ts"] <= out["t_k"])).astype(int)
    if "email_conf_ts" in out:
        out["time_to_email_confirm_k"] = censored_lag("email_conf_ts")
        out["has_email_confirm_by_k"]  = ((out["email_conf_ts"].notna()) & (out["email_conf_ts"] <= out["t_k"])).astype(int)

    # --- Card readiness (censurado a k)
    out["card_linked_by_k"]   = 0
    out["time_to_card_link_k"]= np.nan
    if "card_linked_ts" in out:
        within_k = ((out["card_linked_ts"].notna()) & (out["card_linked_ts"] <= out["t_k"]))
        out["card_linked_by_k"]    = within_k.astype(int)
        dt_h = (out["card_linked_ts"] - out["signup_ts"]).dt.total_seconds() / 3600.0
        out["time_to_card_link_k"] = np.where(within_k, np.maximum(dt_h, 0), np.nan)

    # --- Premia hook
    out["premia_present_at_signup"] = (
        (out["premia_accountid"].notna() if "premia_accountid" in out else False) |
        ((out["has_premia"] == 1)      if "has_premia"        in out else False)
    ).astype(int)

    # --- Calendario / operación
    out["signup_local"] = out["signup_ts"]  # alias semántico
    out["signup_dow"]   = out["signup_local"].dt.dayofweek.astype("Int64")
    out["signup_week"]  = out["signup_local"].dt.isocalendar().week.astype(int)
    out["signup_month"] = out["signup_local"].dt.month.astype(int)
    out["signup_hour"]  = out["signup_local"].dt.hour.astype(int)
    out["daypart"]      = out["signup_hour"].apply(make_daypart)
    out["near_payday_k"]= near_payday_flag(pd.to_datetime(out["signup_local"].dt.date))

    # Eventos exógenos (opcionales)
    if event_windows:
        for name, start, end in event_windows:
            mask = (
                (out["signup_local"].dt.date >= pd.to_datetime(start).date()) &
                (out["signup_local"].dt.date <= pd.to_datetime(end ).date())
            )
            out[f"event_{name}"] = mask.astype(int)

    # --- Demografía / Geo
    if "birth_date" in out:
        age_days = (pd.to_datetime(out["signup_local"].dt.date) - pd.to_datetime(out["birth_date"]))
        out["age_at_signup"] = np.floor(age_days.dt.days / 365.25).astype("float")
        bins   = [18,25,35,45,200]
        labels = ["18-24","25-34","35-44","45+"]
        out["age_bucket"] = pd.cut(out["age_at_signup"], bins=bins, labels=labels, right=False)

    # --- Baseline lag por estado (usa y_cum30 del MES PREVIO)
    if {"stateName", "y_cum30"}.issubset(out.columns):
        tmp = out[["stateName","signup_local","y_cum30"]].copy()
        tmp["signup_month_key"] = pd.to_datetime(tmp["signup_local"].dt.to_period("M").astype(str))
        rates = (
            tmp.groupby(["stateName","signup_month_key"])["y_cum30"]
               .mean().reset_index().rename(columns={"y_cum30":"state_rate_curr"})
        )
        lag = rates.copy()
        # Desplaza la llave al MES SIGUIENTE para que al unir quede como lag-1
        lag["signup_month_key"] = lag["signup_month_key"] + pd.offsets.MonthBegin(1)
        lag = lag.rename(columns={"state_rate_curr":"state_rate_lag1"})

        out["signup_month_key"] = pd.to_datetime(out["signup_local"].dt.to_period("M").astype(str))
        out = out.merge(lag, on=["stateName","signup_month_key"], how="left")

        # Fallback global (mes previo)
        global_rates = (
            tmp.groupby("signup_month_key")["y_cum30"]
               .mean().reset_index().rename(columns={"y_cum30":"global_rate"})
        )
        global_rates["signup_month_key"] = global_rates["signup_month_key"] + pd.offsets.MonthBegin(1)
        out = out.merge(global_rates, on="signup_month_key", how="left")

        out["state_activation_baseline_lag1"] = (
            out["state_rate_lag1"].fillna(out["global_rate"]).fillna(0.0)
        )

    # --- Cruces pro-señal (si existen insumos)
    if "channelDetail" in out and "daypart" in out:
        out["x_channel_daypart"] = out["channelDetail"].astype(str) + "__" + out["daypart"].astype(str)
    if "channelDetail" in out and "stateName" in out:
        out["x_channel_state"] = out["channelDetail"].astype(str) + "__" + out["stateName"].astype(str)
    if "age_bucket" in out and "channelDetail" in out:
        out["x_age_channel"] = out["age_bucket"].astype(str) + "__" + out["channelDetail"].astype(str)

    # --- Drop: columnas con alto riesgo de fuga
    drop_cols = [
        "activation_date_ever","activation_date_30d","label_activated_30d",
        "tx_30d_count","tx_30d_amount","label_5tx_30d","first_tx_type",
        "first_tx_amount","activation_channel","latest_tx_date",
        "lifespan_days","days_since_last","tx_30d_from_activation",
        "days_to_first_activation",
        # auxiliares temporales que no quieres en X
        "card_linked_ts","state_rate_lag1","state_rate_curr","global_rate"
    ]
    out = out.drop(columns=[c for c in drop_cols if c in out.columns], errors="ignore")

    return out

# ---------------------------------------
# Builder maestro: k in {0,1,7} (producción)
# ---------------------------------------
def build_all_features(
    df: pd.DataFrame,
    ks=(0,1,7),
    event_windows: list[tuple[str, str, str]] | None = None
) -> dict[int, pd.DataFrame]:
    """
    Devuelve {k: df_features_at_k} con anti-leak aplicado.
    """
    out = {}
    for k in ks:
        out[k] = build_features_at_k(df, k_days=k, event_windows=event_windows)
    return out

# ========================
#  EXEC: lab + features
# ========================
# 1) Deriva labels (si no traes y_*). Ajusta los nombres si tu tabla usa otros.
df_lab = build_time_window_labels(
    data,
    instant_hours=1,
    signup_date_col="signup_date",
    first_tx_ts_col=None,                 # e.g. "first_tx_ts" si existiera
    activation_date_col="activation_date_ever"
)

# 2) Genera features para k=0,1,7
features_dict = build_all_features(df_lab, ks=(0,1,7))
feat_k0 = features_dict[0].copy()
feat_k1 = features_dict[1].copy()
feat_k7 = features_dict[7].copy()

# 3) Columnas candidatas a X (ejemplo para k=0)
LEAKY_COLS = {"t_k","signup_local","signup_month_key","signup_ts"}  # auxiliares fuera de X
LABELISH   = {"y_w0","y_w1","y_w7","y_w30","y_cum30"}               # no entrenables
X_cols = [c for c in feat_k0.columns if c not in LEAKY_COLS | LABELISH]

print("feat_k0 shape:", feat_k0.shape)
print("feat_k1 shape:", feat_k1.shape)
print("feat_k7 shape:", feat_k7.shape)
print("X_cols (sample):", X_cols[:15])
# Out:
# feat_k0 shape: (2426355, 50)
# feat_k1 shape: (2426355, 50)
# feat_k7 shape: (2426355, 50)
# X_cols (sample): ['user_id', 'signup_date', 'userTypeIdentifier', 'channelUserIdentifier', 'accountLevel', 'stateName', 'gender', 'user_type', 'channelDetail', 'birth_date', 'birthState', 'Card_linked_date', 'IsActive', 'phn_confir', 'email_confir']

# %%
feat_k0 = feat_k0.loc[:, ~feat_k0.columns.duplicated()].copy()
feat_k1 = feat_k1.loc[:, ~feat_k1.columns.duplicated()].copy()
feat_k7 = feat_k7.loc[:, ~feat_k7.columns.duplicated()].copy()

# %%
# ========= RE-DECLARE: PurgedTimeSeriesCV (robusto) =========
TIME_COL = "signup_local"  # ya lo traes del factory

class PurgedTimeSeriesCV:
    """
    Forward-chaining CV por tiempo, con gap opcional antes del fold de validación
    y embargo opcional después. Entrena SOLO con pasado (sin futuro).
    """
    def __init__(self, n_splits=5, time_col=TIME_COL, gap_before_days=0, embargo_after_days=0):
        self.n_splits = int(n_splits)
        self.time_col = str(time_col)
        self.gap_before_days = int(gap_before_days)
        self.embargo_after_days = int(embargo_after_days)

    def split(self, X: pd.DataFrame, y=None):
        # 1) Garantiza una sola columna temporal
        if self.time_col not in X.columns:
            raise KeyError(f"TIME_COL '{self.time_col}' no está en X.columns.")
        x_time = X.loc[:, [self.time_col]]
        if x_time.shape[1] > 1:  # si hubo duplicados de nombre, quédate con la primera
            x_time = x_time.iloc[:, [0]]

        # 2) A datetime seguro (soporta db_dtypes.*)
        s_time = pd.to_datetime(x_time.iloc[:, 0], errors="coerce")

        # 3) Timestamps únicos y bounds por cuantiles
        t_sorted = s_time.sort_values()
        uniq_times = pd.Series(t_sorted).dropna().unique()
        if len(uniq_times) < self.n_splits + 1:
            raise ValueError("Muy pocos timestamps únicos para el n_splits solicitado.")

        # Índices de cortes (n_splits+1 “bordes”)
        cut_idx = np.linspace(0, len(uniq_times) - 1, self.n_splits + 1, dtype=int)

        for i in range(self.n_splits):
            val_start = uniq_times[cut_idx[i]]
            val_end   = uniq_times[cut_idx[i+1]] if i < self.n_splits - 1 else uniq_times[-1]

            # Validación: [val_start, val_end) salvo el último que es [val_start, +inf)
            if i < self.n_splits - 1:
                val_mask = (s_time >= val_start) & (s_time < val_end)
            else:
                val_mask = (s_time >= val_start)

            # Gap antes del inicio de validación
            gap_start = val_start - pd.Timedelta(days=self.gap_before_days)

            # Entrenamiento: estrictamente pasado (y respetando el gap)
            train_mask = (s_time < gap_start)

            # Embargo opcional post-validación (no es necesario si ya usamos solo pasado,
            # lo dejamos para futuras variantes si miras ventanas amplias)
            # embargo_end = val_end + pd.Timedelta(days=self.embargo_after_days)

            tr_idx = np.where(train_mask)[0]
            va_idx = np.where(val_mask)[0]

            # Sanity: evita folds vacíos
            if len(tr_idx) == 0 or len(va_idx) == 0:
                continue
            yield tr_idx, va_idx

# ====== EXTRA: asegúrate de no tener columnas duplicadas en X de cada horizonte
def _dedup_cols(df: pd.DataFrame) -> pd.DataFrame:
    return df.loc[:, ~df.columns.duplicated()].copy()

# %%
# === 1) Métricas/visuales/umbral/fairness ===
def auprc(y_true, y_proba):
    return average_precision_score(y_true, y_proba)

def gains_curve(y_true, y_proba, target_class=0):
    scores = y_proba if target_class==1 else (1 - y_proba)
    order  = np.argsort(scores)[::-1]
    y      = (y_true == target_class).astype(int)[order]
    cum_evt = np.cumsum(y)
    perc_pop = np.arange(1, len(y)+1)/len(y)
    gains = cum_evt / max(1, y.sum())
    lift  = gains / np.maximum(perc_pop, 1e-12)
    return perc_pop, gains, lift

def reliability_plot(y_true, y_proba, n_bins=10, ax=None, title="Reliability"):
    prob_true, prob_pred = calibration_curve(y_true, y_proba, n_bins=n_bins, strategy="quantile")
    if ax is None:
        plt.figure(); ax = plt.gca()
    ax.plot(prob_pred, prob_true, marker="o", label="Empírico")
    ax.plot([0,1],[0,1],"--", label="Perfecto")
    ax.set_xlabel("Score promedio por bin"); ax.set_ylabel("Tasa real por bin")
    ax.set_title(title); ax.legend() 
    

def expected_cost(y_true, y_score, thr, cost_fp=1.0, cost_fn=5.0):
    """Costo esperado = FP*cost_fp + FN*cost_fn."""
    y_true = np.asarray(y_true).astype(int)
    y_pred = (np.asarray(y_score) >= thr).astype(int)
    fp = np.sum((y_pred == 1) & (y_true == 0))
    fn = np.sum((y_pred == 0) & (y_true == 1))
    return fp * cost_fp + fn * cost_fn


def best_threshold_by_cost(y_true, y_proba,
                           cost_fp=1.0, cost_fn=5.0,
                           qgrid=None,
                           min_q=0.05, max_q=0.95):
    """
    Versión saneada: busca el umbral que minimiza costo
    SOLO en el rango central de las probabilidades.
    """
    y_true = np.asarray(y_true).astype(int)
    y_proba = np.asarray(y_proba)

    if qgrid is None:
        qgrid = np.linspace(min_q, max_q, 19)

    cand = np.unique(np.quantile(y_proba, qgrid))
    best_thr = 0.5
    best_cost = float("inf")
    best_stats = (0, 0, 0, 0)

    for t in cand:
        y_hat = (y_proba >= t).astype(int)
        tn, fp, fn, tp = confusion_matrix(y_true, y_hat, labels=[0,1]).ravel()
        cost = cost_fp*fp + cost_fn*fn
        if cost < best_cost:
            best_cost = cost
            best_thr = float(t)
            best_stats = (tn, fp, fn, tp)

    tn, fp, fn, tp = best_stats
    print(f"[COST] Best threshold={best_thr:.3f} | cost={best_cost:.2f} | tn={tn}, fp={fp}, fn={fn}, tp={tp}")
    return best_thr


def thresholds_by_group(y_true, y_proba, groups,
                        cost_fp=1.0, cost_fn=5.0,
                        min_support=3000):
    """
    Calcula umbral global y, si hay datos suficientes,
    umbral por grupo (canal).
    """
    y_true = np.asarray(y_true).astype(int)
    y_proba = np.asarray(y_proba)
    groups = np.asarray(groups).astype(str)

    thr_global = best_threshold_by_cost(
        y_true, y_proba,
        cost_fp=cost_fp, cost_fn=cost_fn,
        min_q=0.05, max_q=0.95
    )
    thr_map = {"_GLOBAL_": float(thr_global)}

    # por grupo
    for g in np.unique(groups):
        idx = (groups == g)
        if idx.sum() < min_support:
            continue
        thr_g = best_threshold_by_cost(
            y_true[idx], y_proba[idx],
            cost_fp=cost_fp, cost_fn=cost_fn,
            min_q=0.05, max_q=0.95
        )
        thr_map[g] = float(thr_g)

    return thr_map


def eval_at_thr_grouped(y_true, y_proba, groups, thr_map):
    """
    Mide P/R/NPV usando el umbral de cada grupo.
    Si el grupo no está en el mapa, usa el global.
    """
    y_true = np.asarray(y_true).astype(int)
    y_proba = np.asarray(y_proba)
    if groups is None:
        groups = np.array(["_GLOBAL_"] * len(y_true))
    else:
        groups = np.asarray(groups).astype(str)

    thr_global = thr_map.get("_GLOBAL_", 0.5)
    y_hat = np.zeros(len(y_true), dtype=int)
    for g in np.unique(groups):
        idx = (groups == g)
        thr_g = thr_map.get(g, thr_global)
        y_hat[idx] = (y_proba[idx] >= thr_g).astype(int)

    tn, fp, fn, tp = confusion_matrix(y_true, y_hat, labels=[0,1]).ravel()
    prec = tp / (tp+fp) if (tp+fp)>0 else 0.0
    rec  = tp / (tp+fn) if (tp+fn)>0 else 0.0
    npv  = tn / (tn+fn) if (tn+fn)>0 else 0.0

    return {
        "precision": prec,
        "recall": rec,
        "npv": npv,
        "tn": int(tn), "fp": int(fp),
        "fn": int(fn), "tp": int(tp)
    }
   
    
#def best_threshold_by_cost(y_true, y_proba, cost_fp=1.0, cost_fn=5.0):
  #  thrs = np.linspace(0,1,1001)
 #   best = (0.5, float("inf"), 0,0,0,0)
#    for t in thrs:
      #  y_hat = (y_proba >= t).astype(int)
     #   tn, fp, fn, tp = confusion_matrix(y_true, y_hat, labels=[0,1]).ravel()
    #    cost = cost_fp*fp + cost_fn*fn
   #     if cost < best[1]:
  #          best = (t, cost, tn, fp, fn, tp)
 #   print(f"[COST] Best threshold={best[0]:.3f} | cost={best[1]:.2f} | tn={best[2]}, fp={best[3]}, fn={best[4]}, tp={best[5]}")
#    return best[0]


def best_threshold_max_npv(y_true, y_proba, max_points=200):
    """
    Calcula el umbral que maximiza el NPV pero en O(N log N),
    no en O(N × #umbrales).

    y_true: array-like binario (0/1)
    y_proba: probabilidades del modelo
    max_points: cuántos puntos de corte evaluar como máximo
    """
    y_true = np.asarray(y_true).astype(int)
    y_proba = np.asarray(y_proba)

    n = y_true.shape[0]

    # 1) ordenamos de mayor proba a menor
    order = np.argsort(-y_proba)
    y_true_sorted = y_true[order]
    proba_sorted  = y_proba[order]

    # 2) acumulados hacia adelante (para la parte "positiva")
    cum_pos = np.cumsum(y_true_sorted)          # TP si corto aquí
    cum_all = np.arange(1, n+1)                 # predichos positivos si corto aquí

    # 3) acumulados hacia atrás (para la parte "negativa")
    #   suffix_pos[k] = cuántos 1's hay de k hasta el final
    suffix_pos = np.cumsum(y_true_sorted[::-1])[::-1]

    # 4) si corto en k → predichos positivos = k, predichos negativos = n-k
    #   FN = positivos en la cola = suffix_pos[k]
    #   TN = (n-k) - FN
    ks = np.linspace(0, n-1, num=min(max_points, n), dtype=int)

    best_npv = -1.0
    best_thr = 0.5  # default por si todo sale 0

    for k in ks:
        neg_count = n - k
        if neg_count == 0:
            continue  # no hay negativos predichos → NPV no aplica

        fn = suffix_pos[k]
        tn = neg_count - fn
        denom = tn + fn  # == neg_count
        npv = tn / denom if denom > 0 else 0.0

        if npv > best_npv:
            best_npv = npv
            # el umbral es la proba del último que metimos como positivo
            best_thr = proba_sorted[k]

    return best_thr, best_npv


def fairness_report(y_true, y_proba, groups: pd.Series, thr: float):
    y_hat = (y_proba >= thr).astype(int)
    rep = []
    groups_series = pd.Series(groups).astype("category")
    for g in groups_series.cat.categories:
        idx = np.where(groups_series == g)[0]
        if len(idx) < 50:  # evita ruido
            continue
        yt = y_true[idx]; yh = y_hat[idx]
        tn, fp, fn, tp = confusion_matrix(yt, yh, labels=[0,1]).ravel()
        tpr = tp/max(1, (tp+fn))
        fpr = fp/max(1, (fp+tn))
        rep.append({"group": g, "n": len(idx), "TPR": tpr, "FPR": fpr})
    return pd.DataFrame(rep).sort_values("n", ascending=False)

# %%
def fit_group_isotonic(df_train, score_col, y_col, group_col, min_support=2000):
    models = {}
    # Fallback global
    models["_GLOBAL_"] = IsotonicRegression(out_of_bounds="clip").fit(
        df_train[score_col].values, df_train[y_col].values
    )
    for g, d in df_train.groupby(group_col):
        if len(d) < min_support:
            continue
        ir = IsotonicRegression(out_of_bounds="clip").fit(
            d[score_col].values, d[y_col].values
        )
        models[g] = ir
    return models

def predict_group_isotonic(df, score_col, group_col, models):
    global_m = models["_GLOBAL_"]
    out = np.empty(len(df), dtype=float)
    for g, idx in df.groupby(group_col).groups.items():
        m = models.get(g, global_m)
        out[idx] = m.predict(df.loc[idx, score_col].values)
    return out

# %%
# Ejemplo: ajusta a tu realidad
COST_MAP = {
    "POS": (1, 2),            # (cost_fp, cost_fn) push barato
    "DIGITAL_ORGANIC": (2, 2),
    "SPIN_PREMIA": (6, 1),    # si es caro contactar / incentivar
    "ORGANIC": (2, 2),
}
GLOBAL_COST_FP, GLOBAL_COST_FN = 2, 2

# %%
def thresholds_by_group(df_val, score_col, y_col, group_col,
                        cost_map=None, global_cost_fp=1.0, global_cost_fn=5.0,
                        min_support=3000):
    """Devuelve dict de umbrales por grupo + '_GLOBAL_'."""
    y = df_val[y_col].values
    s = df_val[score_col].values
    # Umbral global como fallback
    t_global = best_threshold_by_cost(
        y, s, cost_fp=global_cost_fp, cost_fn=global_cost_fn,
        qgrid=np.linspace(0.05, 0.95, 19),
        min_thr=np.quantile(s, 0.05)
    )
    thr_map = {"_GLOBAL_": float(t_global)}

    for g, d in df_val.groupby(group_col):
        if len(d) < min_support:   # evita sobreajuste en grupos chicos
            continue
        cfp, cfn = (cost_map.get(g, (global_cost_fp, global_cost_fn))
                    if cost_map else (global_cost_fp, global_cost_fn))
        t_g = best_threshold_by_cost(
            d[y_col].values, d[score_col].values,
            cost_fp=cfp, cost_fn=cfn,
            qgrid=np.linspace(0.05, 0.95, 19),
            min_thr=np.quantile(d[score_col].values, 0.05)
        )
        thr_map[g] = float(t_g)
    return thr_map

def apply_group_threshold(df, score_col, group_col, thr_map):
    t_global = thr_map.get("_GLOBAL_", 0.5)
    thr_vec = df[group_col].map(thr_map).fillna(t_global).values
    return (df[score_col].values >= thr_vec).astype(int)

# %%
# === 2) Preprocesamiento para modelos sklearn (OHE) ===
from sklearn.utils.validation import check_is_fitted as _tmp

def split_num_cat(df: pd.DataFrame, feats):
    num_cols = [c for c in feats if pd.api.types.is_numeric_dtype(df[c]) and not pd.api.types.is_bool_dtype(df[c])]
    cat_cols = [c for c in feats if (pd.api.types.is_categorical_dtype(df[c]) or df[c].dtype == object)]
    return num_cols, cat_cols

def onehot_preprocessor(num_cols, cat_cols, scale_numeric=False, min_freq=0.01, dense_ohe=False):
    num_pipe = [("imputer", SimpleImputer(strategy="median"))]
    if scale_numeric:
        num_pipe.append(("scaler", StandardScaler()))
    num_pipe = Pipeline(num_pipe)

    # Compatibilidad scikit: sparse_output (>=1.2) / sparse (antiguas)
    if dense_ohe:
        try:
            ohe = OneHotEncoder(handle_unknown="ignore", min_frequency=min_freq, sparse_output=False)
        except TypeError:
            ohe = OneHotEncoder(handle_unknown="ignore", min_frequency=min_freq, sparse=False)
    else:
        ohe = OneHotEncoder(handle_unknown="ignore", min_frequency=min_freq)  # por defecto (sparse)

    cat_pipe = Pipeline([("imputer", SimpleImputer(strategy="most_frequent")), ("ohe", ohe)])

    pre = ColumnTransformer(
        transformers=[("num", num_pipe, num_cols), ("cat", cat_pipe, cat_cols)],
        remainder="drop",
        sparse_threshold=0.3  # no importa si OHE ya es denso
    )
    return pre

# %%
# === 3) Builders de modelos ===
def make_logreg(pre):
    return Pipeline([("pre", pre), ("clf", LogisticRegression(max_iter=2000, class_weight="balanced"))])

def make_rf(pre):
    return Pipeline([("pre", pre), ("clf", RandomForestClassifier(
        n_estimators=600, max_depth=None, min_samples_leaf=2,
        class_weight="balanced_subsample", n_jobs=-1, random_state=42))])

def make_histgb(pre):
    # Convierte a denso si viene sparse (solo para HistGB)
    to_dense = FunctionTransformer(lambda X: X.toarray() if hasattr(X, "toarray") else X,
                                   accept_sparse=True)
    return Pipeline([
        ("pre", pre),
        ("to_dense", to_dense),
        ("clf", HistGradientBoostingClassifier(
            max_depth=None,
            min_samples_leaf=100,
            max_leaf_nodes= 127,
            learning_rate=0.05,
            l2_regularization=5.0,
            early_stopping=True,
            random_state=42
        ))
    ])

def make_xgb_native():
    if not HAS_XGB: return None
    return xgb.XGBClassifier(
        n_estimators=600, max_depth=6, learning_rate=0.07,
        subsample=0.9, colsample_bytree=0.9,
        tree_method="hist", enable_categorical=True,
        reg_lambda=1.0, reg_alpha=0.0, random_state=42, n_jobs=-1
    )

def make_lgbm_native():
    if not HAS_LGBM: return None
    return lgb.LGBMClassifier(
        n_estimators=1200, learning_rate=0.05, num_leaves=63,
        subsample=0.9, colsample_bytree=0.9, reg_lambda=1.0,
        random_state=42, n_jobs=-1
    )

def make_cat_native():
    if not HAS_CAT: return None
    return CatBoostClassifier(
        depth=8, learning_rate=0.07, iterations=1200,
        loss_function="Logloss", eval_metric="AUC",
        l2_leaf_reg=3.0, random_seed=42,
        auto_class_weights="Balanced", verbose=False
    )

# %%
# === 4) Selector de X,y por horizonte (anti-fuga por k) ===
def get_xy_for_horizon(hname: str, label_col: str):
    # Asegura y_cum7 si no existe
    if "y_cum7" not in df_lab.columns and set(["y_w0","y_w1","y_w7"]).issubset(df_lab.columns):
        df_lab["y_cum7"] = ((df_lab["y_w0"] + df_lab["y_w1"] + df_lab["y_w7"])>0).astype(int)

    # Mapeo horizonte -> features k
    k_map = {
        "W0_discrete": 0,
        "W1_discrete": 0,   # as-of fin de D0
        "W7_discrete": 1,   # as-of fin de D1
        "W30_discrete": 7,  # as-of fin de D7
        "W7_cum": 0,
        "W30_cum": 0
    }
    k = k_map[hname]
    feat = {0: feat_k0, 1: feat_k1, 7: feat_k7}[k].copy()

    # Labels vienen embebidas en feat_* (por herencia de df_lab). Si no, merge por índice.
    if label_col not in feat.columns and label_col in df_lab.columns:
        feat[label_col] = df_lab[label_col]

    # Drop auxiliares y labels de X
    LEAKY_COLS = {"t_k","signup_ts","signup_local","signup_month_key"}
    LABELISH   = {"y_w0","y_w1","y_w7","y_w30","y_cum7","y_cum30"}
    
    feats = [c for c in feat.columns if c not in (LEAKY_COLS | LABELISH | ID_COLS)]
    feats = [c for c in feats if feat[c].notna().sum() > 0] 

 

    # Num/Cat
    num_cols, cat_cols = split_num_cat(feat, feats)

    # Forzar category en object para nativos
    for c in cat_cols:
        if feat[c].dtype == object:
            feat[c] = feat[c].astype("category")

    # Construye X e impide duplicados
    X = feat[feats + [TIME_COL]].copy()
    # Si por accidente feats traía TIME_COL, aquí nos aseguramos de dejarlo 1 sola vez
    X = X.loc[:, ~X.columns.duplicated()].copy()

    # Sanity check: que TIME_COL sea único y exista
    time_hits = (X.columns == TIME_COL).sum()
    assert time_hits == 1, f"TIME_COL '{TIME_COL}' aparece {time_hits} veces en X. Revisa duplicados."
    y = feat[label_col].astype(int).values
    return X, y, feats, num_cols, cat_cols, k

# %%
# === 5) Entrenamiento/Evaluación por horizonte ===
def train_eval_horizon(hname: str, label_col: str,
                       gap_before_days: int = 1, embargo_after_days: int = 30,
                       cost_fp: float = 5.0, cost_fn: float = 1.0,
                       calib_method: str = "isotonic"):
    print(f"\n=== Horizonte: {hname} | label={label_col} ===")
    X, y, feats, num_cols, cat_cols, k = get_xy_for_horizon(hname, label_col)

    # Preprocesador para modelos sklearn
    pre = onehot_preprocessor(num_cols, cat_cols, scale_numeric=False, min_freq=0.01)
    pre_sparse = onehot_preprocessor(num_cols, cat_cols, scale_numeric=False, min_freq=0.01, dense_ohe=False)
    pre_dense  = onehot_preprocessor(num_cols, cat_cols, scale_numeric=False, min_freq=0.01, dense_ohe=True)


    # Model zoo
    models = {
#        "LogReg": make_logreg(pre),
#        "RandomForest": make_rf(pre),
        "HistGB": make_histgb(pre_dense)
    }
#    if HAS_XGB: models["XGBoost"] = make_xgb_native()
#    if HAS_LGBM: models["LightGBM"] = make_lgbm_native()
#    if HAS_CAT: models["CatBoost"] = make_cat_native()

    # CV temporal (gap/embargo configurable)
    cv = PurgedTimeSeriesCV(n_splits=5, time_col=TIME_COL,
                            gap_before_days=gap_before_days,
                            embargo_after_days=embargo_after_days)


    results = {}
    for mname, model in models.items():
        if model is None:
            print(f"[{mname}] no disponible.")
            continue

        print(f"\n-- Modelo: {mname} --")
        oof_proba = np.zeros(len(X)); oof_mask = np.zeros(len(X), dtype=bool)
        use_native_cat = mname in ["XGBoost","LightGBM","CatBoost"]

        for fold, (tr_idx, va_idx) in enumerate(cv.split(X)):
            Xtr, Xva = X.iloc[tr_idx].copy(), X.iloc[va_idx].copy()
            ytr, yva = y[tr_idx], y[va_idx]

            if use_native_cat:
                # balanceo simple
                pos = max(1, ytr.sum()); neg = max(1, len(ytr)-pos)
                if mname == "XGBoost":
                    model.set_params(scale_pos_weight=neg/pos)
                    model.fit(Xtr[feats], ytr, eval_set=[(Xva[feats], yva)], verbose=False)
                    proba = model.predict_proba(Xva[feats])[:,1]
                elif mname == "LightGBM":
                    model.set_params(class_weight={0:1.0, 1:neg/pos})
                    model.fit(Xtr[feats], ytr,
                              eval_set=[(Xva[feats], yva)],
                              categorical_feature=[c for c in cat_cols if c in feats],
                              callbacks=[lgb.early_stopping(50, verbose=False)])
                    proba = model.predict_proba(Xva[feats])[:,1]
                elif mname == "CatBoost":
                    train_pool = Pool(Xtr[feats], label=ytr, cat_features=[c for c in cat_cols if c in feats])
                    valid_pool = Pool(Xva[feats], label=yva, cat_features=[c for c in cat_cols if c in feats])
                    model.fit(train_pool, eval_set=valid_pool, verbose=False)
                    proba = model.predict_proba(valid_pool)[:,1]
            else:
                model.fit(Xtr[feats], ytr)
                proba = model.predict_proba(Xva[feats])[:,1]

            oof_proba[va_idx] = proba
            oof_mask[va_idx] = True

            ap = auprc(yva, proba); auc = roc_auc_score(yva, proba)
            print(f"   Fold {fold+1}: AUC-PR={ap:.4f} | AUC-ROC={auc:.4f}")

        y_true = y[oof_mask]; y_prob = oof_proba[oof_mask]
        ap = auprc(y_true, y_prob); auc = roc_auc_score(y_true, y_prob)
        print(f"[{mname}] OOF: AUC-PR={ap:.4f} | AUC-ROC={auc:.4f}")

        # Calibración rápida (global)
        try:
            if use_native_cat:
                cal = CalibratedClassifierCV(model, cv=3, method=calib_method)
                cal.fit(X[feats], y)
                y_prob_cal = cal.predict_proba(X[feats])[:,1]
                brier = brier_score_loss(y, y_prob_cal)
                print(f"[{mname}] Brier (calibrado): {brier:.4f}")
            else:
                cal = CalibratedClassifierCV(model, cv=3, method=calib_method)
                cal.fit(X[feats], y)
                y_prob_cal = cal.predict_proba(X[feats])[:,1]
                brier = brier_score_loss(y, y_prob_cal)
                print(f"[{mname}] Brier (calibrado): {brier:.4f}")
        except Exception as e:
            print(f"[{mname}] Calibración saltada ({e}).")
            y_prob_cal = y_prob
        #
        iso = IsotonicRegression(out_of_bounds="clip")
        iso.fit(y_prob, y_true)
        y_prob_cal = iso.predict(y_prob)
        brier = brier_score_loss(y_true, y_prob_cal)
        print(f"[{mname}] Brier (isotonic OOF): {brier:.4f}")

        # a partir de aquí TODO usa y_prob_cal, no y_prob
        thr_cost = best_threshold_by_cost(
            y_true, y_prob_cal,
            cost_fp=cost_fp, cost_fn=cost_fn
        )
        thr_npv, npv_val = best_threshold_max_npv(y_true, y_prob, max_points=200)
        res = {
        "horizon": hname,
        "label_col": label_col,
        "gap_before_days": gap_before_days,
        "embargo_after_days": embargo_after_days,
        # puedes tener aquí tus métricas base (auc, pr, etc.) si ya las calculas arriba
    }
            # 4) guardas los thresholds
        res["thr_cost"] = float(thr_cost)
        res["thr_npv"] = float(thr_npv)
        res["npv_at_thr_npv"] = float(npv_val)
        

        # Umbrales
        thr_cost = best_threshold_by_cost(y_true, y_prob, cost_fp=cost_fp, cost_fn=cost_fn)
        thr_npv, npv_val = best_threshold_max_npv(y_true, y_prob, max_points=200)
        return res


        
        def eval_at_thr(y_true, y_prob, thr):
            y_hat = (y_prob >= thr).astype(int)
            tn, fp, fn, tp = confusion_matrix(y_true, y_hat, labels=[0,1]).ravel()
            prec = precision_score(y_true, y_hat, zero_division=0)
            rec  = recall_score(y_true, y_hat, zero_division=0)
            npv  = tn/(tn+fn) if (tn+fn)>0 else 0.0
            return {
                "precision":prec, "recall":rec, "npv":npv,
                "tn":tn, "fp":fp, "fn":fn, "tp":tp
            }

        eval_cost = eval_at_thr(y_true, y_prob_cal, thr_cost)
        eval_npv  = eval_at_thr(y_true, y_prob_cal, thr_npv)

        print(f"[{mname}] @thr_cost -> P={eval_cost['precision']:.3f} | R={eval_cost['recall']:.3f} | NPV={eval_cost['npv']:.3f}")
        print(f"[{mname}] @thr_npv  -> P={eval_npv['precision']:.3f} | R={eval_npv['recall']:.3f} | NPV={eval_npv['npv']:.3f}")

        # Visuales clave
        fig, axs = plt.subplots(2, 2, figsize=(12,10))

        # PR
        precs, recalls, _ = precision_recall_curve(y_true, y_prob)
        axs[0,0].plot(recalls, precs); axs[0,0].set_title(f"{mname} - PR (AP={ap:.3f})")
        axs[0,0].set_xlabel("Recall"); axs[0,0].set_ylabel("Precision")

        # ROC
        fpr, tpr, _ = roc_curve(y_true, y_prob)
        axs[0,1].plot(fpr, tpr); axs[0,1].plot([0,1],[0,1],'--')
        axs[0,1].set_title(f"{mname} - ROC (AUC={auc:.3f})")
        axs[0,1].set_xlabel("FPR"); axs[0,1].set_ylabel("TPR")

        # Confusión @thr_cost
        y_hat_cost = (y_prob >= thr_cost).astype(int)
        cm = confusion_matrix(y_true, y_hat_cost, normalize='true')
        im = axs[1,0].imshow(cm, cmap="Blues")
        axs[1,0].set_title(f"{mname} - Confusion @thr_cost")
        axs[1,0].set_xticks([0,1]); axs[1,0].set_xticklabels(["0","1"])
        axs[1,0].set_yticks([0,1]); axs[1,0].set_yticklabels(["0","1"])
        for (i,j), v in np.ndenumerate(cm):
            axs[1,0].text(j, i, f"{v:.2f}", ha="center", va="center")

        # Reliability
        reliability_plot(y_true, y_prob, n_bins=10, ax=axs[1,1], title=f"{mname} - Reliability")
        plt.tight_layout(); plt.show()

        # Gains / Lift para clase 0 (Nudge)
        ppop, gains, lift = gains_curve(y_true, y_prob, target_class=0)
        plt.figure(figsize=(6,4)); plt.plot(ppop, gains); plt.title(f"{mname} - Gains (clase 0)")
        plt.xlabel("% población"); plt.ylabel("% capturado clase 0"); plt.show()
        plt.figure(figsize=(6,4)); plt.plot(ppop, lift); plt.title(f"{mname} - Lift (clase 0)")
        plt.xlabel("% población"); plt.ylabel("Lift"); plt.show()

        # Fairness rápido por columnas sensibles (si existen en X original)
        SENSITIVE_COLS = [c for c in ["gender","stateName","channelDetail"] if c in X.columns]
        fairness_tables = {}
        for gcol in SENSITIVE_COLS:
            df_fair = fairness_report(
                y_true, y_prob_cal,
                groups=X.loc[X.index[oof_mask], gcol],
                thr=thr_cost
            )
            if not df_fair.empty:
                print(f"\n[{mname}] Fairness @thr_cost por {gcol} (top grupos):")
                display(df_fair.head(10))
            fairness_tables[gcol] = df_fair

        results[mname] = {
            "model": model,
            "oof_ap": ap, "oof_auc": auc,
            "thr_cost": thr_cost,
#            "thr_cost_map": thr_cost_map,
            "thr_npv": thr_npv,
            "eval_cost": eval_cost,
            "eval_npv": eval_npv,
            "fairness": fairness_tables
        }

    return results

# %%
# === 6) Ejecuta por horizontes y resume ===
# Si no existe el contenedor global, créalo
if "ALL_RESULTS" not in globals():
    ALL_RESULTS = {}

# Definimos los 4 horizontes que estás usando
HORIZONS = [
    ("W0_discrete", "y_w0", 0, 1),   # primeras horas
    ("W1_discrete", "y_w1", 0, 1),   # resto del día 1
    ("W7_discrete", "y_w7", 1, 7),   # hasta 7 días
    ("W30_discrete", "y_w30", 7, 30) # hasta 30 días
]

for hname, lcol, gap_days, embargo_days in HORIZONS:
    if hname in ALL_RESULTS and "HistGB" in ALL_RESULTS[hname] and "model" in ALL_RESULTS[hname]["HistGB"]:
        continue

    # 1) entrena y evalúa con tu función del notebook
    res = train_eval_horizon(
        hname,
        lcol,
        gap_before_days=gap_days,
        embargo_after_days=embargo_days,
        cost_fp=2.0,
        cost_fn=2.0,
        calib_method="isotonic"
    )
    # 2) re-entrena un modelo "full data" para producción y guárdalo
    X, y, feats, num_cols, cat_cols, k = get_xy_for_horizon(hname, lcol)  # :contentReference[oaicite:2]{index=2}
    pre_dense = onehot_preprocessor(num_cols, cat_cols, scale_numeric=False, min_freq=0.01, dense_ohe=True)
    full_model = make_histgb(pre_dense)
    full_model.fit(X[feats], y)

    # 3) cuélgalo en el resultado
    if "HistGB" not in res:
        res["HistGB"] = {}
    res["HistGB"]["model"] = full_model

    ALL_RESULTS[hname] = res

    
#Helper para sacar las probas OOF/producción


def get_oof_scores(hname, label_col):
    # recupera exactamente el mismo X que usaste al entrenar
    X, y, feats, num_cols, cat_cols, k = get_xy_for_horizon(hname, label_col)
    # toma el modelo que acabamos de colgar
    model = ALL_RESULTS[hname]["HistGB"]["model"]
    proba = model.predict_proba(X[feats])[:, 1]
    return X.index, proba


# Scores por horizonte

idx_w0, p_w0   = get_oof_scores("W0_discrete",  "y_w0")
idx_w1, p_w1   = get_oof_scores("W1_discrete",  "y_w1")
idx_w7, p_w7   = get_oof_scores("W7_discrete",  "y_w7")
idx_w30, p_w30 = get_oof_scores("W30_discrete", "y_w30")

# base de usuarios: la misma que tus labels
df_scores = df_lab[["user_id", "signup_date", "channelDetail"]].copy()

df_scores.loc[idx_w0,  "p_w0"]  = p_w0
df_scores.loc[idx_w1,  "p_w1"]  = p_w1
df_scores.loc[idx_w7,  "p_w7"]  = p_w7
df_scores.loc[idx_w30, "p_w30"] = p_w30

#Derivar scores día / semana / mes
# día = ventanas en las primeras 24h (W0 + W1)
df_scores["score_dia"] = (
    df_scores["p_w0"].fillna(0.0) +
    df_scores["p_w1"].fillna(0.0)
).clip(0, 1)

# semana = lo anterior + lo que puede caer entre 24h y 7d
df_scores["score_semana"] = (
    df_scores["score_dia"] +
    df_scores["p_w7"].fillna(0.0)
).clip(0, 1)

# mes = todo lo de arriba + 7d..30d
df_scores["score_mes"] = (
    df_scores["score_semana"] +
    df_scores["p_w30"].fillna(0.0)
).clip(0, 1)

#Segmentación de probabilidad de conocer su primera transacción
def bucket_prob(p):
    if p >= 0.70:
        return " alta"
    elif p >= 0.40:
        return " media"
    else:
        return " baja"

df_scores["prob_first_tx_dia"]    = df_scores["score_dia"]
df_scores["prob_first_tx_semana"] = df_scores["score_semana"]
df_scores["prob_first_tx_mes"]    = df_scores["score_mes"]

df_scores["seg_first_tx_dia"]    = df_scores["prob_first_tx_dia"].apply(bucket_prob)
df_scores["seg_first_tx_semana"] = df_scores["prob_first_tx_semana"].apply(bucket_prob)
df_scores["seg_first_tx_mes"]    = df_scores["prob_first_tx_mes"].apply(bucket_prob)

# Canal de transacción más viable por ventana
# el dataset original sí traía info de la primera tx pero la sacaste de X para evitar leakage
TX_COL = "first_tx_type" if "first_tx_type" in df_lab.columns else (
    "activation_channel" if "activation_channel" in df_lab.columns else None
)

canal_dia = None
canal_semana = None
canal_mes = None

if TX_COL is not None:
    # quién SÍ activó en cada ventana
    m_dia = (df_lab["y_w0"] == 1) | (df_lab["y_w1"] == 1)
    m_sem = m_dia | (df_lab["y_w7"] == 1)
    m_mes = m_sem | (df_lab["y_w30"] == 1)

    # modo por canal de origen
    canal_dia = (
        df_lab.loc[m_dia]
        .groupby("channelDetail")[TX_COL]
        .agg(lambda s: s.value_counts().index[0] if s.notna().any() else None)
        .rename("canal_tx_mas_viable_dia")
    )

    canal_semana = (
        df_lab.loc[m_sem]
        .groupby("channelDetail")[TX_COL]
        .agg(lambda s: s.value_counts().index[0] if s.notna().any() else None)
        .rename("canal_tx_mas_viable_semana")
    )

    canal_mes = (
        df_lab.loc[m_mes]
        .groupby("channelDetail")[TX_COL]
        .agg(lambda s: s.value_counts().index[0] if s.notna().any() else None)
        .rename("canal_tx_mas_viable_mes")
    )

    df_scores = (
        df_scores
        .merge(canal_dia,    on="channelDetail", how="left")
        .merge(canal_semana, on="channelDetail", how="left")
        .merge(canal_mes,    on="channelDetail", how="left")
    )

# df_scores ahora trae TODO lo que pediste
df_scores.head()


def summarize_results(allres):
    rows = []

    for hname, d in allres.items():
        # 1) a veces guardaste un string tipo "Models fail"
        if not isinstance(d, dict):
            print(f"[WARN] {hname}: no es dict ({type(d)}). Lo salto.")
            continue

        for m, r in d.items():
            # 2) a veces el valor del modelo tampoco es dict
            if not isinstance(r, dict):
                print(f"[WARN] {hname}/{m}: valor no dict -> {r}. Lo salto.")
                continue

            # 3) checa que tenga las llaves mínimas
            oof_ap  = r.get("oof_ap")
            oof_auc = r.get("oof_auc")
            thr_cost = r.get("thr_cost")
            thr_npv  = r.get("thr_npv")

            eval_cost = r.get("eval_cost") or {}
            eval_npv  = r.get("eval_npv") or {}

            # si no tiene métrica base, no lo metas
            if oof_ap is None or oof_auc is None:
                print(f"[WARN] {hname}/{m}: sin métricas OOF. Lo salto.")
                continue

            rows.append({
                "horizon":  hname,
                "model":    m,
                "AUC-PR":   oof_ap,
                "AUC-ROC":  oof_auc,
                "thr_cost": thr_cost,
                "thr_npv":  thr_npv,
                "NPV@cost": eval_cost.get("npv"),
                "Prec@cost": eval_cost.get("precision"),
                "Rec@cost":  eval_cost.get("recall"),
                "NPV@npv":  eval_npv.get("npv"),
                "Prec@npv": eval_npv.get("precision"),
                "Rec@npv":  eval_npv.get("recall"),
            })

    if not rows:
        print("[WARN] summarize_results: no hay filas válidas.")
        return pd.DataFrame()

    return (
        pd.DataFrame(rows)
        .sort_values(["horizon", "AUC-PR"], ascending=[True, False])
        .reset_index(drop=True)
    )

summary_df = summarize_results(ALL_RESULTS)
display(summary_df)
# Out:
# === Horizonte: W0_discrete | label=y_w0 ===
#
# -- Modelo: HistGB --
#    Fold 1: AUC-PR=0.4423 | AUC-ROC=0.6869
#    Fold 2: AUC-PR=0.4431 | AUC-ROC=0.6849
#    Fold 3: AUC-PR=0.4373 | AUC-ROC=0.6843
#    Fold 4: AUC-PR=0.4390 | AUC-ROC=0.6799
# [HistGB] OOF: AUC-PR=0.4402 | AUC-ROC=0.6839
# [HistGB] Brier (calibrado): 0.1875
# [HistGB] Brier (isotonic OOF): 0.1880
# [COST] Best threshold=0.488 | cost=1107544.00 | tn=1333297, fp=47267, fn=506505, tp=53966
# [COST] Best threshold=0.483 | cost=1107534.00 | tn=1335390, fp=45174, fn=508593, tp=51878
#
# === Horizonte: W1_discrete | label=y_w1 ===
#
# -- Modelo: HistGB --
#    Fold 1: AUC-PR=0.1446 | AUC-ROC=0.6756
#    Fold 2: AUC-PR=0.1500 | AUC-ROC=0.6785
#    Fold 3: AUC-PR=0.1508 | AUC-ROC=0.6809
#    Fold 4: AUC-PR=0.1534 | AUC-ROC=0.6863
# [HistGB] OOF: AUC-PR=0.1496 | AUC-ROC=0.6803
# [HistGB] Brier (calibrado): 0.0752
# [HistGB] Brier (isotonic OOF): 0.0747
# [COST] Best threshold=0.173 | cost=461680.00 | tn=1689306, fp=88284, fn=142556, tp=20889
# [COST] Best threshold=0.175 | cost=445998.00 | tn=1699287, fp=78303, fn=144696, tp=18749
#
# === Horizonte: W7_discrete | label=y_w7 ===
#
# -- Modelo: HistGB --
#    Fold 1: AUC-PR=0.2542 | AUC-ROC=0.6890
#    Fold 2: AUC-PR=0.2606 | AUC-ROC=0.6893
#    Fold 3: AUC-PR=0.2647 | AUC-ROC=0.6920
#    Fold 4: AUC-PR=0.2607 | AUC-ROC=0.7001
# [HistGB] OOF: AUC-PR=0.2597 | AUC-ROC=0.6925
# [HistGB] Brier (calibrado): 0.1117
# [HistGB] Brier (isotonic OOF): 0.1113
# [COST] Best threshold=0.320 | cost=588098.00 | tn=1610294, fp=64512, fn=229537, tp=36692
# [COST] Best threshold=0.314 | cost=585306.00 | tn=1613068, fp=61738, fn=230915, tp=35314
#
# === Horizonte: W30_discrete | label=y_w30 ===
#
# -- Modelo: HistGB --
#    Fold 1: AUC-PR=0.1837 | AUC-ROC=0.6691
#    Fold 2: AUC-PR=0.1888 | AUC-ROC=0.6745
#    Fold 3: AUC-PR=0.2056 | AUC-ROC=0.6769
#    Fold 4: AUC-PR=0.1989 | AUC-ROC=0.6873
# [HistGB] OOF: AUC-PR=0.1962 | AUC-ROC=0.6791
# [HistGB] Brier (calibrado): 0.0837
# [HistGB] Brier (isotonic OOF): 0.0826
# [COST] Best threshold=0.243 | cost=459570.00 | tn=1681313, fp=74087, fn=155698, tp=29937
# [COST] Best threshold=0.221 | cost=452514.00 | tn=1686563, fp=68837, fn=157420, tp=28215
# [WARN] W0_discrete/horizon: valor no dict -> W0_discrete. Lo salto.
# [WARN] W0_discrete/label_col: valor no dict -> y_w0. Lo salto.
# [WARN] W0_discrete/gap_before_days: valor no dict -> 0. Lo salto.
# [WARN] W0_discrete/embargo_after_days: valor no dict -> 1. Lo salto.
# [WARN] W0_discrete/thr_cost: valor no dict -> 0.48822791864028975. Lo salto.
# [WARN] W0_discrete/thr_npv: valor no dict -> 0.0410129784986729. Lo salto.
# [WARN] W0_discrete/npv_at_thr_npv: valor no dict -> 1.0. Lo salto.
# [WARN] W0_discrete/HistGB: sin métricas OOF. Lo salto.
# [WARN] W1_discrete/horizon: valor no dict -> W1_discrete. Lo salto.
# [WARN] W1_discrete/label_col: valor no dict -> y_w1. Lo salto.
# [WARN] W1_discrete/gap_before_days: valor no dict -> 0. Lo salto.
# [WARN] W1_discrete/embargo_after_days: valor no dict -> 1. Lo salto.
# [WARN] W1_discrete/thr_cost: valor no dict -> 0.1730072849657053. Lo salto.
# [WARN] W1_discrete/thr_npv: valor no dict -> 0.00686721229501424. Lo salto.
# [WARN] W1_discrete/npv_at_thr_npv: valor no dict -> 1.0. Lo salto.
# [WARN] W1_discrete/HistGB: sin métricas OOF. Lo salto.
# [WARN] W7_discrete/horizon: valor no dict -> W7_discrete. Lo salto.
# [WARN] W7_discrete/label_col: valor no dict -> y_w7. Lo salto.
# [WARN] W7_discrete/gap_before_days: valor no dict -> 1. Lo salto.
# [WARN] W7_discrete/embargo_after_days: valor no dict -> 7. Lo salto.
# [WARN] W7_discrete/thr_cost: valor no dict -> 0.3200204377075704. Lo salto.
# [WARN] W7_discrete/thr_npv: valor no dict -> 0.014443638061825331. Lo salto.
# [WARN] W7_discrete/npv_at_thr_npv: valor no dict -> 1.0. Lo salto.
# [WARN] W7_discrete/HistGB: sin métricas OOF. Lo salto.
# [WARN] W30_discrete/horizon: valor no dict -> W30_discrete. Lo salto.
# [WARN] W30_discrete/label_col: valor no dict -> y_w30. Lo salto.
# [WARN] W30_discrete/gap_before_days: valor no dict -> 7. Lo salto.
# [WARN] W30_discrete/embargo_after_days: valor no dict -> 30. Lo salto.
# [WARN] W30_discrete/thr_cost: valor no dict -> 0.24321043165467626. Lo salto.
# [WARN] W30_discrete/thr_npv: valor no dict -> 0.010497664002179287. Lo salto.
# [WARN] W30_discrete/npv_at_thr_npv: valor no dict -> 1.0. Lo salto.
# [WARN] W30_discrete/HistGB: sin métricas OOF. Lo salto.
# [WARN] summarize_results: no hay filas válidas.
# Empty DataFrame
# Columns: []
# Index: []

# %%
df_scores
# Out:
#                                       user_id signup_date channelDetail  \
# 0        cf810547-aca0-452e-be9a-1d817cea671c  2025-06-12           POS
# 1        cf81de8a-b635-449f-8d80-2a72977bad9c  2025-01-27           POS
# 2        cf832492-786d-4f4a-b1f5-1cfee36be497  2025-07-17           POS
# 3        cf844863-f2c1-427b-ab95-a167071c7dfe  2025-05-01       ORGANIC
# 4        cf8667c9-d304-40ea-ae26-d5ff8cc1faf7  2025-05-22           POS
# ...                                       ...         ...           ...
# 2426350  92c49483-6016-4169-bee6-8a64074fd926  2025-02-17           POS
# 2426351  92dc0ff4-ae72-4128-956b-b87d26893393  2025-05-02       ORGANIC
# 2426352  93267888-572e-475e-bcc3-d07da346610c  2025-03-03       ORGANIC
# 2426353  9399baa9-ecc8-434b-b595-85e08235e14a  2025-03-09           POS
# 2426354  93b4f8b8-2fcc-4fa4-9a25-451acfa29dca  2025-06-06           POS
#
#              p_w0      p_w1      p_w7     p_w30  score_dia  score_semana  \
# 0        0.368678  0.126937  0.176063  0.055357   0.495616      0.671678
# 1        0.318173  0.042999  0.081340  0.069208   0.361173      0.442512
# 2        0.329458  0.106061  0.122914  0.074262   0.435519      0.558434
# 3        0.447475  0.094372  0.145400  0.103024   0.541847      0.687247
# 4        0.172364  0.032725  0.113367  0.274490   0.205090      0.318457
# ...           ...       ...       ...       ...        ...           ...
# 2426350  0.381619  0.153159  0.147413  0.076310   0.534778      0.682191
# 2426351  0.320962  0.055165  0.094393  0.090369   0.376127      0.470519
# 2426352  0.419027  0.134136  0.183217  0.129339   0.553163      0.736381
# 2426353  0.364135  0.191115  0.202323  0.099797   0.555250      0.757573
# 2426354  0.422059  0.115848  0.184687  0.121573   0.537907      0.722594
#
#          score_mes  prob_first_tx_dia  prob_first_tx_semana  \
# 0         0.727035           0.495616              0.671678
# 1         0.511720           0.361173              0.442512
# 2         0.632696           0.435519              0.558434
# 3         0.790271           0.541847              0.687247
# 4         0.592947           0.205090              0.318457
# ...            ...                ...                   ...
# 2426350   0.758501           0.534778              0.682191
# 2426351   0.560888           0.376127              0.470519
# 2426352   0.865719           0.553163              0.736381
# 2426353   0.857370           0.555250              0.757573
# 2426354   0.844167           0.537907              0.722594
#
#          prob_first_tx_mes seg_first_tx_dia seg_first_tx_semana  \
# 0                 0.727035            media               media
# 1                 0.511720             baja               media
# 2                 0.632696            media               media
# 3                 0.790271            media               media
# 4                 0.592947             baja                baja
# ...                    ...              ...                 ...
# 2426350           0.758501            media               media
# 2426351           0.560888             baja               media
# 2426352           0.865719            media                alta
# 2426353           0.857370            media                alta
# 2426354           0.844167            media                alta
#
#         seg_first_tx_mes canal_tx_mas_viable_dia canal_tx_mas_viable_semana  \
# 0                   alta         CASH_IN_AT_OXXO            CASH_IN_AT_OXXO
# 1                  media         CASH_IN_AT_OXXO            CASH_IN_AT_OXXO
# 2                  media         CASH_IN_AT_OXXO            CASH_IN_AT_OXXO
# 3                   alta            SPEI_CASH_IN               SPEI_CASH_IN
# 4                  media         CASH_IN_AT_OXXO            CASH_IN_AT_OXXO
# ...                  ...                     ...                        ...
# 2426350             alta         CASH_IN_AT_OXXO            CASH_IN_AT_OXXO
# 2426351            media            SPEI_CASH_IN               SPEI_CASH_IN
# 2426352             alta            SPEI_CASH_IN               SPEI_CASH_IN
# 2426353             alta         CASH_IN_AT_OXXO            CASH_IN_AT_OXXO
# 2426354             alta         CASH_IN_AT_OXXO            CASH_IN_AT_OXXO
#
#         canal_tx_mas_viable_mes
# 0               CASH_IN_AT_OXXO
# 1               CASH_IN_AT_OXXO
# 2               CASH_IN_AT_OXXO
# 3                  SPEI_CASH_IN
# 4               CASH_IN_AT_OXXO
# ...                         ...
# 2426350         CASH_IN_AT_OXXO
# 2426351            SPEI_CASH_IN
# 2426352            SPEI_CASH_IN
# 2426353         CASH_IN_AT_OXXO
# 2426354         CASH_IN_AT_OXXO
#
# [2426355 rows x 19 columns]

# %%
summary_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # model optimization

# %%
try:
    import optuna
    print("✓ Optuna ya está instalado")
except ImportError:
    print("Instalando Optuna...")
    # !pip install optuna --quiet
    import optuna
    print("✓ Optuna instalado exitosamente")
# Out:
# ✓ Optuna ya está instalado

# %%
import warnings
warnings.filterwarnings('ignore', category=optuna.exceptions.ExperimentalWarning)

# %%
def compute_metrics_at_threshold(y_true, y_proba, threshold, cost_fp=2.0, cost_fn=2.0):
    """
    Calcula precision, recall, f1 y costo para un threshold dado.
    """
    y_pred = (y_proba >= threshold).astype(int)
    
    # Confusion matrix manual
    tp = np.sum((y_pred == 1) & (y_true == 1))
    fp = np.sum((y_pred == 1) & (y_true == 0))
    fn = np.sum((y_pred == 0) & (y_true == 1))
    tn = np.sum((y_pred == 0) & (y_true == 0))
    
    # Métricas
    precision = tp / (tp + fp) if (tp + fp) > 0 else 0.0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0.0
    f1 = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0.0
    
    # Costo
    cost = fp * cost_fp + fn * cost_fn
    
    return {
        'precision': precision,
        'recall': recall,
        'f1': f1,
        'cost': cost,
        'tp': int(tp), 'fp': int(fp), 'fn': int(fn), 'tn': int(tn)
    }

print("✓ Funciones auxiliares cargadas")
# Out:
# ✓ Funciones auxiliares cargadas

# %%
def objective_threshold(trial, y_true, y_proba, cost_fp, cost_fn, optimize_metric='cost'):
    """
    Función objetivo para optimizar threshold.
    
    optimize_metric: 'cost' (minimizar) o 'f1' (maximizar)
    """
    # Sugerir threshold entre 0.01 y 0.99
    threshold = trial.suggest_float('threshold', 0.01, 0.99)
    
    # Calcular métricas
    metrics = compute_metrics_at_threshold(y_true, y_proba, threshold, cost_fp, cost_fn)
    
    # Registrar métricas adicionales en el trial
    trial.set_user_attr('precision', metrics['precision'])
    trial.set_user_attr('recall', metrics['recall'])
    trial.set_user_attr('f1', metrics['f1'])
    trial.set_user_attr('cost', metrics['cost'])
    
    # Retornar la métrica a optimizar
    if optimize_metric == 'cost':
        return metrics['cost']  # Optuna minimizará
    else:  # 'f1'
        return metrics['f1']  # Optuna maximizará


# Iterar sobre cada horizonte
for hname, lcol, gap_days, embargo_days in HORIZONS:
    print(f"\n--- Optimizando threshold para {hname} ---")
    
    # Obtener predicciones OOF y labels
    X, y, feats, num_cols, cat_cols, k = get_xy_for_horizon(hname, lcol)
    
    # Verificar que el modelo existe
    if hname not in ALL_RESULTS or "HistGB" not in ALL_RESULTS[hname]:
        print(f"  ⚠️  No hay resultados para {hname}, saltando...")
        continue
    
    # Obtener predicciones del modelo full data (como proxy de OOF)
    # En tu código original, las predicciones OOF se generan en train_eval_horizon
    # Aquí usamos el modelo full data que ya entrenaste
    model = ALL_RESULTS[hname]["HistGB"]["model"]
    y_proba = model.predict_proba(X[feats])[:, 1]
    
    # Crear study de Optuna para minimizar costo
    study = optuna.create_study(
        study_name=f"threshold_{hname}",
        direction='minimize',  # Minimizar costo
        sampler=optuna.samplers.TPESampler(seed=42)
    )
    
    # Optimizar (100 trials para threshold es suficiente)
    study.optimize(
        lambda trial: objective_threshold(trial, y, y_proba, 
                                         cost_fp=2.0, cost_fn=2.0, 
                                         optimize_metric='cost'),
        n_trials=100,
        show_progress_bar=False
    )
    
    # Obtener mejores resultados
    best_trial = study.best_trial
    best_threshold = best_trial.params['threshold']
    best_metrics = compute_metrics_at_threshold(y, y_proba, best_threshold, 2.0, 2.0)
    
    # Guardar en estructura global
    BEST_THRESHOLDS[hname] = {
        'threshold': best_threshold,
        'precision': best_metrics['precision'],
        'recall': best_metrics['recall'],
        'f1': best_metrics['f1'],
        'cost': best_metrics['cost'],
        'confusion': {
            'tp': best_metrics['tp'],
            'fp': best_metrics['fp'],
            'fn': best_metrics['fn'],
            'tn': best_metrics['tn']
        }
    }
    
    # Imprimir resultados
    print(f"  ✓ Mejor threshold: {best_threshold:.4f}")
    print(f"    - Precision: {best_metrics['precision']:.4f}")
    print(f"    - Recall:    {best_metrics['recall']:.4f}")
    print(f"    - F1:        {best_metrics['f1']:.4f}")
    print(f"    - Costo:     {best_metrics['cost']:.2f}")
    print(f"    - Confusion: TP={best_metrics['tp']}, FP={best_metrics['fp']}, "
          f"FN={best_metrics['fn']}, TN={best_metrics['tn']}")

print("\n" + "="*80)
print("RESUMEN DE MEJORES THRESHOLDS POR HORIZONTE")
print("="*80)
for hname, info in BEST_THRESHOLDS.items():
    print(f"{hname:15s} | Thr={info['threshold']:.4f} | "
          f"P={info['precision']:.3f} | R={info['recall']:.3f} | "
          f"F1={info['f1']:.3f} | Cost={info['cost']:.0f}")
# Out:
# --- Optimizando threshold para W0_discrete ---
# [I 2025-11-02 04:27:31,434] A new study created in memory with name: threshold_W0_discrete
# [I 2025-11-02 04:27:31,470] Trial 0 finished with value: 1569732.0 and parameters: {'threshold': 0.37704931647041523}. Best is trial 0 with value: 1569732.0.
# [I 2025-11-02 04:27:31,503] Trial 1 finished with value: 1403686.0 and parameters: {'threshold': 0.9417000202817178}. Best is trial 1 with value: 1403686.0.
# [I 2025-11-02 04:27:31,536] Trial 2 finished with value: 1402372.0 and parameters: {'threshold': 0.727354062975177}. Best is trial 2 with value: 1402372.0.
# [I 2025-11-02 04:27:31,568] Trial 3 finished with value: 1397322.0 and parameters: {'threshold': 0.5966853145130959}. Best is trial 3 with value: 1397322.0.
# [I 2025-11-02 04:27:31,601] Trial 4 finished with value: 2634846.0 and parameters: {'threshold': 0.1628982676335878}. Best is trial 3 with value: 1397322.0.
# [I 2025-11-02 04:27:31,634] Trial 5 finished with value: 2635052.0 and parameters: {'threshold': 0.1628746299294786}. Best is trial 3 with value: 1397322.0.
# [I 2025-11-02 04:27:31,666] Trial 6 finished with value: 3415172.0 and parameters: {'threshold': 0.06692193992483547}. Best is trial 3 with value: 1397322.0.
# [I 2025-11-02 04:27:31,697] Trial 7 finished with value: 1403686.0 and parameters: {'threshold': 0.8588526228594364}. Best is trial 3 with value: 1397322.0.
# [I 2025-11-02 04:27:31,729] Trial 8 finished with value: 1397682.0 and parameters: {'threshold': 0.5990927115083446}. Best is trial 3 with value: 1397322.0.
# [I 2025-11-02 04:27:31,760] Trial 9 finished with value: 1401838.0 and parameters: {'threshold': 0.7039111262401245}. Best is trial 3 with value: 1397322.0.
# [I 2025-11-02 04:27:31,797] Trial 10 finished with value: 1424642.0 and parameters: {'threshold': 0.4263533010733973}. Best is trial 3 with value: 1397322.0.
# [I 2025-11-02 04:27:31,831] Trial 11 finished with value: 1394718.0 and parameters: {'threshold': 0.579007446359683}. Best is trial 11 with value: 1394718.0.
# [I 2025-11-02 04:27:31,865] Trial 12 finished with value: 1385402.0 and parameters: {'threshold': 0.5251111192486895}. Best is trial 12 with value: 1385402.0.
# [I 2025-11-02 04:27:31,899] Trial 13 finished with value: 1670196.0 and parameters: {'threshold': 0.34961626754595676}. Best is trial 12 with value: 1385402.0.
# [I 2025-11-02 04:27:31,933] Trial 14 finished with value: 1385036.0 and parameters: {'threshold': 0.5232388213650043}. Best is trial 14 with value: 1385036.0.
# [I 2025-11-02 04:27:31,967] Trial 15 finished with value: 1820228.0 and parameters: {'threshold': 0.3045535265883591}. Best is trial 14 with value: 1385036.0.
# [I 2025-11-02 04:27:32,001] Trial 16 finished with value: 1402970.0 and parameters: {'threshold': 0.7445165090650132}. Best is trial 14 with value: 1385036.0.
# [I 2025-11-02 04:27:32,034] Trial 17 finished with value: 1380454.0 and parameters: {'threshold': 0.49557453615947955}. Best is trial 17 with value: 1380454.0.
# [I 2025-11-02 04:27:32,067] Trial 18 finished with value: 1384806.0 and parameters: {'threshold': 0.4617943793052285}. Best is trial 17 with value: 1380454.0.
# [I 2025-11-02 04:27:32,101] Trial 19 finished with value: 2068622.0 and parameters: {'threshold': 0.23687183471028594}. Best is trial 17 with value: 1380454.0.
# [I 2025-11-02 04:27:32,135] Trial 20 finished with value: 1397612.0 and parameters: {'threshold': 0.44590606615555384}. Best is trial 17 with value: 1380454.0.
# [I 2025-11-02 04:27:32,168] Trial 21 finished with value: 1382478.0 and parameters: {'threshold': 0.5074931404094568}. Best is trial 17 with value: 1380454.0.
# [I 2025-11-02 04:27:32,201] Trial 22 finished with value: 1384118.0 and parameters: {'threshold': 0.46309769469321255}. Best is trial 17 with value: 1380454.0.
# [I 2025-11-02 04:27:32,233] Trial 23 finished with value: 1400828.0 and parameters: {'threshold': 0.6346205974445264}. Best is trial 17 with value: 1380454.0.
# [I 2025-11-02 04:27:32,267] Trial 24 finished with value: 1914916.0 and parameters: {'threshold': 0.27421490162395007}. Best is trial 17 with value: 1380454.0.
# [I 2025-11-02 04:27:32,300] Trial 25 finished with value: 1574154.0 and parameters: {'threshold': 0.3758833581083389}. Best is trial 17 with value: 1380454.0.
# [I 2025-11-02 04:27:32,335] Trial 26 finished with value: 1382802.0 and parameters: {'threshold': 0.5100205508916368}. Best is trial 17 with value: 1380454.0.
# [I 2025-11-02 04:27:32,368] Trial 27 finished with value: 1403686.0 and parameters: {'threshold': 0.8390565101706382}. Best is trial 17 with value: 1380454.0.
# [I 2025-11-02 04:27:32,402] Trial 28 finished with value: 1401334.0 and parameters: {'threshold': 0.6704697663102177}. Best is trial 17 with value: 1380454.0.
# [I 2025-11-02 04:27:32,435] Trial 29 finished with value: 1388472.0 and parameters: {'threshold': 0.5435060869804003}. Best is trial 17 with value: 1380454.0.
# [I 2025-11-02 04:27:32,469] Trial 30 finished with value: 1513974.0 and parameters: {'threshold': 0.39233216444104524}. Best is trial 17 with value: 1380454.0.
# [I 2025-11-02 04:27:32,502] Trial 31 finished with value: 1383042.0 and parameters: {'threshold': 0.5117748258934146}. Best is trial 17 with value: 1380454.0.
# [I 2025-11-02 04:27:32,536] Trial 32 finished with value: 1383142.0 and parameters: {'threshold': 0.5125912012932524}. Best is trial 17 with value: 1380454.0.
# [I 2025-11-02 04:27:32,570] Trial 33 finished with value: 1403686.0 and parameters: {'threshold': 0.7836875249930755}. Best is trial 17 with value: 1380454.0.
# [I 2025-11-02 04:27:32,604] Trial 34 finished with value: 1400936.0 and parameters: {'threshold': 0.6372106270903992}. Best is trial 17 with value: 1380454.0.
# [I 2025-11-02 04:27:32,638] Trial 35 finished with value: 1746160.0 and parameters: {'threshold': 0.32756843592857465}. Best is trial 17 with value: 1380454.0.
# [I 2025-11-02 04:27:32,671] Trial 36 finished with value: 1396064.0 and parameters: {'threshold': 0.5879011686197605}. Best is trial 17 with value: 1380454.0.
# [I 2025-11-02 04:27:32,704] Trial 37 finished with value: 1403686.0 and parameters: {'threshold': 0.9860962011124869}. Best is trial 17 with value: 1380454.0.
# [I 2025-11-02 04:27:32,739] Trial 38 finished with value: 1476586.0 and parameters: {'threshold': 0.40419712330512536}. Best is trial 17 with value: 1380454.0.
# [I 2025-11-02 04:27:32,773] Trial 39 finished with value: 1379368.0 and parameters: {'threshold': 0.4878452869358127}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:27:32,807] Trial 40 finished with value: 2134574.0 and parameters: {'threshold': 0.22621006538985383}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:27:32,840] Trial 41 finished with value: 1387974.0 and parameters: {'threshold': 0.457308615394681}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:27:32,874] Trial 42 finished with value: 1380084.0 and parameters: {'threshold': 0.493038940912989}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:27:32,908] Trial 43 finished with value: 1392298.0 and parameters: {'threshold': 0.5642458799742982}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:27:32,941] Trial 44 finished with value: 1379604.0 and parameters: {'threshold': 0.48890285094263225}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:27:32,974] Trial 45 finished with value: 1401042.0 and parameters: {'threshold': 0.6417802115627238}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:27:33,007] Trial 46 finished with value: 1379498.0 and parameters: {'threshold': 0.4813351239405775}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:27:33,041] Trial 47 finished with value: 1618630.0 and parameters: {'threshold': 0.3636157095111002}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:27:33,074] Trial 48 finished with value: 1445036.0 and parameters: {'threshold': 0.41647363350639777}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:27:33,107] Trial 49 finished with value: 1379714.0 and parameters: {'threshold': 0.47750870114196836}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:27:33,140] Trial 50 finished with value: 1396314.0 and parameters: {'threshold': 0.5897311099040883}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:27:33,175] Trial 51 finished with value: 1380414.0 and parameters: {'threshold': 0.47343369907697586}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:27:33,210] Trial 52 finished with value: 1381506.0 and parameters: {'threshold': 0.4697477788891925}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:27:33,244] Trial 53 finished with value: 1419550.0 and parameters: {'threshold': 0.4294495320996033}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:27:33,277] Trial 54 finished with value: 1390722.0 and parameters: {'threshold': 0.5557215252028843}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:27:33,313] Trial 55 finished with value: 1379514.0 and parameters: {'threshold': 0.4808495346805836}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:27:33,348] Trial 56 finished with value: 1746192.0 and parameters: {'threshold': 0.32755417597800296}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:27:33,383] Trial 57 finished with value: 2989152.0 and parameters: {'threshold': 0.12213006114694941}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:27:33,421] Trial 58 finished with value: 3449024.0 and parameters: {'threshold': 0.02076940545889583}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:27:33,456] Trial 59 finished with value: 1399900.0 and parameters: {'threshold': 0.61884467933442}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:27:33,491] Trial 60 finished with value: 1401638.0 and parameters: {'threshold': 0.6935846128814009}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:27:33,526] Trial 61 finished with value: 1380470.0 and parameters: {'threshold': 0.47297962935814025}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:27:33,560] Trial 62 finished with value: 1389380.0 and parameters: {'threshold': 0.5480576758637232}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:27:33,595] Trial 63 finished with value: 1379610.0 and parameters: {'threshold': 0.48868754124265523}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:27:33,630] Trial 64 finished with value: 1409862.0 and parameters: {'threshold': 0.43572682939044816}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:27:33,665] Trial 65 finished with value: 1379258.0 and parameters: {'threshold': 0.48566645746996934}. Best is trial 65 with value: 1379258.0.
# [I 2025-11-02 04:27:33,700] Trial 66 finished with value: 1469062.0 and parameters: {'threshold': 0.4067603287012668}. Best is trial 65 with value: 1379258.0.
# [I 2025-11-02 04:27:33,735] Trial 67 finished with value: 1387272.0 and parameters: {'threshold': 0.5364783189873712}. Best is trial 65 with value: 1379258.0.
# [I 2025-11-02 04:27:33,769] Trial 68 finished with value: 1403074.0 and parameters: {'threshold': 0.4409527726713359}. Best is trial 65 with value: 1379258.0.
# [I 2025-11-02 04:27:33,804] Trial 69 finished with value: 1544562.0 and parameters: {'threshold': 0.3836984558824349}. Best is trial 65 with value: 1379258.0.
# [I 2025-11-02 04:27:33,838] Trial 70 finished with value: 1379222.0 and parameters: {'threshold': 0.4874831716958652}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:27:33,873] Trial 71 finished with value: 1379226.0 and parameters: {'threshold': 0.4869262864790581}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:27:33,908] Trial 72 finished with value: 1385946.0 and parameters: {'threshold': 0.5286668928108579}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:27:33,943] Trial 73 finished with value: 1676012.0 and parameters: {'threshold': 0.3481283681036119}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:27:33,978] Trial 74 finished with value: 1382752.0 and parameters: {'threshold': 0.5096449917192872}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:27:34,013] Trial 75 finished with value: 1399038.0 and parameters: {'threshold': 0.6108814052363454}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:27:34,047] Trial 76 finished with value: 1394536.0 and parameters: {'threshold': 0.5779531254567483}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:27:34,082] Trial 77 finished with value: 1379596.0 and parameters: {'threshold': 0.4893286618854822}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:27:34,116] Trial 78 finished with value: 1400154.0 and parameters: {'threshold': 0.4438124945013278}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:27:34,151] Trial 79 finished with value: 1390846.0 and parameters: {'threshold': 0.5566585486869664}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:27:34,186] Trial 80 finished with value: 1439762.0 and parameters: {'threshold': 0.41877544337238454}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:27:34,220] Trial 81 finished with value: 1380100.0 and parameters: {'threshold': 0.4936690123925438}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:27:34,256] Trial 82 finished with value: 1381044.0 and parameters: {'threshold': 0.500049845347165}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:27:34,290] Trial 83 finished with value: 1386106.0 and parameters: {'threshold': 0.5295059395487278}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:27:34,325] Trial 84 finished with value: 1379224.0 and parameters: {'threshold': 0.48582362081253005}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:27:34,359] Trial 85 finished with value: 1519614.0 and parameters: {'threshold': 0.3906980287101552}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:27:34,395] Trial 86 finished with value: 1388058.0 and parameters: {'threshold': 0.4569361092673472}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:27:34,430] Trial 87 finished with value: 1393922.0 and parameters: {'threshold': 0.5735574217390992}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:27:34,467] Trial 88 finished with value: 1893408.0 and parameters: {'threshold': 0.28103008899744863}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:27:34,501] Trial 89 finished with value: 1386158.0 and parameters: {'threshold': 0.5301165888376261}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:27:34,536] Trial 90 finished with value: 1648614.0 and parameters: {'threshold': 0.3555184597800873}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:27:34,571] Trial 91 finished with value: 1379894.0 and parameters: {'threshold': 0.4908671570709244}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:27:34,607] Trial 92 finished with value: 1381178.0 and parameters: {'threshold': 0.4706125546300934}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:27:34,641] Trial 93 finished with value: 1421328.0 and parameters: {'threshold': 0.4283467024468726}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:27:34,676] Trial 94 finished with value: 1381530.0 and parameters: {'threshold': 0.5024458169256771}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:27:34,711] Trial 95 finished with value: 1395904.0 and parameters: {'threshold': 0.4473785807761995}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:27:34,746] Trial 96 finished with value: 1379702.0 and parameters: {'threshold': 0.47784851665942873}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:27:34,780] Trial 97 finished with value: 1384086.0 and parameters: {'threshold': 0.5181174256467497}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:27:34,815] Trial 98 finished with value: 1470244.0 and parameters: {'threshold': 0.4063551599687303}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:27:34,850] Trial 99 finished with value: 1390086.0 and parameters: {'threshold': 0.5515069477668297}. Best is trial 70 with value: 1379222.0.
#   ✓ Mejor threshold: 0.4875
#     - Precision: 0.5563
#     - Recall:    0.0860
#     - F1:        0.1490
#     - Costo:     1379222.00
#     - Confusion: TP=60390, FP=48158, FN=641453, TN=1676354
#
# --- Optimizando threshold para W1_discrete ---
# [I 2025-11-02 04:28:17,794] A new study created in memory with name: threshold_W1_discrete
# [I 2025-11-02 04:28:17,827] Trial 0 finished with value: 412920.0 and parameters: {'threshold': 0.37704931647041523}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:28:17,859] Trial 1 finished with value: 412920.0 and parameters: {'threshold': 0.9417000202817178}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:28:17,891] Trial 2 finished with value: 412920.0 and parameters: {'threshold': 0.727354062975177}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:28:17,923] Trial 3 finished with value: 412920.0 and parameters: {'threshold': 0.5966853145130959}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:28:17,954] Trial 4 finished with value: 630320.0 and parameters: {'threshold': 0.1628982676335878}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:28:17,986] Trial 5 finished with value: 630508.0 and parameters: {'threshold': 0.1628746299294786}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:28:18,018] Trial 6 finished with value: 2673744.0 and parameters: {'threshold': 0.06692193992483547}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:28:18,049] Trial 7 finished with value: 412920.0 and parameters: {'threshold': 0.8588526228594364}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:28:18,081] Trial 8 finished with value: 412920.0 and parameters: {'threshold': 0.5990927115083446}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:28:18,112] Trial 9 finished with value: 412920.0 and parameters: {'threshold': 0.7039111262401245}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:28:18,147] Trial 10 finished with value: 412920.0 and parameters: {'threshold': 0.3769870974683338}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:28:18,181] Trial 11 finished with value: 412920.0 and parameters: {'threshold': 0.3922180649768887}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:28:18,215] Trial 12 finished with value: 412920.0 and parameters: {'threshold': 0.9601463685721084}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:28:18,249] Trial 13 finished with value: 412922.0 and parameters: {'threshold': 0.3499138735784894}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:28:18,283] Trial 14 finished with value: 412920.0 and parameters: {'threshold': 0.4969220260448285}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:28:18,317] Trial 15 finished with value: 412920.0 and parameters: {'threshold': 0.852759915379516}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:28:18,351] Trial 16 finished with value: 414238.0 and parameters: {'threshold': 0.26033458958989486}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:28:18,385] Trial 17 finished with value: 412920.0 and parameters: {'threshold': 0.5127406936978046}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:28:18,419] Trial 18 finished with value: 412920.0 and parameters: {'threshold': 0.7397676814617209}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:28:18,453] Trial 19 finished with value: 412920.0 and parameters: {'threshold': 0.9858797125799896}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:28:18,486] Trial 20 finished with value: 413064.0 and parameters: {'threshold': 0.28514573515491004}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:28:18,520] Trial 21 finished with value: 412920.0 and parameters: {'threshold': 0.7652346217266811}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:28:18,554] Trial 22 finished with value: 412920.0 and parameters: {'threshold': 0.9097926711983474}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:28:18,587] Trial 23 finished with value: 412920.0 and parameters: {'threshold': 0.6543957292102196}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:28:18,621] Trial 24 finished with value: 412920.0 and parameters: {'threshold': 0.8091288418394447}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:28:18,655] Trial 25 finished with value: 412920.0 and parameters: {'threshold': 0.5004283503698654}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:28:18,687] Trial 26 finished with value: 412920.0 and parameters: {'threshold': 0.9072939149284966}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:28:18,721] Trial 27 finished with value: 412920.0 and parameters: {'threshold': 0.661807144988821}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:28:18,755] Trial 28 finished with value: 412920.0 and parameters: {'threshold': 0.5581861761306598}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:28:18,789] Trial 29 finished with value: 412920.0 and parameters: {'threshold': 0.44091680408362666}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:28:18,823] Trial 30 finished with value: 412920.0 and parameters: {'threshold': 0.8012666340035751}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:28:18,857] Trial 31 finished with value: 412920.0 and parameters: {'threshold': 0.6224780382915017}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:28:18,889] Trial 32 finished with value: 412920.0 and parameters: {'threshold': 0.7061518848269643}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:28:18,923] Trial 33 finished with value: 414588.0 and parameters: {'threshold': 0.2562447179047049}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:28:18,956] Trial 34 finished with value: 1251776.0 and parameters: {'threshold': 0.11653480164462432}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:28:18,989] Trial 35 finished with value: 412920.0 and parameters: {'threshold': 0.5622274689942929}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:28:19,023] Trial 36 finished with value: 412920.0 and parameters: {'threshold': 0.4448185363654171}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:28:19,057] Trial 37 finished with value: 412920.0 and parameters: {'threshold': 0.5798701631864945}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:28:19,090] Trial 38 finished with value: 528552.0 and parameters: {'threshold': 0.17777982050805624}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:28:19,124] Trial 39 finished with value: 3690014.0 and parameters: {'threshold': 0.03150756826512785}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:28:19,158] Trial 40 finished with value: 412910.0 and parameters: {'threshold': 0.3371779109860835}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:19,192] Trial 41 finished with value: 412934.0 and parameters: {'threshold': 0.3086437081204995}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:19,225] Trial 42 finished with value: 412920.0 and parameters: {'threshold': 0.41360900722607097}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:19,259] Trial 43 finished with value: 451212.0 and parameters: {'threshold': 0.1981308401755637}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:19,293] Trial 44 finished with value: 412916.0 and parameters: {'threshold': 0.3355047643761011}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:19,328] Trial 45 finished with value: 412926.0 and parameters: {'threshold': 0.3563805331340178}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:19,362] Trial 46 finished with value: 434260.0 and parameters: {'threshold': 0.20800612736200377}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:19,397] Trial 47 finished with value: 412916.0 and parameters: {'threshold': 0.32406522294745227}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:19,432] Trial 48 finished with value: 412928.0 and parameters: {'threshold': 0.31255898877549704}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:19,467] Trial 49 finished with value: 412920.0 and parameters: {'threshold': 0.446452310930668}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:19,502] Trial 50 finished with value: 417548.0 and parameters: {'threshold': 0.23290170957461118}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:19,537] Trial 51 finished with value: 412916.0 and parameters: {'threshold': 0.33477726106095906}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:19,571] Trial 52 finished with value: 412916.0 and parameters: {'threshold': 0.32456313015496846}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:19,607] Trial 53 finished with value: 412916.0 and parameters: {'threshold': 0.33496376893695595}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:19,642] Trial 54 finished with value: 412912.0 and parameters: {'threshold': 0.3267525760260042}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:19,676] Trial 55 finished with value: 1040420.0 and parameters: {'threshold': 0.128201633934934}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:19,710] Trial 56 finished with value: 412918.0 and parameters: {'threshold': 0.38175889298386034}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:19,745] Trial 57 finished with value: 413110.0 and parameters: {'threshold': 0.2822471645846949}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:19,780] Trial 58 finished with value: 412920.0 and parameters: {'threshold': 0.4189636951160417}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:19,815] Trial 59 finished with value: 412922.0 and parameters: {'threshold': 0.3501655885227264}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:19,850] Trial 60 finished with value: 412920.0 and parameters: {'threshold': 0.4741470374021109}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:19,886] Trial 61 finished with value: 412920.0 and parameters: {'threshold': 0.3203058019791616}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:19,920] Trial 62 finished with value: 416490.0 and parameters: {'threshold': 0.23759309119064964}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:19,955] Trial 63 finished with value: 412916.0 and parameters: {'threshold': 0.3323080748528673}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:19,990] Trial 64 finished with value: 413056.0 and parameters: {'threshold': 0.28595872743217865}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:20,024] Trial 65 finished with value: 412920.0 and parameters: {'threshold': 0.37754914970042264}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:20,058] Trial 66 finished with value: 412920.0 and parameters: {'threshold': 0.40181288856593783}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:20,093] Trial 67 finished with value: 412916.0 and parameters: {'threshold': 0.34769729371691416}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:20,130] Trial 68 finished with value: 413262.0 and parameters: {'threshold': 0.2767067165571231}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:20,168] Trial 69 finished with value: 856122.0 and parameters: {'threshold': 0.14076605787545607}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:20,205] Trial 70 finished with value: 412920.0 and parameters: {'threshold': 0.5267970496328767}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:20,239] Trial 71 finished with value: 412914.0 and parameters: {'threshold': 0.3254194418766005}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:20,274] Trial 72 finished with value: 412936.0 and parameters: {'threshold': 0.30756600240747306}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:20,309] Trial 73 finished with value: 412924.0 and parameters: {'threshold': 0.362198222942248}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:20,344] Trial 74 finished with value: 415834.0 and parameters: {'threshold': 0.24201494685236435}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:20,378] Trial 75 finished with value: 412920.0 and parameters: {'threshold': 0.4775385805478367}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:20,412] Trial 76 finished with value: 412920.0 and parameters: {'threshold': 0.38971133748468867}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:20,446] Trial 77 finished with value: 428516.0 and parameters: {'threshold': 0.2135837127124791}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:20,481] Trial 78 finished with value: 412912.0 and parameters: {'threshold': 0.3274352831505749}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:20,515] Trial 79 finished with value: 413896.0 and parameters: {'threshold': 0.26578182441397374}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:20,549] Trial 80 finished with value: 412920.0 and parameters: {'threshold': 0.42623061590680933}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:20,582] Trial 81 finished with value: 412916.0 and parameters: {'threshold': 0.33295836650062843}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:20,616] Trial 82 finished with value: 412962.0 and parameters: {'threshold': 0.2977625776249586}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:20,650] Trial 83 finished with value: 412916.0 and parameters: {'threshold': 0.33206585168043934}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:20,684] Trial 84 finished with value: 412922.0 and parameters: {'threshold': 0.3680430618523004}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:20,718] Trial 85 finished with value: 412920.0 and parameters: {'threshold': 0.39672875486339804}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:20,752] Trial 86 finished with value: 414266.0 and parameters: {'threshold': 0.26007620486908245}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:20,786] Trial 87 finished with value: 532718.0 and parameters: {'threshold': 0.1770520529614707}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:20,820] Trial 88 finished with value: 412968.0 and parameters: {'threshold': 0.29481711312344383}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:20,853] Trial 89 finished with value: 412920.0 and parameters: {'threshold': 0.4580954155853907}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:20,887] Trial 90 finished with value: 420884.0 and parameters: {'threshold': 0.2237671955730493}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:20,921] Trial 91 finished with value: 412916.0 and parameters: {'threshold': 0.3336028742826056}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:20,955] Trial 92 finished with value: 412916.0 and parameters: {'threshold': 0.3358239156277083}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:20,989] Trial 93 finished with value: 412928.0 and parameters: {'threshold': 0.31647256619360387}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:21,023] Trial 94 finished with value: 412924.0 and parameters: {'threshold': 0.3641506723623052}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:21,058] Trial 95 finished with value: 414606.0 and parameters: {'threshold': 0.2560106126663054}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:21,092] Trial 96 finished with value: 412920.0 and parameters: {'threshold': 0.4118014839767165}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:21,127] Trial 97 finished with value: 412922.0 and parameters: {'threshold': 0.34996358664809296}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:21,161] Trial 98 finished with value: 412958.0 and parameters: {'threshold': 0.299159506905468}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:28:21,194] Trial 99 finished with value: 412920.0 and parameters: {'threshold': 0.37485699421985313}. Best is trial 40 with value: 412910.0.
#   ✓ Mejor threshold: 0.3372
#     - Precision: 0.6190
#     - Recall:    0.0001
#     - F1:        0.0001
#     - Costo:     412910.00
#     - Confusion: TP=13, FP=8, FN=206447, TN=2219887
#
# --- Optimizando threshold para W7_discrete ---
# [I 2025-11-02 04:29:04,619] A new study created in memory with name: threshold_W7_discrete
# [I 2025-11-02 04:29:04,652] Trial 0 finished with value: 680602.0 and parameters: {'threshold': 0.37704931647041523}. Best is trial 0 with value: 680602.0.
# [I 2025-11-02 04:29:04,684] Trial 1 finished with value: 672762.0 and parameters: {'threshold': 0.9417000202817178}. Best is trial 1 with value: 672762.0.
# [I 2025-11-02 04:29:04,716] Trial 2 finished with value: 672762.0 and parameters: {'threshold': 0.727354062975177}. Best is trial 1 with value: 672762.0.
# [I 2025-11-02 04:29:04,747] Trial 3 finished with value: 672762.0 and parameters: {'threshold': 0.5966853145130959}. Best is trial 1 with value: 672762.0.
# [I 2025-11-02 04:29:04,779] Trial 4 finished with value: 1488050.0 and parameters: {'threshold': 0.1628982676335878}. Best is trial 1 with value: 672762.0.
# [I 2025-11-02 04:29:04,810] Trial 5 finished with value: 1488520.0 and parameters: {'threshold': 0.1628746299294786}. Best is trial 1 with value: 672762.0.
# [I 2025-11-02 04:29:04,842] Trial 6 finished with value: 3181882.0 and parameters: {'threshold': 0.06692193992483547}. Best is trial 1 with value: 672762.0.
# [I 2025-11-02 04:29:04,873] Trial 7 finished with value: 672762.0 and parameters: {'threshold': 0.8588526228594364}. Best is trial 1 with value: 672762.0.
# [I 2025-11-02 04:29:04,905] Trial 8 finished with value: 672762.0 and parameters: {'threshold': 0.5990927115083446}. Best is trial 1 with value: 672762.0.
# [I 2025-11-02 04:29:04,936] Trial 9 finished with value: 672762.0 and parameters: {'threshold': 0.7039111262401245}. Best is trial 1 with value: 672762.0.
# [I 2025-11-02 04:29:04,970] Trial 10 finished with value: 672762.0 and parameters: {'threshold': 0.9699049477268573}. Best is trial 1 with value: 672762.0.
# [I 2025-11-02 04:29:05,004] Trial 11 finished with value: 672762.0 and parameters: {'threshold': 0.8029026582945012}. Best is trial 1 with value: 672762.0.
# [I 2025-11-02 04:29:05,038] Trial 12 finished with value: 672762.0 and parameters: {'threshold': 0.9694809150597243}. Best is trial 1 with value: 672762.0.
# [I 2025-11-02 04:29:05,072] Trial 13 finished with value: 672494.0 and parameters: {'threshold': 0.4556837729838583}. Best is trial 13 with value: 672494.0.
# [I 2025-11-02 04:29:05,106] Trial 14 finished with value: 674800.0 and parameters: {'threshold': 0.3992648948371728}. Best is trial 13 with value: 672494.0.
# [I 2025-11-02 04:29:05,140] Trial 15 finished with value: 677036.0 and parameters: {'threshold': 0.38827812518374166}. Best is trial 13 with value: 672494.0.
# [I 2025-11-02 04:29:05,175] Trial 16 finished with value: 672738.0 and parameters: {'threshold': 0.5109441875173779}. Best is trial 13 with value: 672494.0.
# [I 2025-11-02 04:29:05,210] Trial 17 finished with value: 672652.0 and parameters: {'threshold': 0.4885176481810135}. Best is trial 13 with value: 672494.0.
# [I 2025-11-02 04:29:05,246] Trial 18 finished with value: 835348.0 and parameters: {'threshold': 0.2467348166735741}. Best is trial 13 with value: 672494.0.
# [I 2025-11-02 04:29:05,283] Trial 19 finished with value: 672740.0 and parameters: {'threshold': 0.5036190340942092}. Best is trial 13 with value: 672494.0.
# [I 2025-11-02 04:29:05,319] Trial 20 finished with value: 775004.0 and parameters: {'threshold': 0.28514573515491004}. Best is trial 13 with value: 672494.0.
# [I 2025-11-02 04:29:05,355] Trial 21 finished with value: 672762.0 and parameters: {'threshold': 0.5330243973584159}. Best is trial 13 with value: 672494.0.
# [I 2025-11-02 04:29:05,390] Trial 22 finished with value: 672542.0 and parameters: {'threshold': 0.4432957706101451}. Best is trial 13 with value: 672494.0.
# [I 2025-11-02 04:29:05,426] Trial 23 finished with value: 673588.0 and parameters: {'threshold': 0.4128151676525437}. Best is trial 13 with value: 672494.0.
# [I 2025-11-02 04:29:05,462] Trial 24 finished with value: 672762.0 and parameters: {'threshold': 0.6308683973855311}. Best is trial 13 with value: 672494.0.
# [I 2025-11-02 04:29:05,498] Trial 25 finished with value: 767636.0 and parameters: {'threshold': 0.2912401222313599}. Best is trial 13 with value: 672494.0.
# [I 2025-11-02 04:29:05,533] Trial 26 finished with value: 672490.0 and parameters: {'threshold': 0.4550828548506232}. Best is trial 26 with value: 672490.0.
# [I 2025-11-02 04:29:05,570] Trial 27 finished with value: 672520.0 and parameters: {'threshold': 0.44418971442151206}. Best is trial 26 with value: 672490.0.
# [I 2025-11-02 04:29:05,607] Trial 28 finished with value: 711422.0 and parameters: {'threshold': 0.3388819433570871}. Best is trial 26 with value: 672490.0.
# [I 2025-11-02 04:29:05,647] Trial 29 finished with value: 672762.0 and parameters: {'threshold': 0.6782587178118477}. Best is trial 26 with value: 672490.0.
# [I 2025-11-02 04:29:05,685] Trial 30 finished with value: 721348.0 and parameters: {'threshold': 0.33062088585680877}. Best is trial 26 with value: 672490.0.
# [I 2025-11-02 04:29:05,723] Trial 31 finished with value: 672526.0 and parameters: {'threshold': 0.47236231227745307}. Best is trial 26 with value: 672490.0.
# [I 2025-11-02 04:29:05,759] Trial 32 finished with value: 672432.0 and parameters: {'threshold': 0.46080946923503696}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:05,795] Trial 33 finished with value: 672762.0 and parameters: {'threshold': 0.5521923539065368}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:05,831] Trial 34 finished with value: 907270.0 and parameters: {'threshold': 0.22035812890601478}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:05,866] Trial 35 finished with value: 672506.0 and parameters: {'threshold': 0.45034141248062565}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:05,902] Trial 36 finished with value: 672762.0 and parameters: {'threshold': 0.588334914428812}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:05,943] Trial 37 finished with value: 693748.0 and parameters: {'threshold': 0.3555654191966984}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:05,979] Trial 38 finished with value: 672762.0 and parameters: {'threshold': 0.6479954871081627}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:06,015] Trial 39 finished with value: 672762.0 and parameters: {'threshold': 0.7510246441752109}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:06,050] Trial 40 finished with value: 3205110.0 and parameters: {'threshold': 0.06558370383922896}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:06,085] Trial 41 finished with value: 672506.0 and parameters: {'threshold': 0.45595274156148236}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:06,121] Trial 42 finished with value: 672762.0 and parameters: {'threshold': 0.5634907252154275}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:06,156] Trial 43 finished with value: 672556.0 and parameters: {'threshold': 0.44298523480234403}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:06,191] Trial 44 finished with value: 672500.0 and parameters: {'threshold': 0.46939946212814293}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:06,227] Trial 45 finished with value: 1429602.0 and parameters: {'threshold': 0.16634028034070986}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:06,261] Trial 46 finished with value: 677144.0 and parameters: {'threshold': 0.38799222508805403}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:06,295] Trial 47 finished with value: 748638.0 and parameters: {'threshold': 0.30737737487078676}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:06,330] Trial 48 finished with value: 672750.0 and parameters: {'threshold': 0.5171551873024016}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:06,364] Trial 49 finished with value: 672762.0 and parameters: {'threshold': 0.61728218129514}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:06,397] Trial 50 finished with value: 673446.0 and parameters: {'threshold': 0.414478471937744}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:06,432] Trial 51 finished with value: 672616.0 and parameters: {'threshold': 0.4793765754187904}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:06,466] Trial 52 finished with value: 672496.0 and parameters: {'threshold': 0.4565850324022589}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:06,501] Trial 53 finished with value: 672762.0 and parameters: {'threshold': 0.5688104652276321}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:06,536] Trial 54 finished with value: 684496.0 and parameters: {'threshold': 0.36915260525930343}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:06,571] Trial 55 finished with value: 672752.0 and parameters: {'threshold': 0.5235440657018331}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:06,605] Trial 56 finished with value: 672646.0 and parameters: {'threshold': 0.48641122755021515}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:06,640] Trial 57 finished with value: 673230.0 and parameters: {'threshold': 0.4185099095186221}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:06,675] Trial 58 finished with value: 4053764.0 and parameters: {'threshold': 0.02076940545889583}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:06,710] Trial 59 finished with value: 672762.0 and parameters: {'threshold': 0.5356215348616298}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:06,744] Trial 60 finished with value: 680378.0 and parameters: {'threshold': 0.37756057406670374}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:06,779] Trial 61 finished with value: 672482.0 and parameters: {'threshold': 0.4514255056301712}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:06,814] Trial 62 finished with value: 673686.0 and parameters: {'threshold': 0.41094002216958936}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:06,848] Trial 63 finished with value: 672484.0 and parameters: {'threshold': 0.4492516341349964}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:06,883] Trial 64 finished with value: 672726.0 and parameters: {'threshold': 0.5025030100058795}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:06,918] Trial 65 finished with value: 722600.0 and parameters: {'threshold': 0.3294980080706059}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:06,954] Trial 66 finished with value: 847822.0 and parameters: {'threshold': 0.24052425321773027}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:06,988] Trial 67 finished with value: 672718.0 and parameters: {'threshold': 0.4330044011493486}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:07,023] Trial 68 finished with value: 672492.0 and parameters: {'threshold': 0.4692726670587507}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:07,058] Trial 69 finished with value: 672762.0 and parameters: {'threshold': 0.5864761665228987}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:07,092] Trial 70 finished with value: 692798.0 and parameters: {'threshold': 0.35668571934261856}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:07,126] Trial 71 finished with value: 672464.0 and parameters: {'threshold': 0.4645622407664017}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:07,160] Trial 72 finished with value: 672688.0 and parameters: {'threshold': 0.4956277930779522}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:07,194] Trial 73 finished with value: 675564.0 and parameters: {'threshold': 0.394824322491873}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:07,228] Trial 74 finished with value: 672762.0 and parameters: {'threshold': 0.8632154411289008}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:07,262] Trial 75 finished with value: 672762.0 and parameters: {'threshold': 0.5465752139762868}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:07,295] Trial 76 finished with value: 672454.0 and parameters: {'threshold': 0.4624020055142569}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:07,329] Trial 77 finished with value: 672990.0 and parameters: {'threshold': 0.4245273595212899}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:07,363] Trial 78 finished with value: 672560.0 and parameters: {'threshold': 0.4748398042214953}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:07,398] Trial 79 finished with value: 672746.0 and parameters: {'threshold': 0.5117567997649142}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:07,432] Trial 80 finished with value: 736380.0 and parameters: {'threshold': 0.3179021131088514}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:07,467] Trial 81 finished with value: 672570.0 and parameters: {'threshold': 0.44275171788589557}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:07,503] Trial 82 finished with value: 672582.0 and parameters: {'threshold': 0.47600651562625446}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:07,537] Trial 83 finished with value: 672502.0 and parameters: {'threshold': 0.45576407708689404}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:07,572] Trial 84 finished with value: 675294.0 and parameters: {'threshold': 0.3965266613579287}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:07,608] Trial 85 finished with value: 672762.0 and parameters: {'threshold': 0.5334593493583364}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:07,643] Trial 86 finished with value: 702064.0 and parameters: {'threshold': 0.34697629501616656}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:07,678] Trial 87 finished with value: 672762.0 and parameters: {'threshold': 0.573009096543195}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:07,713] Trial 88 finished with value: 672704.0 and parameters: {'threshold': 0.4988234953965806}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:29:07,749] Trial 89 finished with value: 672422.0 and parameters: {'threshold': 0.4601283184863986}. Best is trial 89 with value: 672422.0.
# [I 2025-11-02 04:29:07,784] Trial 90 finished with value: 682610.0 and parameters: {'threshold': 0.3726301474689337}. Best is trial 89 with value: 672422.0.
# [I 2025-11-02 04:29:07,820] Trial 91 finished with value: 672910.0 and parameters: {'threshold': 0.4275358752764036}. Best is trial 89 with value: 672422.0.
# [I 2025-11-02 04:29:07,855] Trial 92 finished with value: 672464.0 and parameters: {'threshold': 0.4653180815541249}. Best is trial 89 with value: 672422.0.
# [I 2025-11-02 04:29:07,891] Trial 93 finished with value: 674778.0 and parameters: {'threshold': 0.3993642001488825}. Best is trial 89 with value: 672422.0.
# [I 2025-11-02 04:29:07,925] Trial 94 finished with value: 672754.0 and parameters: {'threshold': 0.5200865811358155}. Best is trial 89 with value: 672422.0.
# [I 2025-11-02 04:29:07,961] Trial 95 finished with value: 672468.0 and parameters: {'threshold': 0.4646192604759062}. Best is trial 89 with value: 672422.0.
# [I 2025-11-02 04:29:07,996] Trial 96 finished with value: 672476.0 and parameters: {'threshold': 0.4682790805203332}. Best is trial 89 with value: 672422.0.
# [I 2025-11-02 04:29:08,030] Trial 97 finished with value: 672762.0 and parameters: {'threshold': 0.5447561358554981}. Best is trial 89 with value: 672422.0.
# [I 2025-11-02 04:29:08,064] Trial 98 finished with value: 672762.0 and parameters: {'threshold': 0.6174109400984582}. Best is trial 89 with value: 672422.0.
# ...
# [I 2025-11-02 04:29:52,524] Trial 3 finished with value: 474526.0 and parameters: {'threshold': 0.5966853145130959}. Best is trial 1 with value: 474526.0.
# [I 2025-11-02 04:29:52,556] Trial 4 finished with value: 760316.0 and parameters: {'threshold': 0.1628982676335878}. Best is trial 1 with value: 474526.0.
# [I 2025-11-02 04:29:52,588] Trial 5 finished with value: 760418.0 and parameters: {'threshold': 0.1628746299294786}. Best is trial 1 with value: 474526.0.
# [I 2025-11-02 04:29:52,620] Trial 6 finished with value: 2931724.0 and parameters: {'threshold': 0.06692193992483547}. Best is trial 1 with value: 474526.0.
# [I 2025-11-02 04:29:52,651] Trial 7 finished with value: 474526.0 and parameters: {'threshold': 0.8588526228594364}. Best is trial 1 with value: 474526.0.
# [I 2025-11-02 04:29:52,682] Trial 8 finished with value: 474526.0 and parameters: {'threshold': 0.5990927115083446}. Best is trial 1 with value: 474526.0.
# [I 2025-11-02 04:29:52,712] Trial 9 finished with value: 474526.0 and parameters: {'threshold': 0.7039111262401245}. Best is trial 1 with value: 474526.0.
# [I 2025-11-02 04:29:52,745] Trial 10 finished with value: 474526.0 and parameters: {'threshold': 0.9699049477268573}. Best is trial 1 with value: 474526.0.
# [I 2025-11-02 04:29:52,776] Trial 11 finished with value: 474526.0 and parameters: {'threshold': 0.8029026582945012}. Best is trial 1 with value: 474526.0.
# [I 2025-11-02 04:29:52,809] Trial 12 finished with value: 474526.0 and parameters: {'threshold': 0.9694809150597243}. Best is trial 1 with value: 474526.0.
# [I 2025-11-02 04:29:52,842] Trial 13 finished with value: 474336.0 and parameters: {'threshold': 0.4556837729838583}. Best is trial 13 with value: 474336.0.
# [I 2025-11-02 04:29:52,874] Trial 14 finished with value: 474574.0 and parameters: {'threshold': 0.3992648948371728}. Best is trial 13 with value: 474336.0.
# [I 2025-11-02 04:29:52,906] Trial 15 finished with value: 474792.0 and parameters: {'threshold': 0.38827812518374166}. Best is trial 13 with value: 474336.0.
# [I 2025-11-02 04:29:52,939] Trial 16 finished with value: 474448.0 and parameters: {'threshold': 0.5109441875173779}. Best is trial 13 with value: 474336.0.
# [I 2025-11-02 04:29:52,972] Trial 17 finished with value: 474370.0 and parameters: {'threshold': 0.4885176481810135}. Best is trial 13 with value: 474336.0.
# [I 2025-11-02 04:29:53,005] Trial 18 finished with value: 549238.0 and parameters: {'threshold': 0.2467348166735741}. Best is trial 13 with value: 474336.0.
# [I 2025-11-02 04:29:53,037] Trial 19 finished with value: 474434.0 and parameters: {'threshold': 0.5036190340942092}. Best is trial 13 with value: 474336.0.
# [I 2025-11-02 04:29:53,070] Trial 20 finished with value: 500194.0 and parameters: {'threshold': 0.28514573515491004}. Best is trial 13 with value: 474336.0.
# [I 2025-11-02 04:29:53,103] Trial 21 finished with value: 474348.0 and parameters: {'threshold': 0.4829328591232125}. Best is trial 13 with value: 474336.0.
# [I 2025-11-02 04:29:53,135] Trial 22 finished with value: 474526.0 and parameters: {'threshold': 0.6183642641978561}. Best is trial 13 with value: 474336.0.
# [I 2025-11-02 04:29:53,168] Trial 23 finished with value: 474330.0 and parameters: {'threshold': 0.45039138676796436}. Best is trial 23 with value: 474330.0.
# [I 2025-11-02 04:29:53,201] Trial 24 finished with value: 497990.0 and parameters: {'threshold': 0.2882661225273463}. Best is trial 23 with value: 474330.0.
# [I 2025-11-02 04:29:53,234] Trial 25 finished with value: 474352.0 and parameters: {'threshold': 0.46890935409974194}. Best is trial 23 with value: 474330.0.
# [I 2025-11-02 04:29:53,267] Trial 26 finished with value: 474352.0 and parameters: {'threshold': 0.4158097954331593}. Best is trial 23 with value: 474330.0.
# [I 2025-11-02 04:29:53,299] Trial 27 finished with value: 474522.0 and parameters: {'threshold': 0.565376868020081}. Best is trial 23 with value: 474330.0.
# [I 2025-11-02 04:29:53,332] Trial 28 finished with value: 474526.0 and parameters: {'threshold': 0.6922143212557289}. Best is trial 23 with value: 474330.0.
# [I 2025-11-02 04:29:53,364] Trial 29 finished with value: 475408.0 and parameters: {'threshold': 0.36780562988123705}. Best is trial 23 with value: 474330.0.
# [I 2025-11-02 04:29:53,397] Trial 30 finished with value: 479624.0 and parameters: {'threshold': 0.33633576799996234}. Best is trial 23 with value: 474330.0.
# [I 2025-11-02 04:29:53,430] Trial 31 finished with value: 474358.0 and parameters: {'threshold': 0.47236231227745307}. Best is trial 23 with value: 474330.0.
# [I 2025-11-02 04:29:53,463] Trial 32 finished with value: 474358.0 and parameters: {'threshold': 0.46933111451008536}. Best is trial 23 with value: 474330.0.
# [I 2025-11-02 04:29:53,497] Trial 33 finished with value: 474516.0 and parameters: {'threshold': 0.5455508166300368}. Best is trial 23 with value: 474330.0.
# [I 2025-11-02 04:29:53,530] Trial 34 finished with value: 474526.0 and parameters: {'threshold': 0.6250900863508307}. Best is trial 23 with value: 474330.0.
# [I 2025-11-02 04:29:53,564] Trial 35 finished with value: 474328.0 and parameters: {'threshold': 0.436296047941667}. Best is trial 35 with value: 474328.0.
# [I 2025-11-02 04:29:53,598] Trial 36 finished with value: 474320.0 and parameters: {'threshold': 0.4292072472303114}. Best is trial 36 with value: 474320.0.
# [I 2025-11-02 04:29:53,630] Trial 37 finished with value: 656304.0 and parameters: {'threshold': 0.2027467132284084}. Best is trial 36 with value: 474320.0.
# [I 2025-11-02 04:29:53,663] Trial 38 finished with value: 480616.0 and parameters: {'threshold': 0.33192128581876834}. Best is trial 36 with value: 474320.0.
# [I 2025-11-02 04:29:53,696] Trial 39 finished with value: 474332.0 and parameters: {'threshold': 0.4314767166419359}. Best is trial 36 with value: 474320.0.
# [I 2025-11-02 04:29:53,729] Trial 40 finished with value: 3263940.0 and parameters: {'threshold': 0.05544954555542553}. Best is trial 36 with value: 474320.0.
# [I 2025-11-02 04:29:53,762] Trial 41 finished with value: 474340.0 and parameters: {'threshold': 0.42449120606717283}. Best is trial 36 with value: 474320.0.
# [I 2025-11-02 04:29:53,795] Trial 42 finished with value: 474318.0 and parameters: {'threshold': 0.4288959159407192}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:53,829] Trial 43 finished with value: 474518.0 and parameters: {'threshold': 0.5476239978736043}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:53,864] Trial 44 finished with value: 476304.0 and parameters: {'threshold': 0.35807532357161936}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:53,896] Trial 45 finished with value: 490704.0 and parameters: {'threshold': 0.30099025024777737}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:53,929] Trial 46 finished with value: 1223188.0 and parameters: {'threshold': 0.11923838527195979}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:53,961] Trial 47 finished with value: 474526.0 and parameters: {'threshold': 0.668546581806502}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:53,994] Trial 48 finished with value: 474352.0 and parameters: {'threshold': 0.41528400282767475}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:54,025] Trial 49 finished with value: 616518.0 and parameters: {'threshold': 0.21622083957590094}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:54,057] Trial 50 finished with value: 474334.0 and parameters: {'threshold': 0.42728824047851904}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:54,090] Trial 51 finished with value: 474338.0 and parameters: {'threshold': 0.4373014308555342}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:54,122] Trial 52 finished with value: 474450.0 and parameters: {'threshold': 0.517423173860225}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:54,155] Trial 53 finished with value: 474764.0 and parameters: {'threshold': 0.39006725480776955}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:54,186] Trial 54 finished with value: 482940.0 and parameters: {'threshold': 0.32443317504742075}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:54,218] Trial 55 finished with value: 474524.0 and parameters: {'threshold': 0.5679120256314532}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:54,251] Trial 56 finished with value: 474526.0 and parameters: {'threshold': 0.7697485037657625}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:54,284] Trial 57 finished with value: 474330.0 and parameters: {'threshold': 0.43660971089202133}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:54,316] Trial 58 finished with value: 474454.0 and parameters: {'threshold': 0.5193989537203391}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:54,348] Trial 59 finished with value: 475442.0 and parameters: {'threshold': 0.36694651579588167}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:54,382] Trial 60 finished with value: 474346.0 and parameters: {'threshold': 0.4457927115056342}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:54,416] Trial 61 finished with value: 474606.0 and parameters: {'threshold': 0.3975085356725305}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:54,449] Trial 62 finished with value: 474332.0 and parameters: {'threshold': 0.45873415365710646}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:54,482] Trial 63 finished with value: 474422.0 and parameters: {'threshold': 0.5021193488911008}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:54,514] Trial 64 finished with value: 474336.0 and parameters: {'threshold': 0.4487064741887411}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:54,547] Trial 65 finished with value: 475412.0 and parameters: {'threshold': 0.36813747883135123}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:54,580] Trial 66 finished with value: 512818.0 and parameters: {'threshold': 0.27205740804884315}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:54,613] Trial 67 finished with value: 474512.0 and parameters: {'threshold': 0.5393963835379345}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:54,647] Trial 68 finished with value: 474526.0 and parameters: {'threshold': 0.6080657649801527}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:54,680] Trial 69 finished with value: 474346.0 and parameters: {'threshold': 0.4807449769127709}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:54,713] Trial 70 finished with value: 474526.0 and parameters: {'threshold': 0.6462456703223097}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:54,746] Trial 71 finished with value: 474350.0 and parameters: {'threshold': 0.42205895268829036}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:54,778] Trial 72 finished with value: 474332.0 and parameters: {'threshold': 0.44919808945147005}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:54,810] Trial 73 finished with value: 474334.0 and parameters: {'threshold': 0.4588527232550232}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:54,843] Trial 74 finished with value: 474524.0 and parameters: {'threshold': 0.5704887008129553}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:54,876] Trial 75 finished with value: 474526.0 and parameters: {'threshold': 0.9231804837440608}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:54,908] Trial 76 finished with value: 480026.0 and parameters: {'threshold': 0.33416978412803966}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:54,941] Trial 77 finished with value: 474806.0 and parameters: {'threshold': 0.3877279196339868}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:54,975] Trial 78 finished with value: 474378.0 and parameters: {'threshold': 0.48939480960933873}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:55,009] Trial 79 finished with value: 474430.0 and parameters: {'threshold': 0.40707956235369225}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:55,041] Trial 80 finished with value: 487950.0 and parameters: {'threshold': 0.30781527260724517}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:55,074] Trial 81 finished with value: 474334.0 and parameters: {'threshold': 0.4374593444714966}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:55,106] Trial 82 finished with value: 474340.0 and parameters: {'threshold': 0.46076326333625534}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:55,138] Trial 83 finished with value: 477380.0 and parameters: {'threshold': 0.34990500609874103}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:55,172] Trial 84 finished with value: 474474.0 and parameters: {'threshold': 0.5250604756076347}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:55,205] Trial 85 finished with value: 474340.0 and parameters: {'threshold': 0.4263630362186321}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:55,238] Trial 86 finished with value: 474396.0 and parameters: {'threshold': 0.49178365310575434}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:55,272] Trial 87 finished with value: 474756.0 and parameters: {'threshold': 0.3893604275909862}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:55,306] Trial 88 finished with value: 474330.0 and parameters: {'threshold': 0.4652332438271477}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:55,340] Trial 89 finished with value: 474334.0 and parameters: {'threshold': 0.45778658226732427}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:55,375] Trial 90 finished with value: 474524.0 and parameters: {'threshold': 0.5829566128261955}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:55,410] Trial 91 finished with value: 474404.0 and parameters: {'threshold': 0.4092513170827645}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:55,446] Trial 92 finished with value: 474360.0 and parameters: {'threshold': 0.4742665278669245}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:55,481] Trial 93 finished with value: 474446.0 and parameters: {'threshold': 0.5129588050165709}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:55,516] Trial 94 finished with value: 474510.0 and parameters: {'threshold': 0.5364249040305459}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:55,550] Trial 95 finished with value: 474330.0 and parameters: {'threshold': 0.4366667382406733}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:55,585] Trial 96 finished with value: 475112.0 and parameters: {'threshold': 0.3752702147355269}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:55,619] Trial 97 finished with value: 474330.0 and parameters: {'threshold': 0.439961642669698}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:55,652] Trial 98 finished with value: 477046.0 and parameters: {'threshold': 0.35242356827356397}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:29:55,685] Trial 99 finished with value: 474394.0 and parameters: {'threshold': 0.49270599092291306}. Best is trial 42 with value: 474318.0.
#   ✓ Mejor threshold: 0.4289
#     - Precision: 0.5459
#     - Recall:    0.0026
#     - F1:        0.0052
#     - Costo:     474318.00
#     - Confusion: TP=618, FP=514, FN=236645, TN=2188578
#
# ================================================================================
# RESUMEN DE MEJORES THRESHOLDS POR HORIZONTE
# ================================================================================
# W0_discrete     | Thr=0.4875 | P=0.556 | R=0.086 | F1=0.149 | Cost=1379222
# W1_discrete     | Thr=0.3372 | P=0.619 | R=0.000 | F1=0.000 | Cost=412910
# W7_discrete     | Thr=0.4601 | P=0.551 | R=0.003 | F1=0.005 | Cost=672422
# W30_discrete    | Thr=0.4289 | P=0.546 | R=0.003 | F1=0.005 | Cost=474318

# %%
# OPTIMIZACIÓN DE THRESHOLDS
BEST_THRESHOLDS = {}

def objective_hgb(trial, hname="W0_discrete", lcol="y_w0",
                  gap_days=0, embargo_days=1):
    # 1. hiperparámetros propuestos por Optuna
    params = {
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.1, log=True),
        "max_leaf_nodes": trial.suggest_categorical("max_leaf_nodes", [31, 63, 127, 255]),
        "max_depth": trial.suggest_categorical("max_depth", [None, 8, 10]),
        "min_samples_leaf": trial.suggest_categorical("min_samples_leaf", [20, 50, 100, 200]),
        "l2_regularization": trial.suggest_categorical("l2_regularization", [0.0, 0.1, 1.0, 5.0]),
        "max_bins": trial.suggest_categorical("max_bins", [128, 255, 512]),
        "early_stopping": True,
        "validation_fraction": 0.1,
        "random_state": 42
    }
    """
    Función objetivo para optimizar threshold minimizando costo.
    """
        # 2. entrenar con TUS funciones
    # Opción A: si tu train_eval_horizon ya acepta kwargs del modelo:
    res = train_eval_horizon(
        hname, lcol,
        gap_before_days=gap_days,
        embargo_after_days=embargo_days,
        cost_fp=COST_FP,
        cost_fn=COST_FN,
        calib_method="isotonic",
        model_name="HistGB",
        model_kwargs=params   # <- ESTA ES LA CLAVE
    )

    # 3. devolver la métrica que estás optimizando
    oof_ap = res["HistGB"].get("oof_ap", None)
    if oof_ap is None:
        # fallback a ROC si por algo no vino AP
        oof_ap = res["HistGB"].get("oof_auc", 0.0)

    return oof_ap
    # Sugerir threshold entre 0.01 y 0.99
    threshold = trial.suggest_float('threshold', 0.01, 0.99)
    
    # Calcular métricas
    metrics = compute_metrics_at_threshold(y_true, y_proba, threshold, cost_fp, cost_fn)
    
    # Registrar métricas adicionales en el trial
    trial.set_user_attr('precision', metrics['precision'])
    trial.set_user_attr('recall', metrics['recall'])
    trial.set_user_attr('f1', metrics['f1'])
    trial.set_user_attr('cost', metrics['cost'])
    
    # Retornar costo (Optuna minimizará)
    return metrics['cost']

# Iterar sobre cada horizonte
for hname, lcol, gap_days, embargo_days in HORIZONS:
    print(f"\n--- Optimizando threshold para {hname} ---")
    
    # Obtener predicciones y labels
    X, y, feats, num_cols, cat_cols, k = get_xy_for_horizon(hname, lcol)
    
    # Verificar que el modelo existe
    if hname not in ALL_RESULTS or "HistGB" not in ALL_RESULTS[hname]:
        print(f"  No hay resultados para {hname}, saltando...")
        continue
    
    # Obtener predicciones del modelo
    model = ALL_RESULTS[hname]["HistGB"]["model"]
    y_proba = model.predict_proba(X[feats])[:, 1]
    
    # Crear study de Optuna para minimizar costo
    study = optuna.create_study(
        study_name=f"threshold_{hname}",
        direction='minimize',
        sampler=optuna.samplers.TPESampler(seed=42)
    )
    
    # Optimizar (100 trials)
    study.optimize(
        lambda trial: objective_threshold(trial, y, y_proba, cost_fp=2.0, cost_fn=2.0),
        n_trials=100,
        show_progress_bar=False
    )
    
    # Obtener mejores resultados
    best_trial = study.best_trial
    best_threshold = best_trial.params['threshold']
    best_metrics = compute_metrics_at_threshold(y, y_proba, best_threshold, 2.0, 2.0)
    
    # Guardar en estructura global
    BEST_THRESHOLDS[hname] = {
        'threshold': best_threshold,
        'precision': best_metrics['precision'],
        'recall': best_metrics['recall'],
        'f1': best_metrics['f1'],
        'cost': best_metrics['cost'],
        'confusion': {
            'tp': best_metrics['tp'],
            'fp': best_metrics['fp'],
            'fn': best_metrics['fn'],
            'tn': best_metrics['tn']
        }
    }
    
    # Imprimir resultados
    print(f"  ✓ Mejor threshold: {best_threshold:.4f}")
    print(f"    - Precision: {best_metrics['precision']:.4f}")
    print(f"    - Recall:    {best_metrics['recall']:.4f}")
    print(f"    - F1:        {best_metrics['f1']:.4f}")
    print(f"    - Costo:     {best_metrics['cost']:.2f}")

# Resumen
print("\n" + "="*80)
print("RESUMEN DE MEJORES THRESHOLDS")
print("="*80)
for hname, info in BEST_THRESHOLDS.items():
    print(f"{hname:15s} | Thr={info['threshold']:.4f} | "
          f"P={info['precision']:.3f} | R={info['recall']:.3f} | "
          f"F1={info['f1']:.3f} | Cost={info['cost']:.0f}")
# Out:
# --- Optimizando threshold para W0_discrete ---
# [I 2025-11-02 04:30:37,982] A new study created in memory with name: threshold_W0_discrete
# [I 2025-11-02 04:30:38,014] Trial 0 finished with value: 1569732.0 and parameters: {'threshold': 0.37704931647041523}. Best is trial 0 with value: 1569732.0.
# [I 2025-11-02 04:30:38,045] Trial 1 finished with value: 1403686.0 and parameters: {'threshold': 0.9417000202817178}. Best is trial 1 with value: 1403686.0.
# [I 2025-11-02 04:30:38,075] Trial 2 finished with value: 1402372.0 and parameters: {'threshold': 0.727354062975177}. Best is trial 2 with value: 1402372.0.
# [I 2025-11-02 04:30:38,106] Trial 3 finished with value: 1397322.0 and parameters: {'threshold': 0.5966853145130959}. Best is trial 3 with value: 1397322.0.
# [I 2025-11-02 04:30:38,136] Trial 4 finished with value: 2634846.0 and parameters: {'threshold': 0.1628982676335878}. Best is trial 3 with value: 1397322.0.
# [I 2025-11-02 04:30:38,166] Trial 5 finished with value: 2635052.0 and parameters: {'threshold': 0.1628746299294786}. Best is trial 3 with value: 1397322.0.
# [I 2025-11-02 04:30:38,196] Trial 6 finished with value: 3415172.0 and parameters: {'threshold': 0.06692193992483547}. Best is trial 3 with value: 1397322.0.
# [I 2025-11-02 04:30:38,226] Trial 7 finished with value: 1403686.0 and parameters: {'threshold': 0.8588526228594364}. Best is trial 3 with value: 1397322.0.
# [I 2025-11-02 04:30:38,256] Trial 8 finished with value: 1397682.0 and parameters: {'threshold': 0.5990927115083446}. Best is trial 3 with value: 1397322.0.
# [I 2025-11-02 04:30:38,285] Trial 9 finished with value: 1401838.0 and parameters: {'threshold': 0.7039111262401245}. Best is trial 3 with value: 1397322.0.
# [I 2025-11-02 04:30:38,318] Trial 10 finished with value: 1424642.0 and parameters: {'threshold': 0.4263533010733973}. Best is trial 3 with value: 1397322.0.
# [I 2025-11-02 04:30:38,351] Trial 11 finished with value: 1394718.0 and parameters: {'threshold': 0.579007446359683}. Best is trial 11 with value: 1394718.0.
# [I 2025-11-02 04:30:38,384] Trial 12 finished with value: 1385402.0 and parameters: {'threshold': 0.5251111192486895}. Best is trial 12 with value: 1385402.0.
# [I 2025-11-02 04:30:38,417] Trial 13 finished with value: 1670196.0 and parameters: {'threshold': 0.34961626754595676}. Best is trial 12 with value: 1385402.0.
# [I 2025-11-02 04:30:38,449] Trial 14 finished with value: 1385036.0 and parameters: {'threshold': 0.5232388213650043}. Best is trial 14 with value: 1385036.0.
# [I 2025-11-02 04:30:38,483] Trial 15 finished with value: 1820228.0 and parameters: {'threshold': 0.3045535265883591}. Best is trial 14 with value: 1385036.0.
# [I 2025-11-02 04:30:38,517] Trial 16 finished with value: 1402970.0 and parameters: {'threshold': 0.7445165090650132}. Best is trial 14 with value: 1385036.0.
# [I 2025-11-02 04:30:38,551] Trial 17 finished with value: 1380454.0 and parameters: {'threshold': 0.49557453615947955}. Best is trial 17 with value: 1380454.0.
# [I 2025-11-02 04:30:38,585] Trial 18 finished with value: 1384806.0 and parameters: {'threshold': 0.4617943793052285}. Best is trial 17 with value: 1380454.0.
# [I 2025-11-02 04:30:38,619] Trial 19 finished with value: 2068622.0 and parameters: {'threshold': 0.23687183471028594}. Best is trial 17 with value: 1380454.0.
# [I 2025-11-02 04:30:38,652] Trial 20 finished with value: 1397612.0 and parameters: {'threshold': 0.44590606615555384}. Best is trial 17 with value: 1380454.0.
# [I 2025-11-02 04:30:38,686] Trial 21 finished with value: 1382478.0 and parameters: {'threshold': 0.5074931404094568}. Best is trial 17 with value: 1380454.0.
# [I 2025-11-02 04:30:38,718] Trial 22 finished with value: 1384118.0 and parameters: {'threshold': 0.46309769469321255}. Best is trial 17 with value: 1380454.0.
# [I 2025-11-02 04:30:38,750] Trial 23 finished with value: 1400828.0 and parameters: {'threshold': 0.6346205974445264}. Best is trial 17 with value: 1380454.0.
# [I 2025-11-02 04:30:38,782] Trial 24 finished with value: 1914916.0 and parameters: {'threshold': 0.27421490162395007}. Best is trial 17 with value: 1380454.0.
# [I 2025-11-02 04:30:38,813] Trial 25 finished with value: 1574154.0 and parameters: {'threshold': 0.3758833581083389}. Best is trial 17 with value: 1380454.0.
# [I 2025-11-02 04:30:38,846] Trial 26 finished with value: 1382802.0 and parameters: {'threshold': 0.5100205508916368}. Best is trial 17 with value: 1380454.0.
# [I 2025-11-02 04:30:38,879] Trial 27 finished with value: 1403686.0 and parameters: {'threshold': 0.8390565101706382}. Best is trial 17 with value: 1380454.0.
# [I 2025-11-02 04:30:38,911] Trial 28 finished with value: 1401334.0 and parameters: {'threshold': 0.6704697663102177}. Best is trial 17 with value: 1380454.0.
# [I 2025-11-02 04:30:38,944] Trial 29 finished with value: 1388472.0 and parameters: {'threshold': 0.5435060869804003}. Best is trial 17 with value: 1380454.0.
# [I 2025-11-02 04:30:38,976] Trial 30 finished with value: 1513974.0 and parameters: {'threshold': 0.39233216444104524}. Best is trial 17 with value: 1380454.0.
# [I 2025-11-02 04:30:39,008] Trial 31 finished with value: 1383042.0 and parameters: {'threshold': 0.5117748258934146}. Best is trial 17 with value: 1380454.0.
# [I 2025-11-02 04:30:39,041] Trial 32 finished with value: 1383142.0 and parameters: {'threshold': 0.5125912012932524}. Best is trial 17 with value: 1380454.0.
# [I 2025-11-02 04:30:39,073] Trial 33 finished with value: 1403686.0 and parameters: {'threshold': 0.7836875249930755}. Best is trial 17 with value: 1380454.0.
# [I 2025-11-02 04:30:39,106] Trial 34 finished with value: 1400936.0 and parameters: {'threshold': 0.6372106270903992}. Best is trial 17 with value: 1380454.0.
# [I 2025-11-02 04:30:39,139] Trial 35 finished with value: 1746160.0 and parameters: {'threshold': 0.32756843592857465}. Best is trial 17 with value: 1380454.0.
# [I 2025-11-02 04:30:39,172] Trial 36 finished with value: 1396064.0 and parameters: {'threshold': 0.5879011686197605}. Best is trial 17 with value: 1380454.0.
# [I 2025-11-02 04:30:39,204] Trial 37 finished with value: 1403686.0 and parameters: {'threshold': 0.9860962011124869}. Best is trial 17 with value: 1380454.0.
# [I 2025-11-02 04:30:39,235] Trial 38 finished with value: 1476586.0 and parameters: {'threshold': 0.40419712330512536}. Best is trial 17 with value: 1380454.0.
# [I 2025-11-02 04:30:39,268] Trial 39 finished with value: 1379368.0 and parameters: {'threshold': 0.4878452869358127}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:30:39,299] Trial 40 finished with value: 2134574.0 and parameters: {'threshold': 0.22621006538985383}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:30:39,332] Trial 41 finished with value: 1387974.0 and parameters: {'threshold': 0.457308615394681}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:30:39,365] Trial 42 finished with value: 1380084.0 and parameters: {'threshold': 0.493038940912989}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:30:39,398] Trial 43 finished with value: 1392298.0 and parameters: {'threshold': 0.5642458799742982}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:30:39,430] Trial 44 finished with value: 1379604.0 and parameters: {'threshold': 0.48890285094263225}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:30:39,463] Trial 45 finished with value: 1401042.0 and parameters: {'threshold': 0.6417802115627238}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:30:39,496] Trial 46 finished with value: 1379498.0 and parameters: {'threshold': 0.4813351239405775}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:30:39,528] Trial 47 finished with value: 1618630.0 and parameters: {'threshold': 0.3636157095111002}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:30:39,562] Trial 48 finished with value: 1445036.0 and parameters: {'threshold': 0.41647363350639777}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:30:39,594] Trial 49 finished with value: 1379714.0 and parameters: {'threshold': 0.47750870114196836}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:30:39,627] Trial 50 finished with value: 1396314.0 and parameters: {'threshold': 0.5897311099040883}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:30:39,659] Trial 51 finished with value: 1380414.0 and parameters: {'threshold': 0.47343369907697586}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:30:39,692] Trial 52 finished with value: 1381506.0 and parameters: {'threshold': 0.4697477788891925}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:30:39,724] Trial 53 finished with value: 1419550.0 and parameters: {'threshold': 0.4294495320996033}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:30:39,756] Trial 54 finished with value: 1390722.0 and parameters: {'threshold': 0.5557215252028843}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:30:39,787] Trial 55 finished with value: 1379514.0 and parameters: {'threshold': 0.4808495346805836}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:30:39,819] Trial 56 finished with value: 1746192.0 and parameters: {'threshold': 0.32755417597800296}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:30:39,852] Trial 57 finished with value: 2989152.0 and parameters: {'threshold': 0.12213006114694941}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:30:39,885] Trial 58 finished with value: 3449024.0 and parameters: {'threshold': 0.02076940545889583}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:30:39,917] Trial 59 finished with value: 1399900.0 and parameters: {'threshold': 0.61884467933442}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:30:39,950] Trial 60 finished with value: 1401638.0 and parameters: {'threshold': 0.6935846128814009}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:30:39,983] Trial 61 finished with value: 1380470.0 and parameters: {'threshold': 0.47297962935814025}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:30:40,015] Trial 62 finished with value: 1389380.0 and parameters: {'threshold': 0.5480576758637232}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:30:40,047] Trial 63 finished with value: 1379610.0 and parameters: {'threshold': 0.48868754124265523}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:30:40,080] Trial 64 finished with value: 1409862.0 and parameters: {'threshold': 0.43572682939044816}. Best is trial 39 with value: 1379368.0.
# [I 2025-11-02 04:30:40,112] Trial 65 finished with value: 1379258.0 and parameters: {'threshold': 0.48566645746996934}. Best is trial 65 with value: 1379258.0.
# [I 2025-11-02 04:30:40,145] Trial 66 finished with value: 1469062.0 and parameters: {'threshold': 0.4067603287012668}. Best is trial 65 with value: 1379258.0.
# [I 2025-11-02 04:30:40,178] Trial 67 finished with value: 1387272.0 and parameters: {'threshold': 0.5364783189873712}. Best is trial 65 with value: 1379258.0.
# [I 2025-11-02 04:30:40,210] Trial 68 finished with value: 1403074.0 and parameters: {'threshold': 0.4409527726713359}. Best is trial 65 with value: 1379258.0.
# [I 2025-11-02 04:30:40,244] Trial 69 finished with value: 1544562.0 and parameters: {'threshold': 0.3836984558824349}. Best is trial 65 with value: 1379258.0.
# [I 2025-11-02 04:30:40,278] Trial 70 finished with value: 1379222.0 and parameters: {'threshold': 0.4874831716958652}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:30:40,313] Trial 71 finished with value: 1379226.0 and parameters: {'threshold': 0.4869262864790581}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:30:40,347] Trial 72 finished with value: 1385946.0 and parameters: {'threshold': 0.5286668928108579}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:30:40,380] Trial 73 finished with value: 1676012.0 and parameters: {'threshold': 0.3481283681036119}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:30:40,414] Trial 74 finished with value: 1382752.0 and parameters: {'threshold': 0.5096449917192872}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:30:40,448] Trial 75 finished with value: 1399038.0 and parameters: {'threshold': 0.6108814052363454}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:30:40,482] Trial 76 finished with value: 1394536.0 and parameters: {'threshold': 0.5779531254567483}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:30:40,516] Trial 77 finished with value: 1379596.0 and parameters: {'threshold': 0.4893286618854822}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:30:40,551] Trial 78 finished with value: 1400154.0 and parameters: {'threshold': 0.4438124945013278}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:30:40,584] Trial 79 finished with value: 1390846.0 and parameters: {'threshold': 0.5566585486869664}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:30:40,617] Trial 80 finished with value: 1439762.0 and parameters: {'threshold': 0.41877544337238454}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:30:40,651] Trial 81 finished with value: 1380100.0 and parameters: {'threshold': 0.4936690123925438}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:30:40,684] Trial 82 finished with value: 1381044.0 and parameters: {'threshold': 0.500049845347165}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:30:40,717] Trial 83 finished with value: 1386106.0 and parameters: {'threshold': 0.5295059395487278}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:30:40,751] Trial 84 finished with value: 1379224.0 and parameters: {'threshold': 0.48582362081253005}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:30:40,785] Trial 85 finished with value: 1519614.0 and parameters: {'threshold': 0.3906980287101552}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:30:40,818] Trial 86 finished with value: 1388058.0 and parameters: {'threshold': 0.4569361092673472}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:30:40,853] Trial 87 finished with value: 1393922.0 and parameters: {'threshold': 0.5735574217390992}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:30:40,886] Trial 88 finished with value: 1893408.0 and parameters: {'threshold': 0.28103008899744863}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:30:40,920] Trial 89 finished with value: 1386158.0 and parameters: {'threshold': 0.5301165888376261}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:30:40,954] Trial 90 finished with value: 1648614.0 and parameters: {'threshold': 0.3555184597800873}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:30:40,988] Trial 91 finished with value: 1379894.0 and parameters: {'threshold': 0.4908671570709244}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:30:41,021] Trial 92 finished with value: 1381178.0 and parameters: {'threshold': 0.4706125546300934}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:30:41,054] Trial 93 finished with value: 1421328.0 and parameters: {'threshold': 0.4283467024468726}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:30:41,088] Trial 94 finished with value: 1381530.0 and parameters: {'threshold': 0.5024458169256771}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:30:41,122] Trial 95 finished with value: 1395904.0 and parameters: {'threshold': 0.4473785807761995}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:30:41,157] Trial 96 finished with value: 1379702.0 and parameters: {'threshold': 0.47784851665942873}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:30:41,191] Trial 97 finished with value: 1384086.0 and parameters: {'threshold': 0.5181174256467497}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:30:41,226] Trial 98 finished with value: 1470244.0 and parameters: {'threshold': 0.4063551599687303}. Best is trial 70 with value: 1379222.0.
# [I 2025-11-02 04:30:41,259] Trial 99 finished with value: 1390086.0 and parameters: {'threshold': 0.5515069477668297}. Best is trial 70 with value: 1379222.0.
#   ✓ Mejor threshold: 0.4875
#     - Precision: 0.5563
#     - Recall:    0.0860
#     - F1:        0.1490
#     - Costo:     1379222.00
#
# --- Optimizando threshold para W1_discrete ---
# [I 2025-11-02 04:31:24,162] A new study created in memory with name: threshold_W1_discrete
# [I 2025-11-02 04:31:24,194] Trial 0 finished with value: 412920.0 and parameters: {'threshold': 0.37704931647041523}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:31:24,224] Trial 1 finished with value: 412920.0 and parameters: {'threshold': 0.9417000202817178}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:31:24,254] Trial 2 finished with value: 412920.0 and parameters: {'threshold': 0.727354062975177}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:31:24,284] Trial 3 finished with value: 412920.0 and parameters: {'threshold': 0.5966853145130959}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:31:24,314] Trial 4 finished with value: 630320.0 and parameters: {'threshold': 0.1628982676335878}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:31:24,345] Trial 5 finished with value: 630508.0 and parameters: {'threshold': 0.1628746299294786}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:31:24,375] Trial 6 finished with value: 2673744.0 and parameters: {'threshold': 0.06692193992483547}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:31:24,405] Trial 7 finished with value: 412920.0 and parameters: {'threshold': 0.8588526228594364}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:31:24,435] Trial 8 finished with value: 412920.0 and parameters: {'threshold': 0.5990927115083446}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:31:24,464] Trial 9 finished with value: 412920.0 and parameters: {'threshold': 0.7039111262401245}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:31:24,495] Trial 10 finished with value: 412920.0 and parameters: {'threshold': 0.3769870974683338}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:31:24,528] Trial 11 finished with value: 412920.0 and parameters: {'threshold': 0.3922180649768887}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:31:24,560] Trial 12 finished with value: 412920.0 and parameters: {'threshold': 0.9601463685721084}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:31:24,593] Trial 13 finished with value: 412922.0 and parameters: {'threshold': 0.3499138735784894}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:31:24,626] Trial 14 finished with value: 412920.0 and parameters: {'threshold': 0.4969220260448285}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:31:24,658] Trial 15 finished with value: 412920.0 and parameters: {'threshold': 0.852759915379516}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:31:24,691] Trial 16 finished with value: 414238.0 and parameters: {'threshold': 0.26033458958989486}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:31:24,723] Trial 17 finished with value: 412920.0 and parameters: {'threshold': 0.5127406936978046}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:31:24,755] Trial 18 finished with value: 412920.0 and parameters: {'threshold': 0.7397676814617209}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:31:24,788] Trial 19 finished with value: 412920.0 and parameters: {'threshold': 0.9858797125799896}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:31:24,820] Trial 20 finished with value: 413064.0 and parameters: {'threshold': 0.28514573515491004}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:31:24,853] Trial 21 finished with value: 412920.0 and parameters: {'threshold': 0.7652346217266811}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:31:24,884] Trial 22 finished with value: 412920.0 and parameters: {'threshold': 0.9097926711983474}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:31:24,917] Trial 23 finished with value: 412920.0 and parameters: {'threshold': 0.6543957292102196}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:31:24,949] Trial 24 finished with value: 412920.0 and parameters: {'threshold': 0.8091288418394447}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:31:24,981] Trial 25 finished with value: 412920.0 and parameters: {'threshold': 0.5004283503698654}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:31:25,013] Trial 26 finished with value: 412920.0 and parameters: {'threshold': 0.9072939149284966}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:31:25,044] Trial 27 finished with value: 412920.0 and parameters: {'threshold': 0.661807144988821}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:31:25,075] Trial 28 finished with value: 412920.0 and parameters: {'threshold': 0.5581861761306598}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:31:25,107] Trial 29 finished with value: 412920.0 and parameters: {'threshold': 0.44091680408362666}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:31:25,138] Trial 30 finished with value: 412920.0 and parameters: {'threshold': 0.8012666340035751}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:31:25,170] Trial 31 finished with value: 412920.0 and parameters: {'threshold': 0.6224780382915017}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:31:25,202] Trial 32 finished with value: 412920.0 and parameters: {'threshold': 0.7061518848269643}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:31:25,235] Trial 33 finished with value: 414588.0 and parameters: {'threshold': 0.2562447179047049}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:31:25,268] Trial 34 finished with value: 1251776.0 and parameters: {'threshold': 0.11653480164462432}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:31:25,302] Trial 35 finished with value: 412920.0 and parameters: {'threshold': 0.5622274689942929}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:31:25,335] Trial 36 finished with value: 412920.0 and parameters: {'threshold': 0.4448185363654171}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:31:25,370] Trial 37 finished with value: 412920.0 and parameters: {'threshold': 0.5798701631864945}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:31:25,403] Trial 38 finished with value: 528552.0 and parameters: {'threshold': 0.17777982050805624}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:31:25,436] Trial 39 finished with value: 3690014.0 and parameters: {'threshold': 0.03150756826512785}. Best is trial 0 with value: 412920.0.
# [I 2025-11-02 04:31:25,471] Trial 40 finished with value: 412910.0 and parameters: {'threshold': 0.3371779109860835}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:25,504] Trial 41 finished with value: 412934.0 and parameters: {'threshold': 0.3086437081204995}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:25,539] Trial 42 finished with value: 412920.0 and parameters: {'threshold': 0.41360900722607097}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:25,572] Trial 43 finished with value: 451212.0 and parameters: {'threshold': 0.1981308401755637}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:25,605] Trial 44 finished with value: 412916.0 and parameters: {'threshold': 0.3355047643761011}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:25,638] Trial 45 finished with value: 412926.0 and parameters: {'threshold': 0.3563805331340178}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:25,670] Trial 46 finished with value: 434260.0 and parameters: {'threshold': 0.20800612736200377}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:25,702] Trial 47 finished with value: 412916.0 and parameters: {'threshold': 0.32406522294745227}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:25,734] Trial 48 finished with value: 412928.0 and parameters: {'threshold': 0.31255898877549704}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:25,767] Trial 49 finished with value: 412920.0 and parameters: {'threshold': 0.446452310930668}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:25,799] Trial 50 finished with value: 417548.0 and parameters: {'threshold': 0.23290170957461118}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:25,831] Trial 51 finished with value: 412916.0 and parameters: {'threshold': 0.33477726106095906}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:25,862] Trial 52 finished with value: 412916.0 and parameters: {'threshold': 0.32456313015496846}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:25,893] Trial 53 finished with value: 412916.0 and parameters: {'threshold': 0.33496376893695595}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:25,925] Trial 54 finished with value: 412912.0 and parameters: {'threshold': 0.3267525760260042}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:25,956] Trial 55 finished with value: 1040420.0 and parameters: {'threshold': 0.128201633934934}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:25,988] Trial 56 finished with value: 412918.0 and parameters: {'threshold': 0.38175889298386034}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:26,019] Trial 57 finished with value: 413110.0 and parameters: {'threshold': 0.2822471645846949}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:26,051] Trial 58 finished with value: 412920.0 and parameters: {'threshold': 0.4189636951160417}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:26,082] Trial 59 finished with value: 412922.0 and parameters: {'threshold': 0.3501655885227264}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:26,112] Trial 60 finished with value: 412920.0 and parameters: {'threshold': 0.4741470374021109}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:26,145] Trial 61 finished with value: 412920.0 and parameters: {'threshold': 0.3203058019791616}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:26,176] Trial 62 finished with value: 416490.0 and parameters: {'threshold': 0.23759309119064964}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:26,207] Trial 63 finished with value: 412916.0 and parameters: {'threshold': 0.3323080748528673}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:26,238] Trial 64 finished with value: 413056.0 and parameters: {'threshold': 0.28595872743217865}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:26,269] Trial 65 finished with value: 412920.0 and parameters: {'threshold': 0.37754914970042264}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:26,300] Trial 66 finished with value: 412920.0 and parameters: {'threshold': 0.40181288856593783}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:26,332] Trial 67 finished with value: 412916.0 and parameters: {'threshold': 0.34769729371691416}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:26,364] Trial 68 finished with value: 413262.0 and parameters: {'threshold': 0.2767067165571231}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:26,395] Trial 69 finished with value: 856122.0 and parameters: {'threshold': 0.14076605787545607}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:26,426] Trial 70 finished with value: 412920.0 and parameters: {'threshold': 0.5267970496328767}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:26,457] Trial 71 finished with value: 412914.0 and parameters: {'threshold': 0.3254194418766005}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:26,489] Trial 72 finished with value: 412936.0 and parameters: {'threshold': 0.30756600240747306}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:26,520] Trial 73 finished with value: 412924.0 and parameters: {'threshold': 0.362198222942248}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:26,552] Trial 74 finished with value: 415834.0 and parameters: {'threshold': 0.24201494685236435}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:26,585] Trial 75 finished with value: 412920.0 and parameters: {'threshold': 0.4775385805478367}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:26,620] Trial 76 finished with value: 412920.0 and parameters: {'threshold': 0.38971133748468867}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:26,653] Trial 77 finished with value: 428516.0 and parameters: {'threshold': 0.2135837127124791}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:26,686] Trial 78 finished with value: 412912.0 and parameters: {'threshold': 0.3274352831505749}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:26,719] Trial 79 finished with value: 413896.0 and parameters: {'threshold': 0.26578182441397374}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:26,751] Trial 80 finished with value: 412920.0 and parameters: {'threshold': 0.42623061590680933}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:26,784] Trial 81 finished with value: 412916.0 and parameters: {'threshold': 0.33295836650062843}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:26,817] Trial 82 finished with value: 412962.0 and parameters: {'threshold': 0.2977625776249586}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:26,850] Trial 83 finished with value: 412916.0 and parameters: {'threshold': 0.33206585168043934}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:26,882] Trial 84 finished with value: 412922.0 and parameters: {'threshold': 0.3680430618523004}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:26,914] Trial 85 finished with value: 412920.0 and parameters: {'threshold': 0.39672875486339804}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:26,948] Trial 86 finished with value: 414266.0 and parameters: {'threshold': 0.26007620486908245}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:26,981] Trial 87 finished with value: 532718.0 and parameters: {'threshold': 0.1770520529614707}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:27,015] Trial 88 finished with value: 412968.0 and parameters: {'threshold': 0.29481711312344383}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:27,048] Trial 89 finished with value: 412920.0 and parameters: {'threshold': 0.4580954155853907}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:27,081] Trial 90 finished with value: 420884.0 and parameters: {'threshold': 0.2237671955730493}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:27,113] Trial 91 finished with value: 412916.0 and parameters: {'threshold': 0.3336028742826056}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:27,146] Trial 92 finished with value: 412916.0 and parameters: {'threshold': 0.3358239156277083}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:27,179] Trial 93 finished with value: 412928.0 and parameters: {'threshold': 0.31647256619360387}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:27,210] Trial 94 finished with value: 412924.0 and parameters: {'threshold': 0.3641506723623052}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:27,242] Trial 95 finished with value: 414606.0 and parameters: {'threshold': 0.2560106126663054}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:27,274] Trial 96 finished with value: 412920.0 and parameters: {'threshold': 0.4118014839767165}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:27,306] Trial 97 finished with value: 412922.0 and parameters: {'threshold': 0.34996358664809296}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:27,339] Trial 98 finished with value: 412958.0 and parameters: {'threshold': 0.299159506905468}. Best is trial 40 with value: 412910.0.
# [I 2025-11-02 04:31:27,372] Trial 99 finished with value: 412920.0 and parameters: {'threshold': 0.37485699421985313}. Best is trial 40 with value: 412910.0.
#   ✓ Mejor threshold: 0.3372
#     - Precision: 0.6190
#     - Recall:    0.0001
#     - F1:        0.0001
#     - Costo:     412910.00
#
# --- Optimizando threshold para W7_discrete ---
# [I 2025-11-02 04:32:09,725] A new study created in memory with name: threshold_W7_discrete
# [I 2025-11-02 04:32:09,756] Trial 0 finished with value: 680602.0 and parameters: {'threshold': 0.37704931647041523}. Best is trial 0 with value: 680602.0.
# [I 2025-11-02 04:32:09,784] Trial 1 finished with value: 672762.0 and parameters: {'threshold': 0.9417000202817178}. Best is trial 1 with value: 672762.0.
# [I 2025-11-02 04:32:09,812] Trial 2 finished with value: 672762.0 and parameters: {'threshold': 0.727354062975177}. Best is trial 1 with value: 672762.0.
# [I 2025-11-02 04:32:09,841] Trial 3 finished with value: 672762.0 and parameters: {'threshold': 0.5966853145130959}. Best is trial 1 with value: 672762.0.
# [I 2025-11-02 04:32:09,869] Trial 4 finished with value: 1488050.0 and parameters: {'threshold': 0.1628982676335878}. Best is trial 1 with value: 672762.0.
# [I 2025-11-02 04:32:09,896] Trial 5 finished with value: 1488520.0 and parameters: {'threshold': 0.1628746299294786}. Best is trial 1 with value: 672762.0.
# [I 2025-11-02 04:32:09,925] Trial 6 finished with value: 3181882.0 and parameters: {'threshold': 0.06692193992483547}. Best is trial 1 with value: 672762.0.
# [I 2025-11-02 04:32:09,953] Trial 7 finished with value: 672762.0 and parameters: {'threshold': 0.8588526228594364}. Best is trial 1 with value: 672762.0.
# [I 2025-11-02 04:32:09,981] Trial 8 finished with value: 672762.0 and parameters: {'threshold': 0.5990927115083446}. Best is trial 1 with value: 672762.0.
# [I 2025-11-02 04:32:10,009] Trial 9 finished with value: 672762.0 and parameters: {'threshold': 0.7039111262401245}. Best is trial 1 with value: 672762.0.
# [I 2025-11-02 04:32:10,040] Trial 10 finished with value: 672762.0 and parameters: {'threshold': 0.9699049477268573}. Best is trial 1 with value: 672762.0.
# [I 2025-11-02 04:32:10,070] Trial 11 finished with value: 672762.0 and parameters: {'threshold': 0.8029026582945012}. Best is trial 1 with value: 672762.0.
# [I 2025-11-02 04:32:10,101] Trial 12 finished with value: 672762.0 and parameters: {'threshold': 0.9694809150597243}. Best is trial 1 with value: 672762.0.
# [I 2025-11-02 04:32:10,132] Trial 13 finished with value: 672494.0 and parameters: {'threshold': 0.4556837729838583}. Best is trial 13 with value: 672494.0.
# [I 2025-11-02 04:32:10,162] Trial 14 finished with value: 674800.0 and parameters: {'threshold': 0.3992648948371728}. Best is trial 13 with value: 672494.0.
# [I 2025-11-02 04:32:10,193] Trial 15 finished with value: 677036.0 and parameters: {'threshold': 0.38827812518374166}. Best is trial 13 with value: 672494.0.
# [I 2025-11-02 04:32:10,224] Trial 16 finished with value: 672738.0 and parameters: {'threshold': 0.5109441875173779}. Best is trial 13 with value: 672494.0.
# [I 2025-11-02 04:32:10,255] Trial 17 finished with value: 672652.0 and parameters: {'threshold': 0.4885176481810135}. Best is trial 13 with value: 672494.0.
# [I 2025-11-02 04:32:10,285] Trial 18 finished with value: 835348.0 and parameters: {'threshold': 0.2467348166735741}. Best is trial 13 with value: 672494.0.
# [I 2025-11-02 04:32:10,316] Trial 19 finished with value: 672740.0 and parameters: {'threshold': 0.5036190340942092}. Best is trial 13 with value: 672494.0.
# [I 2025-11-02 04:32:10,347] Trial 20 finished with value: 775004.0 and parameters: {'threshold': 0.28514573515491004}. Best is trial 13 with value: 672494.0.
# [I 2025-11-02 04:32:10,378] Trial 21 finished with value: 672762.0 and parameters: {'threshold': 0.5330243973584159}. Best is trial 13 with value: 672494.0.
# [I 2025-11-02 04:32:10,408] Trial 22 finished with value: 672542.0 and parameters: {'threshold': 0.4432957706101451}. Best is trial 13 with value: 672494.0.
# [I 2025-11-02 04:32:10,438] Trial 23 finished with value: 673588.0 and parameters: {'threshold': 0.4128151676525437}. Best is trial 13 with value: 672494.0.
# [I 2025-11-02 04:32:10,470] Trial 24 finished with value: 672762.0 and parameters: {'threshold': 0.6308683973855311}. Best is trial 13 with value: 672494.0.
# [I 2025-11-02 04:32:10,501] Trial 25 finished with value: 767636.0 and parameters: {'threshold': 0.2912401222313599}. Best is trial 13 with value: 672494.0.
# [I 2025-11-02 04:32:10,533] Trial 26 finished with value: 672490.0 and parameters: {'threshold': 0.4550828548506232}. Best is trial 26 with value: 672490.0.
# [I 2025-11-02 04:32:10,564] Trial 27 finished with value: 672520.0 and parameters: {'threshold': 0.44418971442151206}. Best is trial 26 with value: 672490.0.
# [I 2025-11-02 04:32:10,595] Trial 28 finished with value: 711422.0 and parameters: {'threshold': 0.3388819433570871}. Best is trial 26 with value: 672490.0.
# [I 2025-11-02 04:32:10,626] Trial 29 finished with value: 672762.0 and parameters: {'threshold': 0.6782587178118477}. Best is trial 26 with value: 672490.0.
# [I 2025-11-02 04:32:10,656] Trial 30 finished with value: 721348.0 and parameters: {'threshold': 0.33062088585680877}. Best is trial 26 with value: 672490.0.
# [I 2025-11-02 04:32:10,687] Trial 31 finished with value: 672526.0 and parameters: {'threshold': 0.47236231227745307}. Best is trial 26 with value: 672490.0.
# [I 2025-11-02 04:32:10,718] Trial 32 finished with value: 672432.0 and parameters: {'threshold': 0.46080946923503696}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:10,748] Trial 33 finished with value: 672762.0 and parameters: {'threshold': 0.5521923539065368}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:10,779] Trial 34 finished with value: 907270.0 and parameters: {'threshold': 0.22035812890601478}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:10,811] Trial 35 finished with value: 672506.0 and parameters: {'threshold': 0.45034141248062565}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:10,842] Trial 36 finished with value: 672762.0 and parameters: {'threshold': 0.588334914428812}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:10,873] Trial 37 finished with value: 693748.0 and parameters: {'threshold': 0.3555654191966984}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:10,904] Trial 38 finished with value: 672762.0 and parameters: {'threshold': 0.6479954871081627}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:10,935] Trial 39 finished with value: 672762.0 and parameters: {'threshold': 0.7510246441752109}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:10,966] Trial 40 finished with value: 3205110.0 and parameters: {'threshold': 0.06558370383922896}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:10,997] Trial 41 finished with value: 672506.0 and parameters: {'threshold': 0.45595274156148236}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:11,027] Trial 42 finished with value: 672762.0 and parameters: {'threshold': 0.5634907252154275}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:11,058] Trial 43 finished with value: 672556.0 and parameters: {'threshold': 0.44298523480234403}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:11,089] Trial 44 finished with value: 672500.0 and parameters: {'threshold': 0.46939946212814293}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:11,120] Trial 45 finished with value: 1429602.0 and parameters: {'threshold': 0.16634028034070986}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:11,150] Trial 46 finished with value: 677144.0 and parameters: {'threshold': 0.38799222508805403}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:11,183] Trial 47 finished with value: 748638.0 and parameters: {'threshold': 0.30737737487078676}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:11,214] Trial 48 finished with value: 672750.0 and parameters: {'threshold': 0.5171551873024016}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:11,246] Trial 49 finished with value: 672762.0 and parameters: {'threshold': 0.61728218129514}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:11,277] Trial 50 finished with value: 673446.0 and parameters: {'threshold': 0.414478471937744}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:11,309] Trial 51 finished with value: 672616.0 and parameters: {'threshold': 0.4793765754187904}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:11,341] Trial 52 finished with value: 672496.0 and parameters: {'threshold': 0.4565850324022589}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:11,372] Trial 53 finished with value: 672762.0 and parameters: {'threshold': 0.5688104652276321}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:11,403] Trial 54 finished with value: 684496.0 and parameters: {'threshold': 0.36915260525930343}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:11,434] Trial 55 finished with value: 672752.0 and parameters: {'threshold': 0.5235440657018331}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:11,464] Trial 56 finished with value: 672646.0 and parameters: {'threshold': 0.48641122755021515}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:11,496] Trial 57 finished with value: 673230.0 and parameters: {'threshold': 0.4185099095186221}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:11,527] Trial 58 finished with value: 4053764.0 and parameters: {'threshold': 0.02076940545889583}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:11,559] Trial 59 finished with value: 672762.0 and parameters: {'threshold': 0.5356215348616298}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:11,590] Trial 60 finished with value: 680378.0 and parameters: {'threshold': 0.37756057406670374}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:11,622] Trial 61 finished with value: 672482.0 and parameters: {'threshold': 0.4514255056301712}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:11,652] Trial 62 finished with value: 673686.0 and parameters: {'threshold': 0.41094002216958936}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:11,683] Trial 63 finished with value: 672484.0 and parameters: {'threshold': 0.4492516341349964}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:11,714] Trial 64 finished with value: 672726.0 and parameters: {'threshold': 0.5025030100058795}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:11,744] Trial 65 finished with value: 722600.0 and parameters: {'threshold': 0.3294980080706059}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:11,775] Trial 66 finished with value: 847822.0 and parameters: {'threshold': 0.24052425321773027}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:11,806] Trial 67 finished with value: 672718.0 and parameters: {'threshold': 0.4330044011493486}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:11,837] Trial 68 finished with value: 672492.0 and parameters: {'threshold': 0.4692726670587507}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:11,868] Trial 69 finished with value: 672762.0 and parameters: {'threshold': 0.5864761665228987}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:11,898] Trial 70 finished with value: 692798.0 and parameters: {'threshold': 0.35668571934261856}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:11,931] Trial 71 finished with value: 672464.0 and parameters: {'threshold': 0.4645622407664017}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:11,963] Trial 72 finished with value: 672688.0 and parameters: {'threshold': 0.4956277930779522}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:11,995] Trial 73 finished with value: 675564.0 and parameters: {'threshold': 0.394824322491873}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:12,029] Trial 74 finished with value: 672762.0 and parameters: {'threshold': 0.8632154411289008}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:12,061] Trial 75 finished with value: 672762.0 and parameters: {'threshold': 0.5465752139762868}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:12,093] Trial 76 finished with value: 672454.0 and parameters: {'threshold': 0.4624020055142569}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:12,125] Trial 77 finished with value: 672990.0 and parameters: {'threshold': 0.4245273595212899}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:12,158] Trial 78 finished with value: 672560.0 and parameters: {'threshold': 0.4748398042214953}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:12,191] Trial 79 finished with value: 672746.0 and parameters: {'threshold': 0.5117567997649142}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:12,222] Trial 80 finished with value: 736380.0 and parameters: {'threshold': 0.3179021131088514}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:12,255] Trial 81 finished with value: 672570.0 and parameters: {'threshold': 0.44275171788589557}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:12,287] Trial 82 finished with value: 672582.0 and parameters: {'threshold': 0.47600651562625446}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:12,319] Trial 83 finished with value: 672502.0 and parameters: {'threshold': 0.45576407708689404}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:12,351] Trial 84 finished with value: 675294.0 and parameters: {'threshold': 0.3965266613579287}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:12,383] Trial 85 finished with value: 672762.0 and parameters: {'threshold': 0.5334593493583364}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:12,415] Trial 86 finished with value: 702064.0 and parameters: {'threshold': 0.34697629501616656}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:12,447] Trial 87 finished with value: 672762.0 and parameters: {'threshold': 0.573009096543195}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:12,479] Trial 88 finished with value: 672704.0 and parameters: {'threshold': 0.4988234953965806}. Best is trial 32 with value: 672432.0.
# [I 2025-11-02 04:32:12,511] Trial 89 finished with value: 672422.0 and parameters: {'threshold': 0.4601283184863986}. Best is trial 89 with value: 672422.0.
# [I 2025-11-02 04:32:12,545] Trial 90 finished with value: 682610.0 and parameters: {'threshold': 0.3726301474689337}. Best is trial 89 with value: 672422.0.
# [I 2025-11-02 04:32:12,578] Trial 91 finished with value: 672910.0 and parameters: {'threshold': 0.4275358752764036}. Best is trial 89 with value: 672422.0.
# [I 2025-11-02 04:32:12,611] Trial 92 finished with value: 672464.0 and parameters: {'threshold': 0.4653180815541249}. Best is trial 89 with value: 672422.0.
# [I 2025-11-02 04:32:12,643] Trial 93 finished with value: 674778.0 and parameters: {'threshold': 0.3993642001488825}. Best is trial 89 with value: 672422.0.
# [I 2025-11-02 04:32:12,675] Trial 94 finished with value: 672754.0 and parameters: {'threshold': 0.5200865811358155}. Best is trial 89 with value: 672422.0.
# [I 2025-11-02 04:32:12,707] Trial 95 finished with value: 672468.0 and parameters: {'threshold': 0.4646192604759062}. Best is trial 89 with value: 672422.0.
# [I 2025-11-02 04:32:12,738] Trial 96 finished with value: 672476.0 and parameters: {'threshold': 0.4682790805203332}. Best is trial 89 with value: 672422.0.
# [I 2025-11-02 04:32:12,770] Trial 97 finished with value: 672762.0 and parameters: {'threshold': 0.5447561358554981}. Best is trial 89 with value: 672422.0.
# [I 2025-11-02 04:32:12,801] Trial 98 finished with value: 672762.0 and parameters: {'threshold': 0.6174109400984582}. Best is trial 89 with value: 672422.0.
# [I 2025-11-02 04:32:12,833] Trial 99 finished with value: 672500.0 and parameters: {'threshold': 0.4525858851407162}. Best is trial 89 with value: 672422.0.
#   ✓ Mejor threshold: 0.4601
# ...
# [I 2025-11-02 04:32:55,300] Trial 3 finished with value: 474526.0 and parameters: {'threshold': 0.5966853145130959}. Best is trial 1 with value: 474526.0.
# [I 2025-11-02 04:32:55,329] Trial 4 finished with value: 760316.0 and parameters: {'threshold': 0.1628982676335878}. Best is trial 1 with value: 474526.0.
# [I 2025-11-02 04:32:55,357] Trial 5 finished with value: 760418.0 and parameters: {'threshold': 0.1628746299294786}. Best is trial 1 with value: 474526.0.
# [I 2025-11-02 04:32:55,386] Trial 6 finished with value: 2931724.0 and parameters: {'threshold': 0.06692193992483547}. Best is trial 1 with value: 474526.0.
# [I 2025-11-02 04:32:55,415] Trial 7 finished with value: 474526.0 and parameters: {'threshold': 0.8588526228594364}. Best is trial 1 with value: 474526.0.
# [I 2025-11-02 04:32:55,444] Trial 8 finished with value: 474526.0 and parameters: {'threshold': 0.5990927115083446}. Best is trial 1 with value: 474526.0.
# [I 2025-11-02 04:32:55,472] Trial 9 finished with value: 474526.0 and parameters: {'threshold': 0.7039111262401245}. Best is trial 1 with value: 474526.0.
# [I 2025-11-02 04:32:55,503] Trial 10 finished with value: 474526.0 and parameters: {'threshold': 0.9699049477268573}. Best is trial 1 with value: 474526.0.
# [I 2025-11-02 04:32:55,534] Trial 11 finished with value: 474526.0 and parameters: {'threshold': 0.8029026582945012}. Best is trial 1 with value: 474526.0.
# [I 2025-11-02 04:32:55,564] Trial 12 finished with value: 474526.0 and parameters: {'threshold': 0.9694809150597243}. Best is trial 1 with value: 474526.0.
# [I 2025-11-02 04:32:55,594] Trial 13 finished with value: 474336.0 and parameters: {'threshold': 0.4556837729838583}. Best is trial 13 with value: 474336.0.
# [I 2025-11-02 04:32:55,625] Trial 14 finished with value: 474574.0 and parameters: {'threshold': 0.3992648948371728}. Best is trial 13 with value: 474336.0.
# [I 2025-11-02 04:32:55,655] Trial 15 finished with value: 474792.0 and parameters: {'threshold': 0.38827812518374166}. Best is trial 13 with value: 474336.0.
# [I 2025-11-02 04:32:55,686] Trial 16 finished with value: 474448.0 and parameters: {'threshold': 0.5109441875173779}. Best is trial 13 with value: 474336.0.
# [I 2025-11-02 04:32:55,717] Trial 17 finished with value: 474370.0 and parameters: {'threshold': 0.4885176481810135}. Best is trial 13 with value: 474336.0.
# [I 2025-11-02 04:32:55,747] Trial 18 finished with value: 549238.0 and parameters: {'threshold': 0.2467348166735741}. Best is trial 13 with value: 474336.0.
# [I 2025-11-02 04:32:55,777] Trial 19 finished with value: 474434.0 and parameters: {'threshold': 0.5036190340942092}. Best is trial 13 with value: 474336.0.
# [I 2025-11-02 04:32:55,808] Trial 20 finished with value: 500194.0 and parameters: {'threshold': 0.28514573515491004}. Best is trial 13 with value: 474336.0.
# [I 2025-11-02 04:32:55,840] Trial 21 finished with value: 474348.0 and parameters: {'threshold': 0.4829328591232125}. Best is trial 13 with value: 474336.0.
# [I 2025-11-02 04:32:55,872] Trial 22 finished with value: 474526.0 and parameters: {'threshold': 0.6183642641978561}. Best is trial 13 with value: 474336.0.
# [I 2025-11-02 04:32:55,904] Trial 23 finished with value: 474330.0 and parameters: {'threshold': 0.45039138676796436}. Best is trial 23 with value: 474330.0.
# [I 2025-11-02 04:32:55,936] Trial 24 finished with value: 497990.0 and parameters: {'threshold': 0.2882661225273463}. Best is trial 23 with value: 474330.0.
# [I 2025-11-02 04:32:55,967] Trial 25 finished with value: 474352.0 and parameters: {'threshold': 0.46890935409974194}. Best is trial 23 with value: 474330.0.
# [I 2025-11-02 04:32:55,998] Trial 26 finished with value: 474352.0 and parameters: {'threshold': 0.4158097954331593}. Best is trial 23 with value: 474330.0.
# [I 2025-11-02 04:32:56,030] Trial 27 finished with value: 474522.0 and parameters: {'threshold': 0.565376868020081}. Best is trial 23 with value: 474330.0.
# [I 2025-11-02 04:32:56,061] Trial 28 finished with value: 474526.0 and parameters: {'threshold': 0.6922143212557289}. Best is trial 23 with value: 474330.0.
# [I 2025-11-02 04:32:56,091] Trial 29 finished with value: 475408.0 and parameters: {'threshold': 0.36780562988123705}. Best is trial 23 with value: 474330.0.
# [I 2025-11-02 04:32:56,122] Trial 30 finished with value: 479624.0 and parameters: {'threshold': 0.33633576799996234}. Best is trial 23 with value: 474330.0.
# [I 2025-11-02 04:32:56,153] Trial 31 finished with value: 474358.0 and parameters: {'threshold': 0.47236231227745307}. Best is trial 23 with value: 474330.0.
# [I 2025-11-02 04:32:56,184] Trial 32 finished with value: 474358.0 and parameters: {'threshold': 0.46933111451008536}. Best is trial 23 with value: 474330.0.
# [I 2025-11-02 04:32:56,215] Trial 33 finished with value: 474516.0 and parameters: {'threshold': 0.5455508166300368}. Best is trial 23 with value: 474330.0.
# [I 2025-11-02 04:32:56,246] Trial 34 finished with value: 474526.0 and parameters: {'threshold': 0.6250900863508307}. Best is trial 23 with value: 474330.0.
# [I 2025-11-02 04:32:56,277] Trial 35 finished with value: 474328.0 and parameters: {'threshold': 0.436296047941667}. Best is trial 35 with value: 474328.0.
# [I 2025-11-02 04:32:56,308] Trial 36 finished with value: 474320.0 and parameters: {'threshold': 0.4292072472303114}. Best is trial 36 with value: 474320.0.
# [I 2025-11-02 04:32:56,341] Trial 37 finished with value: 656304.0 and parameters: {'threshold': 0.2027467132284084}. Best is trial 36 with value: 474320.0.
# [I 2025-11-02 04:32:56,371] Trial 38 finished with value: 480616.0 and parameters: {'threshold': 0.33192128581876834}. Best is trial 36 with value: 474320.0.
# [I 2025-11-02 04:32:56,404] Trial 39 finished with value: 474332.0 and parameters: {'threshold': 0.4314767166419359}. Best is trial 36 with value: 474320.0.
# [I 2025-11-02 04:32:56,435] Trial 40 finished with value: 3263940.0 and parameters: {'threshold': 0.05544954555542553}. Best is trial 36 with value: 474320.0.
# [I 2025-11-02 04:32:56,467] Trial 41 finished with value: 474340.0 and parameters: {'threshold': 0.42449120606717283}. Best is trial 36 with value: 474320.0.
# [I 2025-11-02 04:32:56,498] Trial 42 finished with value: 474318.0 and parameters: {'threshold': 0.4288959159407192}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:56,530] Trial 43 finished with value: 474518.0 and parameters: {'threshold': 0.5476239978736043}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:56,563] Trial 44 finished with value: 476304.0 and parameters: {'threshold': 0.35807532357161936}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:56,595] Trial 45 finished with value: 490704.0 and parameters: {'threshold': 0.30099025024777737}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:56,628] Trial 46 finished with value: 1223188.0 and parameters: {'threshold': 0.11923838527195979}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:56,659] Trial 47 finished with value: 474526.0 and parameters: {'threshold': 0.668546581806502}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:56,691] Trial 48 finished with value: 474352.0 and parameters: {'threshold': 0.41528400282767475}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:56,724] Trial 49 finished with value: 616518.0 and parameters: {'threshold': 0.21622083957590094}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:56,756] Trial 50 finished with value: 474334.0 and parameters: {'threshold': 0.42728824047851904}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:56,788] Trial 51 finished with value: 474338.0 and parameters: {'threshold': 0.4373014308555342}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:56,820] Trial 52 finished with value: 474450.0 and parameters: {'threshold': 0.517423173860225}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:56,852] Trial 53 finished with value: 474764.0 and parameters: {'threshold': 0.39006725480776955}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:56,884] Trial 54 finished with value: 482940.0 and parameters: {'threshold': 0.32443317504742075}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:56,916] Trial 55 finished with value: 474524.0 and parameters: {'threshold': 0.5679120256314532}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:56,947] Trial 56 finished with value: 474526.0 and parameters: {'threshold': 0.7697485037657625}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:56,979] Trial 57 finished with value: 474330.0 and parameters: {'threshold': 0.43660971089202133}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:57,011] Trial 58 finished with value: 474454.0 and parameters: {'threshold': 0.5193989537203391}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:57,043] Trial 59 finished with value: 475442.0 and parameters: {'threshold': 0.36694651579588167}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:57,075] Trial 60 finished with value: 474346.0 and parameters: {'threshold': 0.4457927115056342}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:57,107] Trial 61 finished with value: 474606.0 and parameters: {'threshold': 0.3975085356725305}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:57,138] Trial 62 finished with value: 474332.0 and parameters: {'threshold': 0.45873415365710646}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:57,171] Trial 63 finished with value: 474422.0 and parameters: {'threshold': 0.5021193488911008}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:57,202] Trial 64 finished with value: 474336.0 and parameters: {'threshold': 0.4487064741887411}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:57,234] Trial 65 finished with value: 475412.0 and parameters: {'threshold': 0.36813747883135123}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:57,266] Trial 66 finished with value: 512818.0 and parameters: {'threshold': 0.27205740804884315}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:57,297] Trial 67 finished with value: 474512.0 and parameters: {'threshold': 0.5393963835379345}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:57,329] Trial 68 finished with value: 474526.0 and parameters: {'threshold': 0.6080657649801527}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:57,362] Trial 69 finished with value: 474346.0 and parameters: {'threshold': 0.4807449769127709}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:57,395] Trial 70 finished with value: 474526.0 and parameters: {'threshold': 0.6462456703223097}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:57,427] Trial 71 finished with value: 474350.0 and parameters: {'threshold': 0.42205895268829036}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:57,457] Trial 72 finished with value: 474332.0 and parameters: {'threshold': 0.44919808945147005}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:57,489] Trial 73 finished with value: 474334.0 and parameters: {'threshold': 0.4588527232550232}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:57,519] Trial 74 finished with value: 474524.0 and parameters: {'threshold': 0.5704887008129553}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:57,551] Trial 75 finished with value: 474526.0 and parameters: {'threshold': 0.9231804837440608}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:57,584] Trial 76 finished with value: 480026.0 and parameters: {'threshold': 0.33416978412803966}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:57,617] Trial 77 finished with value: 474806.0 and parameters: {'threshold': 0.3877279196339868}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:57,649] Trial 78 finished with value: 474378.0 and parameters: {'threshold': 0.48939480960933873}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:57,681] Trial 79 finished with value: 474430.0 and parameters: {'threshold': 0.40707956235369225}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:57,713] Trial 80 finished with value: 487950.0 and parameters: {'threshold': 0.30781527260724517}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:57,745] Trial 81 finished with value: 474334.0 and parameters: {'threshold': 0.4374593444714966}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:57,777] Trial 82 finished with value: 474340.0 and parameters: {'threshold': 0.46076326333625534}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:57,809] Trial 83 finished with value: 477380.0 and parameters: {'threshold': 0.34990500609874103}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:57,841] Trial 84 finished with value: 474474.0 and parameters: {'threshold': 0.5250604756076347}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:57,872] Trial 85 finished with value: 474340.0 and parameters: {'threshold': 0.4263630362186321}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:57,904] Trial 86 finished with value: 474396.0 and parameters: {'threshold': 0.49178365310575434}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:57,937] Trial 87 finished with value: 474756.0 and parameters: {'threshold': 0.3893604275909862}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:57,969] Trial 88 finished with value: 474330.0 and parameters: {'threshold': 0.4652332438271477}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:58,002] Trial 89 finished with value: 474334.0 and parameters: {'threshold': 0.45778658226732427}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:58,033] Trial 90 finished with value: 474524.0 and parameters: {'threshold': 0.5829566128261955}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:58,065] Trial 91 finished with value: 474404.0 and parameters: {'threshold': 0.4092513170827645}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:58,096] Trial 92 finished with value: 474360.0 and parameters: {'threshold': 0.4742665278669245}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:58,129] Trial 93 finished with value: 474446.0 and parameters: {'threshold': 0.5129588050165709}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:58,160] Trial 94 finished with value: 474510.0 and parameters: {'threshold': 0.5364249040305459}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:58,191] Trial 95 finished with value: 474330.0 and parameters: {'threshold': 0.4366667382406733}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:58,223] Trial 96 finished with value: 475112.0 and parameters: {'threshold': 0.3752702147355269}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:58,255] Trial 97 finished with value: 474330.0 and parameters: {'threshold': 0.439961642669698}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:58,286] Trial 98 finished with value: 477046.0 and parameters: {'threshold': 0.35242356827356397}. Best is trial 42 with value: 474318.0.
# [I 2025-11-02 04:32:58,318] Trial 99 finished with value: 474394.0 and parameters: {'threshold': 0.49270599092291306}. Best is trial 42 with value: 474318.0.
#   ✓ Mejor threshold: 0.4289
#     - Precision: 0.5459
#     - Recall:    0.0026
#     - F1:        0.0052
#     - Costo:     474318.00
#
# ================================================================================
# RESUMEN DE MEJORES THRESHOLDS
# ================================================================================
# W0_discrete     | Thr=0.4875 | P=0.556 | R=0.086 | F1=0.149 | Cost=1379222
# W1_discrete     | Thr=0.3372 | P=0.619 | R=0.000 | F1=0.000 | Cost=412910
# W7_discrete     | Thr=0.4601 | P=0.551 | R=0.003 | F1=0.005 | Cost=672422
# W30_discrete    | Thr=0.4289 | P=0.546 | R=0.003 | F1=0.005 | Cost=474318

# %%
#OPTIMIZACIÓN DE HIPERPARÁMETROS - Parte 1 (Función Objetivo)
def objective_hgb(trial, hname, lcol, gap_days, embargo_days):
    """
    Función objetivo para optimizar hiperparámetros de HistGradientBoostingClassifier.
    
    Retorna: AUC-PR OOF
    """
    
    # 1) Sugerir hiperparámetros
    params = {
        'learning_rate': trial.suggest_categorical('learning_rate', [0.01, 0.03, 0.05, 0.1]),
        'max_leaf_nodes': trial.suggest_categorical('max_leaf_nodes', [31, 63, 127]),
        'max_depth': trial.suggest_categorical('max_depth', [None, 8, 10]),
        'min_samples_leaf': trial.suggest_categorical('min_samples_leaf', [20, 50, 100, 200]),
        'l2_regularization': trial.suggest_categorical('l2_regularization', [0.0, 0.1, 1.0, 5.0]),
        'max_bins': trial.suggest_categorical('max_bins', [128, 255])
    }
    
    # 2) Preparar datos
    X, y, feats, num_cols, cat_cols, k = get_xy_for_horizon(hname, lcol)
    
    # 3) Preprocesador
    pre_dense = onehot_preprocessor(num_cols, cat_cols, scale_numeric=False, 
                                    min_freq=0.01, dense_ohe=True)
    
    # 4) Construir modelo con hiperparámetros sugeridos
    to_dense = FunctionTransformer(lambda X: X.toarray() if hasattr(X, "toarray") else X,
                                   accept_sparse=True)
    
    model = Pipeline([
        ("pre", pre_dense),
        ("to_dense", to_dense),
        ("clf", HistGradientBoostingClassifier(
            max_depth=params['max_depth'],
            max_leaf_nodes=params['max_leaf_nodes'],
            learning_rate=params['learning_rate'],
            l2_regularization=params['l2_regularization'],
            max_bins=params['max_bins'],
            min_samples_leaf=params['min_samples_leaf'],
            early_stopping=True,
            random_state=42
        ))
    ])
    
    # 5) Cross-validation temporal
    cv = PurgedTimeSeriesCV(
        n_splits=5, 
        time_col=TIME_COL,
        gap_before_days=gap_days,
        embargo_after_days=embargo_days
    )
    
    # 6) Entrenar y evaluar con CV
    oof_proba = np.zeros(len(X))
    oof_mask = np.zeros(len(X), dtype=bool)
    
    for fold, (tr_idx, va_idx) in enumerate(cv.split(X)):
        Xtr, Xva = X.iloc[tr_idx].copy(), X.iloc[va_idx].copy()
        ytr, yva = y[tr_idx], y[va_idx]
        
        model.fit(Xtr[feats], ytr)
        proba = model.predict_proba(Xva[feats])[:, 1]
        oof_proba[va_idx] = proba
        oof_mask[va_idx] = True
    
    # 7) Calcular AUC-PR OOF
    y_true = y[oof_mask]
    y_prob = oof_proba[oof_mask]
    
    try:
        auc_pr = average_precision_score(y_true, y_prob)
    except:
        try:
            auc_pr = roc_auc_score(y_true, y_prob)
        except:
            auc_pr = 0.0
    
    # Registrar AUC-ROC también
    try:
        auc_roc = roc_auc_score(y_true, y_prob)
        trial.set_user_attr('auc_roc', auc_roc)
    except:
        pass
    
    return auc_pr

print("✓ Función objetivo para hiperparámetros definida")
# Out:
# ✓ Función objetivo para hiperparámetros definida

# %%
# OPTIMIZACIÓN DE HIPERPARÁMETROS
# Estructura para guardar mejores hiperparámetros
BEST_HYPERPARAMS = {}

# Iterar sobre cada horizonte
for hname, lcol, gap_days, embargo_days in HORIZONS:
    print(f"\n--- Optimizando hiperparámetros para {hname} ---")
    
    # Crear study de Optuna para maximizar AUC-PR
    study = optuna.create_study(
        study_name=f"HGB_{hname}",
        direction='maximize',
        sampler=optuna.samplers.TPESampler(seed=42)
    )
    
    # Optimizar (50 trials)
    study.optimize(
        lambda trial: objective_hgb(trial, hname, lcol, gap_days, embargo_days),
        n_trials=50,
        show_progress_bar=True
    )
    
    # Obtener mejores resultados
    best_trial = study.best_trial
    best_params = best_trial.params
    best_auc_pr = best_trial.value
    best_auc_roc = best_trial.user_attrs.get('auc_roc', None)
    
    # Guardar
    BEST_HYPERPARAMS[hname] = {
        'params': best_params,
        'auc_pr': best_auc_pr,
        'auc_roc': best_auc_roc
    }
    
    # Imprimir resultados
    print(f"\n  ✓ Mejores hiperparámetros:")
    for param, value in best_params.items():
        print(f"    - {param:20s}: {value}")
    print(f"\n  ✓ Mejor AUC-PR:  {best_auc_pr:.4f}")
    if best_auc_roc is not None:
        print(f"  ✓ Mejor AUC-ROC: {best_auc_roc:.4f}")

# Resumen
print("\n" + "="*80)
print("RESUMEN DE MEJORES HIPERPARÁMETROS")
print("="*80)
for hname, info in BEST_HYPERPARAMS.items():
    print(f"\n{hname}:")
    print(f"  AUC-PR: {info['auc_pr']:.4f}")
    if info['auc_roc'] is not None:
        print(f"  AUC-ROC: {info['auc_roc']:.4f}")
    print(f"  Params: {info['params']}")
# Out:
# [I 2025-11-02 04:32:58,376] A new study created in memory with name: HGB_W0_discrete
# --- Optimizando hiperparámetros para W0_discrete ---
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-11-02 04:38:45,194] Trial 0 finished with value: 0.43499281257432176 and parameters: {'learning_rate': 0.03, 'max_leaf_nodes': 31, 'max_depth': None, 'min_samples_leaf': 50, 'l2_regularization': 5.0, 'max_bins': 128}. Best is trial 0 with value: 0.43499281257432176.
# [I 2025-11-02 04:45:19,602] Trial 1 finished with value: 0.4322980872483294 and parameters: {'learning_rate': 0.01, 'max_leaf_nodes': 63, 'max_depth': 8, 'min_samples_leaf': 200, 'l2_regularization': 0.0, 'max_bins': 128}. Best is trial 0 with value: 0.43499281257432176.
# [I 2025-11-02 04:50:45,784] Trial 2 finished with value: 0.4394795319469511 and parameters: {'learning_rate': 0.1, 'max_leaf_nodes': 63, 'max_depth': 8, 'min_samples_leaf': 20, 'l2_regularization': 0.1, 'max_bins': 255}. Best is trial 2 with value: 0.4394795319469511.
# [I 2025-11-02 04:57:16,290] Trial 3 finished with value: 0.43937812888846633 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 63, 'max_depth': 10, 'min_samples_leaf': 200, 'l2_regularization': 1.0, 'max_bins': 128}. Best is trial 2 with value: 0.4394795319469511.
# [I 2025-11-02 05:04:13,863] Trial 4 finished with value: 0.43335477176705794 and parameters: {'learning_rate': 0.01, 'max_leaf_nodes': 127, 'max_depth': 8, 'min_samples_leaf': 100, 'l2_regularization': 0.0, 'max_bins': 255}. Best is trial 2 with value: 0.4394795319469511.
# [I 2025-11-02 05:10:02,089] Trial 5 finished with value: 0.4349837876317377 and parameters: {'learning_rate': 0.03, 'max_leaf_nodes': 31, 'max_depth': None, 'min_samples_leaf': 100, 'l2_regularization': 0.1, 'max_bins': 128}. Best is trial 2 with value: 0.4394795319469511.
# [I 2025-11-02 05:18:09,790] Trial 6 finished with value: 0.43897093935502557 and parameters: {'learning_rate': 0.03, 'max_leaf_nodes': 127, 'max_depth': None, 'min_samples_leaf': 20, 'l2_regularization': 0.0, 'max_bins': 255}. Best is trial 2 with value: 0.4394795319469511.
# [I 2025-11-02 05:26:37,688] Trial 7 finished with value: 0.43486403987875194 and parameters: {'learning_rate': 0.01, 'max_leaf_nodes': 127, 'max_depth': None, 'min_samples_leaf': 20, 'l2_regularization': 0.0, 'max_bins': 255}. Best is trial 2 with value: 0.4394795319469511.
# [I 2025-11-02 05:33:02,888] Trial 8 finished with value: 0.4395038804974491 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 63, 'max_depth': 10, 'min_samples_leaf': 20, 'l2_regularization': 1.0, 'max_bins': 128}. Best is trial 8 with value: 0.4395038804974491.
# [I 2025-11-02 05:41:07,001] Trial 9 finished with value: 0.44016907572445174 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 127, 'max_depth': None, 'min_samples_leaf': 100, 'l2_regularization': 5.0, 'max_bins': 128}. Best is trial 9 with value: 0.44016907572445174.
# [I 2025-11-02 05:49:18,845] Trial 10 finished with value: 0.44016907572445174 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 127, 'max_depth': None, 'min_samples_leaf': 100, 'l2_regularization': 5.0, 'max_bins': 128}. Best is trial 9 with value: 0.44016907572445174.
# [I 2025-11-02 05:57:33,422] Trial 11 finished with value: 0.44016907572445174 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 127, 'max_depth': None, 'min_samples_leaf': 100, 'l2_regularization': 5.0, 'max_bins': 128}. Best is trial 9 with value: 0.44016907572445174.
# [I 2025-11-02 06:05:43,592] Trial 12 finished with value: 0.44016907572445174 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 127, 'max_depth': None, 'min_samples_leaf': 100, 'l2_regularization': 5.0, 'max_bins': 128}. Best is trial 9 with value: 0.44016907572445174.
# [I 2025-11-02 06:13:53,362] Trial 13 finished with value: 0.44016907572445174 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 127, 'max_depth': None, 'min_samples_leaf': 100, 'l2_regularization': 5.0, 'max_bins': 128}. Best is trial 9 with value: 0.44016907572445174.
# [I 2025-11-02 06:20:08,415] Trial 14 finished with value: 0.43965038327274514 and parameters: {'learning_rate': 0.1, 'max_leaf_nodes': 127, 'max_depth': 10, 'min_samples_leaf': 50, 'l2_regularization': 5.0, 'max_bins': 128}. Best is trial 9 with value: 0.44016907572445174.
# [I 2025-11-02 06:28:03,796] Trial 15 finished with value: 0.44016907572445174 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 127, 'max_depth': None, 'min_samples_leaf': 100, 'l2_regularization': 5.0, 'max_bins': 128}. Best is trial 9 with value: 0.44016907572445174.
# [I 2025-11-02 06:33:58,185] Trial 16 finished with value: 0.4380354705162202 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 31, 'max_depth': None, 'min_samples_leaf': 100, 'l2_regularization': 5.0, 'max_bins': 128}. Best is trial 9 with value: 0.44016907572445174.
# [I 2025-11-02 06:41:50,375] Trial 17 finished with value: 0.44016907572445174 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 127, 'max_depth': None, 'min_samples_leaf': 100, 'l2_regularization': 5.0, 'max_bins': 128}. Best is trial 9 with value: 0.44016907572445174.
# [I 2025-11-02 06:48:06,978] Trial 18 finished with value: 0.4393345751627379 and parameters: {'learning_rate': 0.1, 'max_leaf_nodes': 127, 'max_depth': 10, 'min_samples_leaf': 200, 'l2_regularization': 0.1, 'max_bins': 255}. Best is trial 9 with value: 0.44016907572445174.
# [I 2025-11-02 06:53:39,158] Trial 19 finished with value: 0.43781237421638236 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 31, 'max_depth': 8, 'min_samples_leaf': 50, 'l2_regularization': 1.0, 'max_bins': 128}. Best is trial 9 with value: 0.44016907572445174.
# [I 2025-11-02 07:01:27,394] Trial 20 finished with value: 0.44016907572445174 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 127, 'max_depth': None, 'min_samples_leaf': 100, 'l2_regularization': 5.0, 'max_bins': 128}. Best is trial 9 with value: 0.44016907572445174.
# [I 2025-11-02 07:09:15,418] Trial 21 finished with value: 0.44016907572445174 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 127, 'max_depth': None, 'min_samples_leaf': 100, 'l2_regularization': 5.0, 'max_bins': 128}. Best is trial 9 with value: 0.44016907572445174.
# [I 2025-11-02 07:17:02,176] Trial 22 finished with value: 0.44016907572445174 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 127, 'max_depth': None, 'min_samples_leaf': 100, 'l2_regularization': 5.0, 'max_bins': 128}. Best is trial 9 with value: 0.44016907572445174.
# [I 2025-11-02 07:24:46,502] Trial 23 finished with value: 0.44016907572445174 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 127, 'max_depth': None, 'min_samples_leaf': 100, 'l2_regularization': 5.0, 'max_bins': 128}. Best is trial 9 with value: 0.44016907572445174.
# [I 2025-11-02 07:33:15,994] Trial 24 finished with value: 0.44016907572445174 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 127, 'max_depth': None, 'min_samples_leaf': 100, 'l2_regularization': 5.0, 'max_bins': 128}. Best is trial 9 with value: 0.44016907572445174.
# [I 2025-11-02 07:41:41,280] Trial 25 finished with value: 0.44016907572445174 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 127, 'max_depth': None, 'min_samples_leaf': 100, 'l2_regularization': 5.0, 'max_bins': 128}. Best is trial 9 with value: 0.44016907572445174.
# [I 2025-11-02 07:48:30,509] Trial 26 finished with value: 0.4401870892581389 and parameters: {'learning_rate': 0.1, 'max_leaf_nodes': 127, 'max_depth': None, 'min_samples_leaf': 100, 'l2_regularization': 5.0, 'max_bins': 255}. Best is trial 26 with value: 0.4401870892581389.
# [I 2025-11-02 07:55:26,871] Trial 27 finished with value: 0.4399017572608674 and parameters: {'learning_rate': 0.1, 'max_leaf_nodes': 127, 'max_depth': None, 'min_samples_leaf': 200, 'l2_regularization': 1.0, 'max_bins': 255}. Best is trial 26 with value: 0.4401870892581389.
# [I 2025-11-02 08:00:47,281] Trial 28 finished with value: 0.4391192643458166 and parameters: {'learning_rate': 0.1, 'max_leaf_nodes': 31, 'max_depth': 8, 'min_samples_leaf': 50, 'l2_regularization': 0.1, 'max_bins': 255}. Best is trial 26 with value: 0.4401870892581389.
# [I 2025-11-02 08:07:50,750] Trial 29 finished with value: 0.43756081603019154 and parameters: {'learning_rate': 0.03, 'max_leaf_nodes': 63, 'max_depth': 10, 'min_samples_leaf': 50, 'l2_regularization': 5.0, 'max_bins': 255}. Best is trial 26 with value: 0.4401870892581389.
# [I 2025-11-02 08:13:24,643] Trial 30 finished with value: 0.43938986549031844 and parameters: {'learning_rate': 0.1, 'max_leaf_nodes': 31, 'max_depth': None, 'min_samples_leaf': 100, 'l2_regularization': 5.0, 'max_bins': 255}. Best is trial 26 with value: 0.4401870892581389.
# [I 2025-11-02 08:20:27,047] Trial 31 finished with value: 0.44001686885651614 and parameters: {'learning_rate': 0.1, 'max_leaf_nodes': 127, 'max_depth': None, 'min_samples_leaf': 100, 'l2_regularization': 5.0, 'max_bins': 128}. Best is trial 26 with value: 0.4401870892581389.
# [I 2025-11-02 08:28:53,190] Trial 32 finished with value: 0.4348400666335109 and parameters: {'learning_rate': 0.01, 'max_leaf_nodes': 127, 'max_depth': None, 'min_samples_leaf': 100, 'l2_regularization': 5.0, 'max_bins': 255}. Best is trial 26 with value: 0.4401870892581389.
# [I 2025-11-02 08:36:57,995] Trial 33 finished with value: 0.43895143778964496 and parameters: {'learning_rate': 0.03, 'max_leaf_nodes': 127, 'max_depth': None, 'min_samples_leaf': 100, 'l2_regularization': 5.0, 'max_bins': 128}. Best is trial 26 with value: 0.4401870892581389.
# [I 2025-11-02 08:42:34,931] Trial 34 finished with value: 0.4395610001312801 and parameters: {'learning_rate': 0.1, 'max_leaf_nodes': 63, 'max_depth': 8, 'min_samples_leaf': 200, 'l2_regularization': 5.0, 'max_bins': 128}. Best is trial 26 with value: 0.4401870892581389.
# [I 2025-11-02 08:50:52,809] Trial 35 finished with value: 0.4348851226784249 and parameters: {'learning_rate': 0.01, 'max_leaf_nodes': 127, 'max_depth': None, 'min_samples_leaf': 100, 'l2_regularization': 0.0, 'max_bins': 255}. Best is trial 26 with value: 0.4401870892581389.
# [I 2025-11-02 08:58:38,270] Trial 36 finished with value: 0.44026638700292225 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 127, 'max_depth': None, 'min_samples_leaf': 100, 'l2_regularization': 0.1, 'max_bins': 128}. Best is trial 36 with value: 0.44026638700292225.
# [I 2025-11-02 09:04:36,454] Trial 37 finished with value: 0.4389487240857926 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 63, 'max_depth': 8, 'min_samples_leaf': 20, 'l2_regularization': 0.1, 'max_bins': 255}. Best is trial 36 with value: 0.44026638700292225.
# [I 2025-11-02 09:12:38,631] Trial 38 finished with value: 0.4389939332446976 and parameters: {'learning_rate': 0.03, 'max_leaf_nodes': 127, 'max_depth': None, 'min_samples_leaf': 100, 'l2_regularization': 0.1, 'max_bins': 128}. Best is trial 36 with value: 0.44026638700292225.
# [I 2025-11-02 09:20:43,075] Trial 39 finished with value: 0.43444728626500895 and parameters: {'learning_rate': 0.01, 'max_leaf_nodes': 127, 'max_depth': 10, 'min_samples_leaf': 200, 'l2_regularization': 0.1, 'max_bins': 255}. Best is trial 36 with value: 0.44026638700292225.
# [I 2025-11-02 09:26:28,528] Trial 40 finished with value: 0.4398975446606241 and parameters: {'learning_rate': 0.1, 'max_leaf_nodes': 63, 'max_depth': None, 'min_samples_leaf': 20, 'l2_regularization': 0.1, 'max_bins': 128}. Best is trial 36 with value: 0.44026638700292225.
# [I 2025-11-02 09:34:09,196] Trial 41 finished with value: 0.4401629594615095 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 127, 'max_depth': None, 'min_samples_leaf': 100, 'l2_regularization': 1.0, 'max_bins': 128}. Best is trial 36 with value: 0.44026638700292225.
# [I 2025-11-02 09:41:55,749] Trial 42 finished with value: 0.44029066990966853 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 127, 'max_depth': None, 'min_samples_leaf': 100, 'l2_regularization': 0.0, 'max_bins': 128}. Best is trial 42 with value: 0.44029066990966853.
# [I 2025-11-02 09:50:22,799] Trial 43 finished with value: 0.44029066990966853 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 127, 'max_depth': None, 'min_samples_leaf': 100, 'l2_regularization': 0.0, 'max_bins': 128}. Best is trial 42 with value: 0.44029066990966853.
# [I 2025-11-02 09:58:19,308] Trial 44 finished with value: 0.44029066990966853 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 127, 'max_depth': None, 'min_samples_leaf': 100, 'l2_regularization': 0.0, 'max_bins': 128}. Best is trial 42 with value: 0.44029066990966853.
# [I 2025-11-02 10:06:25,033] Trial 45 finished with value: 0.44029066990966853 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 127, 'max_depth': None, 'min_samples_leaf': 100, 'l2_regularization': 0.0, 'max_bins': 128}. Best is trial 42 with value: 0.44029066990966853.
# [I 2025-11-02 10:14:14,189] Trial 46 finished with value: 0.44029066990966853 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 127, 'max_depth': None, 'min_samples_leaf': 100, 'l2_regularization': 0.0, 'max_bins': 128}. Best is trial 42 with value: 0.44029066990966853.
# [I 2025-11-02 10:21:56,016] Trial 47 finished with value: 0.4400632215390076 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 127, 'max_depth': None, 'min_samples_leaf': 20, 'l2_regularization': 0.0, 'max_bins': 128}. Best is trial 42 with value: 0.44029066990966853.
# [I 2025-11-02 10:27:38,354] Trial 48 finished with value: 0.43797437602870126 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 31, 'max_depth': None, 'min_samples_leaf': 100, 'l2_regularization': 0.0, 'max_bins': 128}. Best is trial 42 with value: 0.44029066990966853.
# [I 2025-11-02 10:34:49,818] A new study created in memory with name: HGB_W1_discrete
# [I 2025-11-02 10:34:49,812] Trial 49 finished with value: 0.43994220179134125 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 127, 'max_depth': 10, 'min_samples_leaf': 100, 'l2_regularization': 0.0, 'max_bins': 128}. Best is trial 42 with value: 0.44029066990966853.
#
#   ✓ Mejores hiperparámetros:
#     - learning_rate       : 0.05
#     - max_leaf_nodes      : 127
#     - max_depth           : None
#     - min_samples_leaf    : 100
#     - l2_regularization   : 0.0
#     - max_bins            : 128
#
#   ✓ Mejor AUC-PR:  0.4403
#   ✓ Mejor AUC-ROC: 0.6840
#
# --- Optimizando hiperparámetros para W1_discrete ---
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-11-02 10:40:42,076] Trial 0 finished with value: 0.1494325239555542 and parameters: {'learning_rate': 0.03, 'max_leaf_nodes': 31, 'max_depth': None, 'min_samples_leaf': 50, 'l2_regularization': 5.0, 'max_bins': 128}. Best is trial 0 with value: 0.1494325239555542.
# [I 2025-11-02 10:47:34,072] Trial 1 finished with value: 0.14858277335959869 and parameters: {'learning_rate': 0.01, 'max_leaf_nodes': 63, 'max_depth': 8, 'min_samples_leaf': 200, 'l2_regularization': 0.0, 'max_bins': 128}. Best is trial 0 with value: 0.1494325239555542.
# [I 2025-11-02 10:52:31,839] Trial 2 finished with value: 0.14895959768983255 and parameters: {'learning_rate': 0.1, 'max_leaf_nodes': 63, 'max_depth': 8, 'min_samples_leaf': 20, 'l2_regularization': 0.1, 'max_bins': 255}. Best is trial 0 with value: 0.1494325239555542.
# [I 2025-11-02 10:58:51,643] Trial 3 finished with value: 0.1499524953290844 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 63, 'max_depth': 10, 'min_samples_leaf': 200, 'l2_regularization': 1.0, 'max_bins': 128}. Best is trial 3 with value: 0.1499524953290844.
# [I 2025-11-02 11:06:21,665] Trial 4 finished with value: 0.148761905699904 and parameters: {'learning_rate': 0.01, 'max_leaf_nodes': 127, 'max_depth': 8, 'min_samples_leaf': 100, 'l2_regularization': 0.0, 'max_bins': 255}. Best is trial 3 with value: 0.1499524953290844.
# [I 2025-11-02 11:12:21,036] Trial 5 finished with value: 0.1494443274991669 and parameters: {'learning_rate': 0.03, 'max_leaf_nodes': 31, 'max_depth': None, 'min_samples_leaf': 100, 'l2_regularization': 0.1, 'max_bins': 128}. Best is trial 3 with value: 0.1499524953290844.
# [I 2025-11-02 11:19:51,801] Trial 6 finished with value: 0.1491836236386825 and parameters: {'learning_rate': 0.03, 'max_leaf_nodes': 127, 'max_depth': None, 'min_samples_leaf': 20, 'l2_regularization': 0.0, 'max_bins': 255}. Best is trial 3 with value: 0.1499524953290844.
# [I 2025-11-02 11:27:53,805] Trial 7 finished with value: 0.1486736863063077 and parameters: {'learning_rate': 0.01, 'max_leaf_nodes': 127, 'max_depth': None, 'min_samples_leaf': 20, 'l2_regularization': 0.0, 'max_bins': 255}. Best is trial 3 with value: 0.1499524953290844.
# [I 2025-11-02 11:34:22,069] Trial 8 finished with value: 0.14983697685263844 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 63, 'max_depth': 10, 'min_samples_leaf': 20, 'l2_regularization': 1.0, 'max_bins': 128}. Best is trial 3 with value: 0.1499524953290844.
# [I 2025-11-02 11:42:51,834] Trial 9 finished with value: 0.1494130922731737 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 127, 'max_depth': None, 'min_samples_leaf': 100, 'l2_regularization': 5.0, 'max_bins': 128}. Best is trial 3 with value: 0.1499524953290844.
# [I 2025-11-02 11:50:34,293] Trial 10 finished with value: 0.1499524953290844 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 63, 'max_depth': 10, 'min_samples_leaf': 200, 'l2_regularization': 1.0, 'max_bins': 128}. Best is trial 3 with value: 0.1499524953290844.
# [I 2025-11-02 11:58:22,675] Trial 11 finished with value: 0.1499524953290844 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 63, 'max_depth': 10, 'min_samples_leaf': 200, 'l2_regularization': 1.0, 'max_bins': 128}. Best is trial 3 with value: 0.1499524953290844.
# [I 2025-11-02 12:05:57,494] Trial 12 finished with value: 0.1499524953290844 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 63, 'max_depth': 10, 'min_samples_leaf': 200, 'l2_regularization': 1.0, 'max_bins': 128}. Best is trial 3 with value: 0.1499524953290844.
# [I 2025-11-02 12:13:06,846] Trial 13 finished with value: 0.1499524953290844 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 63, 'max_depth': 10, 'min_samples_leaf': 200, 'l2_regularization': 1.0, 'max_bins': 128}. Best is trial 3 with value: 0.1499524953290844.
# [I 2025-11-02 12:18:22,011] Trial 14 finished with value: 0.14977603643634563 and parameters: {'learning_rate': 0.1, 'max_leaf_nodes': 63, 'max_depth': 10, 'min_samples_leaf': 200, 'l2_regularization': 1.0, 'max_bins': 128}. Best is trial 3 with value: 0.1499524953290844.
# [I 2025-11-02 12:24:47,150] Trial 15 finished with value: 0.1498878509890265 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 63, 'max_depth': 10, 'min_samples_leaf': 50, 'l2_regularization': 1.0, 'max_bins': 128}. Best is trial 3 with value: 0.1499524953290844.
# [I 2025-11-02 12:30:27,858] Trial 16 finished with value: 0.15001898036457434 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 31, 'max_depth': 10, 'min_samples_leaf': 200, 'l2_regularization': 1.0, 'max_bins': 128}. Best is trial 16 with value: 0.15001898036457434.
# [I 2025-11-02 12:36:10,023] Trial 17 finished with value: 0.15001898036457434 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 31, 'max_depth': 10, 'min_samples_leaf': 200, 'l2_regularization': 1.0, 'max_bins': 128}. Best is trial 16 with value: 0.15001898036457434.
# [I 2025-11-02 12:41:08,440] Trial 18 finished with value: 0.15017135618899008 and parameters: {'learning_rate': 0.1, 'max_leaf_nodes': 31, 'max_depth': 10, 'min_samples_leaf': 200, 'l2_regularization': 0.1, 'max_bins': 255}. Best is trial 18 with value: 0.15017135618899008.
# [I 2025-11-02 12:46:15,286] Trial 19 finished with value: 0.15002941262803357 and parameters: {'learning_rate': 0.1, 'max_leaf_nodes': 31, 'max_depth': 10, 'min_samples_leaf': 50, 'l2_regularization': 0.1, 'max_bins': 255}. Best is trial 18 with value: 0.15017135618899008.
# [I 2025-11-02 12:51:35,754] Trial 20 finished with value: 0.14989897998460694 and parameters: {'learning_rate': 0.1, 'max_leaf_nodes': 31, 'max_depth': 8, 'min_samples_leaf': 50, 'l2_regularization': 0.1, 'max_bins': 255}. Best is trial 18 with value: 0.15017135618899008.
# [I 2025-11-02 12:57:17,093] Trial 21 finished with value: 0.15002941262803357 and parameters: {'learning_rate': 0.1, 'max_leaf_nodes': 31, 'max_depth': 10, 'min_samples_leaf': 50, 'l2_regularization': 0.1, 'max_bins': 255}. Best is trial 18 with value: 0.15017135618899008.
# [I 2025-11-02 13:03:02,520] Trial 22 finished with value: 0.15002941262803357 and parameters: {'learning_rate': 0.1, 'max_leaf_nodes': 31, 'max_depth': 10, 'min_samples_leaf': 50, 'l2_regularization': 0.1, 'max_bins': 255}. Best is trial 18 with value: 0.15017135618899008.
# [I 2025-11-02 13:08:40,278] Trial 23 finished with value: 0.15002941262803357 and parameters: {'learning_rate': 0.1, 'max_leaf_nodes': 31, 'max_depth': 10, 'min_samples_leaf': 50, 'l2_regularization': 0.1, 'max_bins': 255}. Best is trial 18 with value: 0.15017135618899008.
# [I 2025-11-02 15:34:46,917] Trial 0 finished with value: 0.2589926184622372 and parameters: {'learning_rate': 0.03, 'max_leaf_nodes': 31, 'max_depth': None, 'min_samples_leaf': 50, 'l2_regularization': 5.0, 'max_bins': 128}. Best is trial 0 with value: 0.2589926184622372.
# [I 2025-11-02 15:41:28,750] Trial 1 finished with value: 0.2579161247403369 and parameters: {'learning_rate': 0.01, 'max_leaf_nodes': 63, 'max_depth': 8, 'min_samples_leaf': 200, 'l2_regularization': 0.0, 'max_bins': 128}. Best is trial 0 with value: 0.2589926184622372.
# [I 2025-11-02 15:47:00,150] Trial 2 finished with value: 0.25869370382157736 and parameters: {'learning_rate': 0.1, 'max_leaf_nodes': 63, 'max_depth': 8, 'min_samples_leaf': 20, 'l2_regularization': 0.1, 'max_bins': 255}. Best is trial 0 with value: 0.2589926184622372.
# [I 2025-11-02 15:53:39,322] Trial 3 finished with value: 0.25996445273967067 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 63, 'max_depth': 10, 'min_samples_leaf': 200, 'l2_regularization': 1.0, 'max_bins': 128}. Best is trial 3 with value: 0.25996445273967067.
# [I 2025-11-02 16:01:05,955] Trial 4 finished with value: 0.2581890324567399 and parameters: {'learning_rate': 0.01, 'max_leaf_nodes': 127, 'max_depth': 8, 'min_samples_leaf': 100, 'l2_regularization': 0.0, 'max_bins': 255}. Best is trial 3 with value: 0.25996445273967067.
# [I 2025-11-02 16:07:21,761] Trial 5 finished with value: 0.2589230887050725 and parameters: {'learning_rate': 0.03, 'max_leaf_nodes': 31, 'max_depth': None, 'min_samples_leaf': 100, 'l2_regularization': 0.1, 'max_bins': 128}. Best is trial 3 with value: 0.25996445273967067.
# [I 2025-11-02 16:15:28,713] Trial 6 finished with value: 0.2596894763064325 and parameters: {'learning_rate': 0.03, 'max_leaf_nodes': 127, 'max_depth': None, 'min_samples_leaf': 20, 'l2_regularization': 0.0, 'max_bins': 255}. Best is trial 3 with value: 0.25996445273967067.
# [I 2025-11-02 16:24:42,915] Trial 7 finished with value: 0.2584886346592324 and parameters: {'learning_rate': 0.01, 'max_leaf_nodes': 127, 'max_depth': None, 'min_samples_leaf': 20, 'l2_regularization': 0.0, 'max_bins': 255}. Best is trial 3 with value: 0.25996445273967067.
# [I 2025-11-02 16:32:38,736] Trial 8 finished with value: 0.25989771322496036 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 63, 'max_depth': 10, 'min_samples_leaf': 20, 'l2_regularization': 1.0, 'max_bins': 128}. Best is trial 3 with value: 0.25996445273967067.
# [I 2025-11-02 16:41:49,526] Trial 9 finished with value: 0.25963951449325895 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 127, 'max_depth': None, 'min_samples_leaf': 100, 'l2_regularization': 5.0, 'max_bins': 128}. Best is trial 3 with value: 0.25996445273967067.
# [I 2025-11-02 16:49:30,296] Trial 10 finished with value: 0.25996445273967067 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 63, 'max_depth': 10, 'min_samples_leaf': 200, 'l2_regularization': 1.0, 'max_bins': 128}. Best is trial 3 with value: 0.25996445273967067.
# [I 2025-11-02 16:57:29,833] Trial 11 finished with value: 0.25996445273967067 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 63, 'max_depth': 10, 'min_samples_leaf': 200, 'l2_regularization': 1.0, 'max_bins': 128}. Best is trial 3 with value: 0.25996445273967067.
# [I 2025-11-02 17:05:23,672] Trial 12 finished with value: 0.25996445273967067 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 63, 'max_depth': 10, 'min_samples_leaf': 200, 'l2_regularization': 1.0, 'max_bins': 128}. Best is trial 3 with value: 0.25996445273967067.
# [I 2025-11-02 17:13:07,349] Trial 13 finished with value: 0.25996445273967067 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 63, 'max_depth': 10, 'min_samples_leaf': 200, 'l2_regularization': 1.0, 'max_bins': 128}. Best is trial 3 with value: 0.25996445273967067.
# [I 2025-11-02 17:20:04,784] Trial 14 finished with value: 0.2592876604859827 and parameters: {'learning_rate': 0.1, 'max_leaf_nodes': 63, 'max_depth': 10, 'min_samples_leaf': 200, 'l2_regularization': 1.0, 'max_bins': 128}. Best is trial 3 with value: 0.25996445273967067.
# [I 2025-11-02 17:27:53,540] Trial 15 finished with value: 0.2596779787675373 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 63, 'max_depth': 10, 'min_samples_leaf': 50, 'l2_regularization': 1.0, 'max_bins': 128}. Best is trial 3 with value: 0.25996445273967067.
# [I 2025-11-02 17:34:41,244] Trial 16 finished with value: 0.2596106238357413 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 31, 'max_depth': 10, 'min_samples_leaf': 200, 'l2_regularization': 1.0, 'max_bins': 128}. Best is trial 3 with value: 0.25996445273967067.
# [I 2025-11-02 17:42:38,008] Trial 17 finished with value: 0.25996445273967067 and parameters: {'learning_rate': 0.05, 'max_leaf_nodes': 63, 'max_depth': 10, 'min_samples_leaf': 200, 'l2_regularization': 1.0, 'max_bins': 128}. Best is trial 3 with value: 0.25996445273967067.
# [I 2025-11-02 17:49:14,624] Trial 18 finished with value: 0.25925901440124577 and parameters: {'learning_rate': 0.1, 'max_leaf_nodes': 63, 'max_depth': 10, 'min_samples_leaf': 200, 'l2_regularization': 0.1, 'max_bins': 255}. Best is trial 3 with value: 0.25996445273967067.

# %%
# VISUALIZACIÓN DE RESULTADOS
import optuna.visualization as vis

study_name = "threshold_W0_discrete"

# %%
fig = vis.plot_optimization_history(study)
fig.show()

# %%
fig = vis.plot_param_importances(study)
fig.show()
